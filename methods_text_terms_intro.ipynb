# %% [markdown]
# # Purpose of this notebook
#
# Provide _some_ answer to "so how you detect interesting terms / phrases?"

# %% [markdown]
# Annoyingly, one has to respond with "that depends on what you mean with interesting phrases"
#
#
# There are varied methods, some simple enough that you could implement yourself in half an hour,
# that will return with some interesting fragments, so seem to work.
# ...yet often have assumptions that turn out to not match up with what you thought when you heard 'interesting'.

# %% [markdown]
# While each of these methods visible do useful things,
# each will miss things you may have wanted to give,
# which is invisible, and it is also not clear why.
#
#
# Consider if your goal was
# - "what multi-word phrases appear in this document"
# - "what multi-word phrases make this document interesting"
# - "what multi-word phrases make this document different from others in a set"
# - "can we make lists of words"
# - "what multi-word phrases make this document interesting"
# - match known phrases
# - match phrases of a specific topic
# They may may seem like subtle variations,
#
# Also, if you have not yet thought what kind of phrases are more interesting,
# or why, then you can't expect a method to prefer those.
#
#
# So for the most part, the below is a start on just the first in that list,
# to introduce some methods, but refined output will need your refined needs (and some refined code).

# %% [markdown]
# For example,
# - **tf-idf** is more of an ingredient for a larger analysis, search, and other things, yet
#   - combined with n-grams, they might tell you combinations of words that are more common than others, but still little about how they compare.
#   - so _by itself_ it's not useful for much more than assistance making stoplists.
#   - there's a [separate notebook that goes into its basics](methods_text_terms_tfidf.ipynb)
#
# - using any language parsing, you could look for patterns.
#   - the output may be clean, but it's unclear what one might miss
#   - a basic example follows below
#
# - **Collocation analysis** often refers to a probability-based "does this combination of words appears more often together than its parts would suggest?", which is still simple and works a little better.
#   - it might pick up "eigen gebruik", "echtgenoot of geregistreerde partner", "werk en inkomen naar arbeidsvermogen"
#   - ...but also just fragments that happen, well, because sentences have structure ("heeft gedaan", "verplichtingen uit"), or have been ripped from their context ("tijdstip zal", "KONING DER").
#   - so 'more common together' turns out to not be quite enough for clean output
#   - there's a [separate notebook that goes into its basics](methods_text_terms_collocations.ipynb)
#
# - topic modelling goes further, asking "what sets of words or phrases seem to join and disinguish documents in a set"
#   - this adds a goal that pushes down in that above list.
#   - there's a [separate notebook that goes into its basics](methods_text_topic_modeling.ipynb)

# %% [markdown]
# ## Spacy pattern matcher
#
# Notes:
# - you can express more complex types of patterns, see https://spacy.io/api/matcher#patterns
# - You could extend this to more complex tasks, like maybe rule-based phrase and named entity extraction.
#   - ...though you might base that on more specific existing code like PhraseMatcher and EntityRuler,
#     which may work faster and/or annotate automatically.
#   - and in the case of NER would probaly still be less effective than existing trained NER model components

# %%
import collections
#import spacy
import spacy.matcher

import wetsuite.datasets
import wetsuite.helpers.spacy
# Out:
# 2024-03-12 23:06:36.132682: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-12 23:06:38.319145: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-12 23:06:38.323409: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-12 23:06:38.323531: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
dutch  = spacy.load('nl_core_news_lg')

# Look for   one or more adjectives  before  a noun or proper noun.    
# A little too simple, yet does a useful thing already
an_pattern = [
    [ {"POS": "ADJ", "OP": "+"},   
      {"POS": {"IN":["NOUN","PROPN"]}} ],
    # you can have more rules in a matcher
]
matcher = spacy.matcher.Matcher(dutch.vocab)
matcher.add("adjective-noun", an_pattern)


count_ans = collections.defaultdict(int)

rvs = wetsuite.datasets.load('raadvanstate-adviezen-struc')
larger_rvs_advice = [] # 
for key, item in rvs.data.random_sample(2500):
    body = '\n'.join( item['body'] )
    doc = dutch( body )
    matches = matcher( doc )
    for match_id, start_i, end_i in matches:
        # we could mark and display them in an existing parse, but for now just count them
        #print( doc[ start_i : end_i ].text )
        count_ans[ doc[ start_i : end_i ].text ] += 1 

for str, count in sorted( count_ans.items(), key=lambda x:x[1], reverse=True):
    print( f'{count:5d}  {str}')
# Out:
#  5277  eerste lid
#  4366  tweede lid
#  2628  derde lid
#  2267  vierde lid
#  1519  vijfde lid
#  1340  Nader rapport
#  1128  redactionele kanttekeningen
#  1084  redactionele aard
#  1079  algemene maatregel
#  1056  uitsluitend opmerkingen
#   853  ministeriële regeling
#   814  zesde lid
#   650  Algemene wet
#   562  Gehele tekst
#   491  bestuurlijke boete
#   476  bevoegd gezag
#   462  Nederlandse Antillen
#   433  algemeen deel
#   408  redactionele kanttekening
#   361  hoger onderwijs
#   348  inhoudelijke opmerkingen
#   336  onderhavige wetsvoorstel
#   327  nadere regels
#   314  eerste plaats
#   314  algemeen belang
#   311  Burgerlijk Wetboek
#   311  andere wetten
#   295  nader rapport
#   290  zevende lid
#   286  wettelijke regeling
#   282  fysieke leefomgeving
#   281  strafbare feiten
#   275  openbare orde
#   273  Economische Zaken
#   263  Ruimtelijke Ordening
#   259  financieel toezicht
#   249  redactionele bijlage
#   244  openbare lichamen
#   243  decentrale overheden
#   242  overeenkomstige toepassing
#   239  hoger beroep
#   234  wettelijke grondslag
#   229  onroerende zaken
#   228  Redactionele bijlage
#   217  koninklijk besluit
#   217  achtste lid
#   212  Algemeen deel
#   207  Europese Gemeenschappen
#   203  nieuwe stelsel
#   203  algemene regels
#   195  administratieve lasten
#   193  korte termijn
#   192  andere lidstaten
#   192  openbaar bestuur
#   191  vrij verkeer
#   191  tweede volzin
#   186  persoonlijke levenssfeer
#   184  groot belang
#   180  onderhavige voorstel
#   179  primair onderwijs
#   179  ruimtelijke ordening
#   178  forensische zorg
#   171  redactionele opmerkingen
#   167  sociale zekerheid
#   167  andere lidstaat
#   166  openbaar ministerie
#   163  wetenschappelijk onderzoek
#   162  derde landen
#   161  groot aantal
#   160  Caribische landen
#   159  algemene zin
#   157  huidige situatie
#   153  huidige artikel
#   150  algemene maatregelen
#   146  financiële markten
#   141  interne markt
#   139  nieuwe artikel
#   137  speciaal onderwijs
#   133  natuurlijke personen
#   131  vrije verkeer
#   131  publieke omroep
#   129  financiële ondernemingen
#   129  ministeriële verantwoordelijkheid
#   128  andere landen
#   125  belangrijke mate
#   123  parlementaire behandeling
#   120  strafbaar feit
#   118  eerste instantie
#   118  nieuw artikel
#   116  fundamentele vrijheden
#   116  bijzondere omstandigheden
#   115  sociale partners
#   112  andere wijze
#   112  onderhavige besluit
#   111  lagere regelgeving
#   111  publieke gezondheid
#   111  gelijke behandeling
#   110  negende lid
#   110  tweede alinea
#   110  eerste volzin
#   110  nadere toelichting
#   110  voorwaardelijke invrijheidstelling
#   109  zelfstandige bestuursorganen
#   108  tweede plaats
#   107  Tijdelijke wet
#   107  andere wijzigingen
#   105  gespannen voet
#   104  langere termijn
#   102  dubbele belasting
#   101  groot deel
#   100  interbestuurlijke verhoudingen
#    99  voorschoolse educatie
#    99  vaste boekenprijs
#    98  belangrijke rol
#    97  Europese deel
#    94  Europees Verdrag
#    93  ministeriële regelingen
#    91  bestuurlijke boetes
#    89  wettelijke basis
#    89  nadere uitwerking
#    88  Nederlandse wetgeving
#    88  Redactionele kanttekeningen
#    88  Nederlandse taal
#    87  wettelijke voorschriften
#    86  financiële middelen
#    86  financiële sector
#    86  eerste alinea
#    86  onbepaalde tijd
#    86  burgerlijke stand
#    85  laatste alinea
#    85  strafrechtelijke handhaving
#    85  publieke middelen
#    85  Burgerlijke Rechtsvordering
#    84  Overige opmerkingen
#    84  nader onderzoek
#    84  economische delicten
#    84  terroristische misdrijven
#    84  rechtmatig verblijf
#    83  redactionele opmerking
#    83  maatschappelijke ondersteuning
#    82  Europese regelgeving
#    82  financiële onderneming
#    82  formele zin
#    82  financiële gevolgen
#    82  eigen bijdrage
#    81  algemene bepalingen
#    80  technische wijzigingen
#    80  wettelijk voorschrift
#    80  nadere motivering
#    80  zelfstandig bestuursorgaan
#    80  rechterlijke organisatie
#    79  wettelijke bepalingen
#    79  Caribisch Nederland
#    79  tweede lezing
#    79  Europese regels
#    78  parlementaire betrokkenheid
#    77  nieuwe regeling
#    76  vaste inrichting
#    76  redactionele verbeteringen
#    76  algemene regeling
#    76  andere maatregelen
#    76  eigen vermogen
#    75  openbaar lichaam
#    74  nationale veiligheid
#    74  minnelijk overleg
#    74  voorwaardelijke veroordeling
#    73  onderlinge samenhang
#    73  Tijdelijk besluit
#    73  economische groei
#    72  tweede tekstblok
#    72  huidige stelsel
#    72  eigen verantwoordelijkheid
#    71  nadelige gevolgen
#    71  tiende lid
#    71  onroerende zaak
#    71  algemeen bestuur
#    71  variabele beloning
#    70  laatste volzin
#    69  andere woorden
#    69  Nationale ombudsman
#    68  bevoegde autoriteiten
#    68  redelijke termijn
#    67  gevaarlijke stoffen
#    67  Turkse werknemers
#    67  lange termijn
#    66  openbaar vervoer
#    66  nadere invulling
#    66  justitiële gegevens
#    66  redactionele wijzigingen
#    66  eigen woning
#    65  oorspronkelijke wetsvoorstel
#    65  andere besluiten
#    65  nationale recht
#    65  bijzondere bijstand
#    64  goed bestuur
#    64  publieke taak
#    64  specifieke uitkering
#    63  Europese recht
#    63  voorlopige hechtenis
#    63  programmatische aanpak
#    62  wettelijk kader
#    62  voorlopige voorziening
#    62  huidige regeling
#    62  fiscale stelsel
#    62  wettelijke taken
#    61  openbare veiligheid
#    61  sociale verzekeringen
#    61  belangrijk deel
#    61  lokaal niveau
#    61  bijzonder onderwijs
#    60  verschillende onderdelen
#    60  elektronische weg
#    59  wederzijdse erkenning
#    59  fiscale maatregelen
#    59  onderhavige ontwerpbesluit
#    59  elektronisch berichtenverkeer
#    59  passief kiesrecht
#    59  biometrische kenmerken
#    58  nationale wetgeving
#    58  dergelijke gevallen
#    58  eerste aanleg
#    58  punitieve bestuursrecht
#    57  financiële risico
#    57  nationaal niveau
#    57  Europese richtlijnen
#    57  rechterlijke macht
#    57  nieuwe gemeente
#    57  bestuurlijke lus
#    56  derde alinea
#    56  administratieve aard
#    56  internationale bescherming
#    56  Caribische delen
#    56  representatieve democratie
#    55  procedurele waarborgen
#    55  artikelsgewijze toelichting
#    55  economisch belang
#    55  inkomensafhankelijke regelingen
#    54  Nederlandse Gemeenten
#    54  hoge mate
#    54  Europese Hof
#    54  openbare voorbereidingsprocedure
#    53  huidige praktijk
#    53  strafbare feit
#    53  bevoegde instantie
#    53  prudentiële regels
#    53  burgerlijke rechter
#    53  prudentieel toezicht
#    52  8) Kamerstukken
#    52  huidige wetgeving
#    52  Algemene Wet
#    52  rechterlijke ambtenaren
#    52  Eerste Protocol
#    52  andere vormen
#    52  provinciale staten
#    52  Vierde tranche
#    51  andere gevallen
#    51  financiële stelsel
#    51  democratische legitimatie
#    51  ernstige bezwaren
#    51  specifieke uitkeringen
#    51  uniforme openbare voorbereidingsprocedure
#    51  justitiële jeugdinrichtingen
#    51  bijzondere voorwaarde
#    51  illegaal verblijf
#    50  verdere behandeling
#    50  individuele gevallen
#    50  formele wet
#    50  technische aard
#    50  Nederlandse Vereniging
#    50  uitzonderlijke gevallen
#    50  Nationale Ombudsman
#    50  onderhavig wetsvoorstel
#    50  wettelijke verplichting
#    50  nationale regelgeving
#    50  bijzondere voorwaarden
#    50  buitenschoolse opvang
#    50  continue screening
#    49  ultimum remedium
#    49  Bijzondere Ziektekosten
#    49  Europees niveau
#    49  nationale parlementen
#    48  eerste tekstblok
#    48  politieke partijen
#    48  algemeen economisch belang
#    48  onmiddellijke werking
#    48  Tijdelijke regeling
#    48  gehele Koninkrijk
#    48  algemene deel
#    48  financiële instrumenten
#    48  financiële instellingen
#    48  educatieve module
#    47  bestuurlijke verhoudingen
#    47  veilige afstand
#    47  andere bepalingen
#    47  Economische Ruimte
#    47  Europese Economische Ruimte
#    47  nadere eisen
#    47  stedelijke vernieuwing
#    47  laag inkomen
#    46  ongelijke behandeling
#    46  huidige wet
#    46  concrete geval
#    46  nadere regeling
#    46  fiscale eenheid
#    45  Nederlandse samenleving
#    45  uitsluitend betrekking
#    45  korte tijd
#    45  wettelijke regelingen
#    45  Financiële Markten
#    45  dergelijke regeling
#    45  aanmerkelijk belang
#    44  administratiefrechtelijke handhaving
#    44  geruime tijd
#    44  andere overheden
#    44  internationale verplichtingen
#    44  Sociale Zaken
#    44  economische verkeer
#    44  gemeenschappelijke regelingen
#    44  nationale afkomst
#    44  landelijke doelstellingen
#    43  technische voorschriften
#    43  buitengewone omstandigheden
#    43  strafvorderlijke gegevens
#    43  natuurlijke persoon
#    43  concreet geval
#    43  laatste zin
#    43  Koninklijke machtiging
#    43  bevoegde autoriteit
#    43  vreemd vermogen
#    43  plaatsvervangend voorzitter
#    43  bilaterale verdrag
#    42  voldoende mate
#    42  dergelijke situatie
#    42  goede uitvoering
#    42  landelijk hoogspanningsnet
#    42  desbetreffende bepalingen
#    42  andere staat
#    42  algemene beginselen
#    42  centrale overheid
#    42  duurzame ontwikkeling
#    42  Nederlandse nationaliteit
#    41  laatste tekstblok
#    41  extra kosten
#    41  oudere werknemers
#    41  vierde alinea
#    41  maatschappelijke organisaties
#    41  grote spoed
#    41  andere onderdelen
#    41  oneigenlijk gebruik
#    41  huidige recht
#    41  maximale duur
#    41  openbaar belang
#    41  Nederlandse Gebarentaal
#    41  ambtelijke status
#    41  niet-Nederlandse ingezetenen
#    41  nieuwe opleiding
#    40  civiele rechter
#    40  publieke sector
#    40  fiscale behandeling
#    40  derde land
#    40  Nederlandse regering
#    40  huidige vorm
#    40  Nederlandse economie
#    40  regionale eenheden
#    39  grote schaal
#    39  bijzondere maatregelen
#    39  democratische controle
#    39  nieuwe wet
#    39  regionaal niveau
#    39  goed onderwijs
#    39  onderhavige nader rapport
#    39  technische verbeteringen
#    39  bijzondere persoonsgegevens
#    39  inhoudelijke wijzigingen
#    39  Europees verband
#    39  maatschappelijk belang
#    39  langdurige zorg
#    39  Openbaar Ministerie
#    39  later moment
#    39  bestuursrechtelijke handhaving
#    39  politieke ambtsdragers
#    39  selectieve woningtoewijzing
#    39  vierde tranche
#    39  sociale huurwoningen
#    39  algemene middelen
#    38  mogelijke gevolgen
#    38  bijzondere aandacht
#    38  Europese landen
#    38  Europees Nederland
#    38  verdere ontwikkeling
#    38  gecombineerde vergunning
#    38  oorspronkelijke voorstel
#    38  biometrische gegevens
#    38  private sector
#    38  openbare ruimte
#    38  primaire waterkeringen
#    38  derde volzin
#    38  huidige systeem
#    38  gemeenschappelijke regeling
#    38  bestuursrechtelijke premie
#    38  Penitentiaire beginselenwet
#    38  centrale eindtoets
#    38  extra heffing
#    37  dergelijk geval
#    37  eerste lezing
#    37  voldoende mogelijkheden
#    37  discretionaire bevoegdheid
#    37  Algemene Ouderdomswet
#    37  Redactionele opmerkingen
#    37  onderlinge verhouding
#    37  ander land
#    37  half jaar
#    37  wettelijke taak
#    37  derde tekstblok
#    37  private partijen
#    37  Koninklijke marechaussee
#    37  gemeentelijke herindeling
#    37  stedelijke regio's
#    37  variabele beloningen
#    37  vast dienstverband
#    36  langere tijd
#    36  nieuwe wetgeving
#    36  financiële positie
#    36  lange tijd
#    36  Nederlandse rechtsorde
#    36  bestuursrechtelijke bepalingen
#    36  verschillende artikelen
#    36  punitieve sancties
#    36  andere kant
#    36  ondergeschikte aard
#    36  terroristisch misdrijf
#    36  langdurig ingezetenen
#    36  gemeentelijke basisadministratie
#    36  democratische samenleving
#    36  bestuurlijke boeten
#    36  staatkundige hervorming
#    36  andere onderwerpen
#    36  reguliere procedure
#    36  elektronisch verkeer
#    36  justitiële documentatie
#    36  financiële crisis
#    36  vatbare beschikking
#    35  verschillende vormen
#    35  voldoende ruimte
#    35  grote verschillen
#    35  Nederlandse bevolking
#    35  specifieke bepalingen
#    35  diverse wetten
#    35  specifieke zorgplicht
#    35  eerbiedigende werking
#    35  overgrote deel
#    35  andere sectoren
#    35  Caribische deel
#    35  medisch-wetenschappelijk onderzoek
#    35  nieuw onderdeel
#    35  billijke vergoeding
#    35  educatieve minor
#    34  concrete gevallen
#    34  wettelijke regels
#    34  voldoende middelen
#    34  eerste zin
#    34  Gemeenschappelijk Hof
#    34  waarneembare persoonskenmerken
#    34  openbaar onderwijs
#    34  raadgevend referendum
#    34  onderhavig voorstel
#    34  wettelijke controles
#    34  goed verhuurderschap
#    33  nieuwe situatie
#    33  wettelijke grondslagen
#    33  Medische Zorg
#    33  fundamentele rechten
#    33  grote mate
#    33  andere staten
#    33  artikelsgewijze deel
#    33  lager niveau
#    33  nieuwe regels
#    33  technische wijziging
#    33  financiële belangen
#    33  bijzondere positie
#    33  indirect onderscheid
#    33  internationale verdragen
#    33  objectieve rechtvaardiging
#    33  bestuurlijke maatregel
#    33  seksuele handelingen
#    33  grote aantal
#    33  publieke belang
#    33  voorlopige aanslag
#    33  later tijdstip
#    33  andere partijen
#    33  publieke taken
#    33  dwingende redenen
#    33  penitentiair programma
#    32  democratische rechtsstaat
#    32  Voortgezet Onderwijs
#    32  Europeesrechtelijke aspecten
#    32  administratieve onteigeningsprocedure
#    32  verschillende maatregelen
#    32  bestuurlijke afwegingsruimte
#    32  nationaal recht
#    32  technische aanpassingen
#    32  vaste prijs
#    32  Overige fiscale maatregelen
#    32  dagelijks bestuur
#    32  openbaar gezag
#    32  ernstige misdrijven
#    32  Europese beroepskaart
#    32  negatieve gevolgen
#    32  tijdelijke regeling
#    31  vierde tekstblok
#    31  dergelijke bepaling
#    31  verschillende manieren
#    31  bijzondere situatie
#    31  Caribisch deel
#    31  vergelijk artikel
#    31  maatschappelijke ontwikkelingen
#    31  politieke rechten
#    31  bijzondere regeling
#    31  zekere mate
#    31  nationale rechter
#    31  interbestuurlijk toezicht
#    31  nadere regelgeving
#    31  nieuwe landen
#    31  bestuurlijke drukte
#    31  extra ondersteuning
#    31  private risicodeling
#    31  herziene Procedurerichtlijn
#    31  tijdsevenredige BPM
#    30  brede zin
#    30  landelijk niveau
#    30  decentraal niveau
#    30  eerste fase
#    30  andere belangen
#    30  Franse Republiek
#    30  Overige wijzigingen
#    30  eerste jaar
#    30  sociale voorzieningen
#    30  gelijkwaardig beschermingsniveau
#    30  persoonsgebonden aftrek
#    30  juiste wijze
#    30  vaste beloning
#    30  laatste jaren
#    29  zorgvuldige afweging
#    29  andere instrumenten
#    29  wezenlijk belang
#    29  andere terreinen
#    29  later stadium
#    29  nationale regels
#    29  verschillende soorten
#    29  huidig recht
#    29  Vergelijk artikel
#    29  Uitvoeringsinstituut werknemersverzekeringen
#    29  wederzijdse bijstand
#    29  publieke mediaopdracht
#    29  pensioengerechtigde leeftijd
#    29  onderhavige geval
#    29  andere instanties
#    29  andere personen
#    29  vorige eeuw
#    29  staatkundige verhoudingen
#    29  crimineel gedrag
#    29  wettelijke verankering
#    29  elektronische handel
#    29  eerste ziektejaar
#    29  problematische schulden
#    29  bovenwettelijke uitkeringen
#    28  nieuwe systeem
#    28  specifieke maatregelen
#    28  tijdelijke wet
#    28  specifieke regels
#    28  grote lijnen
#    28  bijzondere karakter
#    28  bevoegde instanties
#    28  andere regels
#    28  afzonderlijk wetsvoorstel
#    28  bijzonder aandacht
#    28  eerste stap
#    28  Bestuurlijke Vernieuwing
#    28  wettelijke rente
#    28  financiële consequenties
#    28  vrijwillige basis
#    28  andere taken
#    28  andere manier
#    28  middellange termijn
#    28  particuliere sector
#    28  binnenlands bestuur
#    28  buitengewoon pensioen
#    27  huidige tekst
#    27  eerdere adviezen
#    27  periodieke beschouwing
#    27  bijzondere gevallen
#    27  Europese verplichtingen
#    27  technologische ontwikkelingen
#    27  algemene rechtspositie
#    27  nuttig effect
#    27  materiële normen
#    27  internationaal recht
#    27  territoriale wateren
#    27  wettelijke bepaling
#    27  verschillende bepalingen
#    27  bestuurlijke strafbeschikking
#    27  lichamelijk letsel
#    27  bijzondere kenmerken
#    27  preventief toezicht
#    27  elfde lid
#    27  correctief referendum
#    27  nieuwe scholen
#    27  digitale infrastructuur
#    27  dubbele naam
#    27  betaalbare woningen
#    27  seksuele intimidatie
#    26  Nederlandse wetgever
#    26  onderhavige wijziging
#    26  bijzondere wetten
#    26  korte periode
#    26  Interbestuurlijke Verhoudingen
#    26  gemeenschappelijke regels
#    26  strafrechtelijke gegevens
#    26  redelijke verhouding
#    26  dierlijke mest
#    26  strafrechtelijke sancties
#    26  publieke belangen
#    26  verschillende aspecten
#    26  terroristische organisatie
#    26  civiele recht
#    26  vroeg stadium
#    26  nieuwe systematiek
#    26  vaste commissie
#    26  gemeentelijk niveau
#    26  uniforme regeling
#    26  positief effect
#    26  prejudiciële vragen
#    26  nodige maatregelen
#    26  nadere voorschriften
#    26  grootstedelijke problematiek
#    26  objectief verdeelmodel
#    26  certificerende instelling
#    26  nadere beschouwing
#    26  sociaal leenstelsel
#    26  redelijke prijs
#    26  periodieke uitkeringen
#    26  meertalige dagopvang
#    26  democratische inbedding
#    25  bijzondere reden
#    25  nadere overweging
#    25  wettelijk minimumloon
#    25  extra middelen
#    25  centraal niveau
#    25  rechtstreekse werking
#    25  laatste geval
#    25  Nederlandse Orde
#    25  sterke mate
#    25  nader aandacht
#    25  parlementaire geschiedenis
#    25  nieuwe artikelen
#    25  commerciële activiteiten
#    25  behoorlijk bestuur
#    25  Nederlands recht
#    25  specifieke zorgplichten
#    25  huidige Wet
#    25  verschillende situaties
#    25  voorlopig verblijf
#    25  rechterlijke toetsing
#    25  provinciaal belang
#    25  nationaal belang
#    25  beschikbare middelen
#    25  andere redenen
#    25  aanzienlijk deel
#    25  ernstige bedreiging
#    25  andere partij
#    25  zwaar lichamelijk letsel
#    25  fiscale wetgeving
#    25  strafrechtelijke titel
#    25  andere categorieën
#    25  flexibele contracten
#    25  uniforme beginselen
#    25  aanmerkelijk belangheffing
#    25  inframarginale elektriciteitsheffing
#    24  bestuurlijke lasten
#    24  openbare dienst
#    24  inhoudelijke wijziging
#    24  verantwoordelijke minister
#    24  wettelijk stelsel
#    24  eigen beweging
#    24  zekere hoogte
#    24  nieuwe maatregelen
#    24  andere activiteiten
#    24  strafrechtelijk onderzoek
#    24  algemene strekking
#    24  elektronische communicatie
#    24  nieuwe Mediawet
#    24  Europese richtlijn
#    24  nieuwe opzet
#    24  elektronische communicatienetwerken
#    24  individuele gemeenten
#    24  overige bepalingen
#    24  nieuwe pensioenstelsel
#    24  specifieke omstandigheden
#    24  Nederlandse recht
#    24  alfabetische volgorde
#    24  maatschappelijke doelen
#    24  externe veiligheid
#    24  individuele gezondheidszorg
#    24  vijfde alinea
#    24  directe beleggingen
#    24  andere bestuursorganen
#    24  onderlinge afstemming
#    24  ongestoord genot
#    24  preventieve maatregelen
#    24  integraal veiligheidsplan
#    24  geestelijke gezondheidszorg
#    24  preventieve werking
#    24  goede werking
#    24  bijzondere scholen
#    24  vrijwillige verzekering
#    24  extraterritoriale rechtsmacht
#    24  strategische adviesraden
#    24  provinciaal medebewind
#    23  derde plaats
#    23  andere groepen
#    23  nieuwe paragraaf
#    23  concrete maatregelen
#    23  uitzonderlijke situaties
#    23  afzienbare tijd
#    23  integrale aanpak
#    23  Code Interbestuurlijke Verhoudingen
#    23  Europees parlement
#    23  overige onderdelen
#    23  gereglementeerde markt
#    23  rechterlijke uitspraak
#    23  eerste dag
#    23  belangrijk onderdeel
#    23  kleine pensioenen
#    23  economische activiteit
#    23  administratieve detentie
#    23  bijzondere bevoegdheden
#    23  redelijk vermoeden
#    23  algemene zorgplicht
#    23  hoog niveau
#    23  negatieve effecten
#    23  Europees Hof
#    23  derde categorie
#    23  eigen initiatief
#    23  nieuw tweede lid
#    23  individueel geval
#    23  regionale samenwerking
#    23  late implementatie
#    23  Vierde Protocol
#    23  financiële problemen
#    23  gemeentelijke schuldhulpverlening
#    23  flankerend beleid
#    23  Gevolmachtigde Ministers
#    23  Centrale Bank
#    23  semipublieke sector
#    23  financiële prikkels
#    23  bestuurlijke afspraken
#    23  incidenteel hoger beroep
#    22  bilaterale verdragen
#    22  verschillende categorieën
#    22  hoge eisen
#    22  fysieke domein
#    22  vergelijkbare bepaling
#    22  bestuurlijke maatregelen
#    22  provinciale weg
#    22  andere factoren
#    22  nadere voorwaarden
#    22  onderlinge aanpassing
#    22  tweede zin
#    22  bijbehorende toelichting
#    22  Europees recht
#    22  herziene richtlijn
#    22  huidige regelgeving
#    22  andere vorm
#    22  wettelijke verplichtingen
#    22  oude recht
#    22  bancaire sector
#    22  algemeen overleg
#    22  dubbele strafbaarheid
#    22  lichamelijke integriteit
#    22  ruime uitleg
#    22  nieuwe grondslag
#    22  wetstechnische gebreken
#    22  andere handelingen
#    22  feitelijke situatie
#    22  internationaalrechtelijke verplichtingen
#    22  beschikbare technieken
#    22  punitieve sanctie
#    22  nationale maatregelen
#    22  mogelijke termijn
#    22  geneeskundige behandelingsovereenkomst
#    22  Algemene bijstandswet
#    22  academische ziekenhuizen
#    22  gedeeltelijk arbeidsongeschikte
#    22  gerechtelijke procedure
#    22  tijdelijke aard
#    22  vast contract
#    22  Europese Centrale Bank
#    22  structurele hervormingen
#    22  bestuurlijke structuur
#    22  generieke digitale infrastructuur
#    22  digitale overheid
#    22  Europees aanhoudingsbevel
#    22  buitenlands kenteken
#    22  Nederlandse volk
#    21  algemeen verbod
#    21  zodanige wijze
#    21  verschillende wetten
#    21  burgerlijk gezag
#    21  administratief beroep
#    21  specifieke situatie
#    21  limitatieve opsomming
#    21  oorspronkelijke artikel
#    21  andere echtgenoot
#    21  wettelijke kaders
#    21  gelijke wijze
#    21  gedeeltelijke goedkeuring
#    21  zorgvuldige wijze
#    21  intern toezicht
#    21  noodzakelijke aanpassingen
#    21  economische activiteiten
#    21  koninklijke boodschap
#    21  inhoudelijke eisen
#    21  centrale rol
#    21  witte vlek
#    21  legitiem doel
#    21  onaanvaardbare risico
#    21  ongewoon voorval
#    21  diverse plaatsen
#    21  hoge kosten
#    21  algemene uitkering
#    21  verschillende landen
#    21  andere organisaties
#    21  reguliere voorbereidingsprocedure
#    21  nationale wetgever
#    21  dringende noodzaak
#    21  economische ontwikkeling
#    21  eigen vennootschap
#    21  Sociale Verzekeringsbank
#    21  medische hulpmiddelen
#    21  Fiscale verzamelwet
#    21  territoriale zee
#    21  internationale recht
#    21  open normen
#    21  Nederlandse arbeidsmarkt
#    21  fiscaal stelsel
#    21  langere periode
#    21  natuurlijk persoon
#    21  slimme meters
#    21  persoonsgebonden budget
#    21  vroegschoolse educatie
#    21  wederzijdse rechtshulp
#    21  mondelinge behandeling
#    21  digitale handhaving
#    21  Nationale Politie
#    21  parlementaire enquête
#    21  bestuurlijk verkeer
#    21  buitenlandse prostituées
#    21  Caribisch gebied
#    21  fijn stof
#    21  extra verhoging
#    21  vrije vestiging
#    20  vaste inrichtingen
#    20  politieke besluitvorming
#    20  Europees verdrag
#    20  adequate wijze
#    20  kwetsbare groepen
#    20  sociaal akkoord
#    20  extra waarborgen
#    20  juridische zin
#    20  nationale rechtsorde
#    20  algemene wet
#    20  parlementaire goedkeuring
#    20  eigen middelen
#    20  inhoudelijke motivering
#    20  tijdige implementatie
#    20  goed pensioenfondsbestuur
#    20  terroristische activiteiten
#    20  Nederlandse markt
#    20  Europese verordening
#    20  eerste vraag
#    20  biologische diversiteit
#    20  nadere aandacht
#    20  financiële situatie
#    20  tijdelijk karakter
#    20  strafrechtelijke vervolging
#    20  algemene rijksregels
#    20  seksueel misbruik
#    20  strafrechtelijke aansprakelijkheid
#    20  gelijk speelveld
#    20  persoonsgebonden aftrekposten
#    20  redelijke grond
#    20  praktische redenen
#    20  integrale afweging
#    20  hypothecair krediet
#    20  financiële diensten
#    20  Nederlandse rechter
#    20  nadere uitleg
#    20  andere EU-lidstaat
#    20  andere artikelen
#    20  Europese jurisprudentie
#    20  ernstige schade
#    20  naamloze vennootschappen
#    20  algemene vergadering
#    20  algemene bepaling
#    20  wettelijke kader
#    20  decentrale overheid
#    20  nieuwe ontwikkelingen
#    20  individuele bijzondere bijstand
#    20  algemene toelichting
#    20  strengere eisen
#    20  derde rijbewijsrichtlijn
#    20  forensische patiënten
#    20  beslagvrije voet
#    20  uiterlijk waarneembare persoonskenmerken
#    20  tweede fase
#    20  tijdelijke contracten
#    20  publiekrechtelijke zorgplicht
#    20  volkenrechtelijke organisatie
#    20  bijzondere bepalingen
#    20  persoonsgebonden nummer
#    20  effectieve handhaving
#    20  eenmalige energietoeslag
#    20  chronische ziekte
#    20  integrale geschilbeslechting
#    20  regionale college
#    20  dierlijke producten
#    20  vierde anti-witwasrichtlijn
#    20  meertalige kinderopvang
#    20  institutionele capaciteit
#    19  ministeriele regeling
#    19  nationaal beleid
#    19  maatschappelijk draagvlak
#    19  specifieke bevoegdheden
#    19  verschillende redenen
#    19  onvoorziene omstandigheden
#    19  buitengewone bevoegdheden
#    19  parlementaire controle
#    19  bredere zin
#    19  huidige systematiek
#    19  lokale omstandigheden
#    19  ongevraagd advies
#    19  nieuwe richtlijn
#    19  afzienbare termijn
#    19  andere Europese landen
#    19  uiteenlopende aard
#    19  eerste gezicht
#    19  andere vormgeving
#    19  Overige overwegingen
#    19  andere regelingen
#    19  aanhangige wetsvoorstel
#    19  verschillende plaatsen
#    19  nadelige effecten
#    19  Nederlandse overheid
#    19  mogelijk duidelijkheid
#    19  nadere uiteenzetting
#    19  provinciaal niveau
#    19  nieuwe onderdeel
#    19  grote steden
#    19  fiscale subsidies
#    19  maatschappelijke beleggingen
#    19  financiële dienstverlening
#    19  bijzondere gegevens
#    19  zelfstandige betekenis
#    19  grote afstand
#    19  nadere onderbouwing
#    19  ’n geval
#    19  andere school
#    19  kort mogelijke termijn
#    19  Turkse onderdanen
#    19  fundamenteel belang
#    19  Internationaal Verdrag
#    19  economische situatie
#    19  nieuwe inzichten
#    19  modern migratiebeleid
#    19  andere EU-lidstaten
#    19  eigen onderdanen
#    19  voldoende reden
#    19  lokale situatie
#    19  executoriale titel
#    19  bestuursrechtelijke rechtsbescherming
#    19  onrechtmatige daad
#    19  gedetacheerde werknemers
#    19  belastbare loon
#    19  collectieve uitgaven
#    19  rechtstreekse gemeenten
#    19  regionale eenheid
#    19  bijzondere zorgplicht
#    19  betrokken partijen
#    19  financiële zekerheid
#    19  gemeentelijk beleid
#    19  ongewenst gedrag
#    19  regionaal bestuur
#    19  maatschappelijke onderneming
#    19  Eenzijdige regeling
#    19  rechtstreekse verstrekking
#    19  financiële overzichten
#    19  dierlijke meststoffen
#    19  bestuursrechtelijke dwangsommen
#    19  professioneel statuut
#    18  Europese verordeningen
#    18  vergelijkbare wijze
#    18  relevante bepalingen
#    18  wettelijke bevoegdheden
#    18  ernstige vrees
#    18  staatsrechtelijke positie
#    18  lokaal maatwerk
#    18  specifieke gevallen
#    18  Algemene verordening
#    18  diverse besluiten
#    18  ontwerp-algemene maatregel
#    18  andere regelgeving
#    18  specifieke regeling
#    18  Friese taal
#    18  inhoudelijke beoordeling
#    18  tweede vraag
#    18  Nederlandse staatsbestel
#    18  huidige kabinet
#    18  grote aantallen
#    18  tweede pijler
#    18  derde pijler
#    18  publiekrechtelijke regeling
#    18  Nederlandse Mededingingsautoriteit
#    18  directe relatie
#    18  ernstige delicten
#    18  volledige implementatie
#    18  publiek belang
#    18  verdere uitwerking
#    18  financiële aspecten
#    18  groter aantal
#    18  goede reden
#    18  internationaal verband
#    18  verschillende regimes
#    18  Nederlandse identiteitskaart
#    18  verschillende lidstaten
#    18  privaatrechtelijke rechtspersoon
#    18  voorlaatste alinea
#    18  ernstig gevaar
#    18  algemene regel
#    18  Europese besluitvorming
#    18  wettelijke vereisten
#    18  ander bestuursorgaan
#    18  nationale regeling
#    18  internationale regels
#    18  betere aansluiting
#    18  nabije toekomst
#    18  onderlinge regeling
#    18  internationale regelingen
#    18  individuele beoordeling
#    18  dergelijke bevoegdheid
#    18  onderhavige verdrag
#    18  eventuele gevolgen
#    18  stedelijke gebieden
#    18  gevaarlijke afvalstoffen
#    18  nominale premie
#    18  grote betekenis
#    18  seksueel contact
#    18  maximale termijn
#    18  eigen risico
#    18  Internationaal verdrag
#    18  openbare karakter
#    18  nieuw besluit
#    18  Sociaal-Economische Raad
#    18  onderling overleg
#    18  tijdelijke bepalingen
#    18  authentieke gegevens
#    18  definitieve regeling
#    18  Nederlandse werknemers
#    18  financiële stabiliteit
#    18  ruime reikwijdte
#    18  financiële fragmentatie
#    18  staatkundige structuur
#    18  korte duur
#    18  reële afspiegeling
#    18  levenslange gevangenisstraf
#    18  fiscale regelingen
#    18  eigen bijdragen
#    18  strategische advisering
#    18  maatschappelijke partijen
#    18  algemene identificatieplicht
#    18  langdurige arbeidsongeschiktheid
#    17  bredere context
#    17  sociale werkvoorziening
#    17  kortere termijn
#    17  uitzonderlijke omstandigheden
#    17  bestuurlijke organisatie
#    17  belangrijk uitgangspunt
#    17  andere wet
#    17  volle breedte
#    17  juridische status
#    17  redactionele wijziging
#    17  toegevoegde waarde
#    17  parlementair stelsel
#    17  dergelijke verdragen
#    17  nadere informatie
#    17  administratieve bijstand
#    17  bijzonder artikel
#    17  desbetreffende bepaling
#    17  commerciële omroepen
#    17  commerciële omroep
#    17  praktische problemen
#    17  bestuurlijk overleg
#    17  eerste voorlichtingsvraag
#    17  onderlinge verhoudingen
#    17  duurzaam gebruik
#    17  juridische procedures
#    17  vaste rechtspraak
#    17  lage inkomens
#    17  voldoende waarborgen
#    17  belangrijke bijdrage
#    17  verschillende belangen
#    17  afzonderlijke regeling
#    17  aanmerkelijke marktmacht
#    17  goed begrip
#    17  grote belang
#    17  voldoende tijd
#    17  brede doeluitkering
#    17  landelijk gebied
#    17  budgettaire gevolgen
#    17  vaste jurisprudentie
#    17  Nederlandse Zorgautoriteit
#    17  huidige stand
#    17  andere status
#    17  dergelijke beperking
#    17  inhoudelijke opmerking
#    17  bijzondere vorm
#    17  actieve rol
#    17  Europese Raad
#    17  rechterlijke instanties
#    17  fiscale pakket
#    17  Nederlandse stelsel
#    17  provinciale verordening
#    17  feitelijke beschrijving
#    17  verschillende onderwerpen
#    17  belangrijke onderdelen
#    17  gehele grondgebied
#    17  twaalfde lid
#    17  internationaal privaatrecht
#    17  nieuwe vormen
#    17  Europese afvalstoffenlijst
#    17  Kaderrichtlijn afvalstoffen
#    17  andere algemene maatregelen
#    17  internationale ontwikkelingen
#    17  strafrechtelijke sanctie
#    17  Algemene nabestaandenwet
#    17  eerste keer
#    17  voorwaardelijke invrijheidsstelling
#    17  budgettaire opbrengst
#    17  werkloze werknemers
#    17  internationale samenwerking
#    17  overeenkomstige wijze
#    17  suppletoire begroting
#    17  elektronische handtekening
#    17  nieuwe procedure
#    17  publieke domein
#    17  collectieve voorzieningen
#    17  algemene heffingskorting
#    17  afzonderlijke landen
#    17  lagere regeling
#    17  exclusieve bevoegdheid
#    17  bevoegde gezagsorganen
#    17  publieke risicodeling
#    17  eerste jaren
#    17  budgettair belang
#    17  stedelijke regio
#    17  goed gevolg
#    17  marginale druk
#    17  Europese spoorwegruimte
#    17  emissieloze voertuigen
#    17  extern klachtrecht
#    17  algemene onderwijswet
#    17  gemeenschappelijke beginselen
#    17  punitieve handhaving
#    16  dergelijke aanwijzing
#    16  grootste deel
#    16  Algemene douanewet
#    16  ander doel
#    16  bijzondere opsporingsdiensten
#    16  metrologische eisen
#    16  aanbestedende diensten
#    16  wettelijke eisen
#    16  concrete situatie
#    16  bestuurlijke praktijk
#    16  zekere zin
#    16  privaatrechtelijke rechtshandelingen
#    16  grondrechtelijke aspecten
#    16  onvoldoende rekening
#    16  specifieke deskundigheid
#    16  onwenselijke situatie
#    16  uitdrukkelijke goedkeuring
#    16  gering aantal
#    16  eerste kanttekening
#    16  tweede wijziging
#    16  administratieve samenwerking
#    16  verschillende instanties
#    16  tweede onderdeel
#    16  laatste instantie
#    16  tweede voorlichtingsvraag
#    16  dergelijk onderzoek
#    16  reëel risico
#    16  tweede helft
#    16  wettelijke maatregelen
#    16  eerste maal
#    16  Europese mededingingsrecht
#    16  financieel toetsingskader
#    16  extra belasting
#    16  eerder stadium
#    16  dergelijke verplichting
#    16  verschillende tijdstippen
#    16  persoonlijke vrijheid
#    16  nieuw lid
#    16  nieuwe regime
#    16  belangrijk instrument
#    16  bestuurlijke handhaving
#    16  Penitentiaire maatregel
#    16  basisregistratie personen
#    16  gemeentelijke verordening
#    16  belastbare inkomen
#    16  eenvoudige wijze
#    16  gegronde redenen
#    16  medische gegevens
#    16  dergelijk besluit
#    16  algemene voorwaarden
#    16  nieuwe lidstaten
#    16  economische belangen
#    16  andere mogelijkheden
#    16  onafhankelijke positie
#    16  verschillende niveaus
#    16  ander voorbeeld
#    16  beste beschikbare technieken
#    16  goede redenen
#    16  zakelijke rechten
#    16  criminele activiteiten
#    16  bijzondere spoorwegen
#    16  nadere duiding
#    16  bijzondere regels
#    16  Europese wetgeving
#    16  goede balans
#    16  particuliere projecten
#    16  andere gegevens
#    16  psychiatrisch ziekenhuis
#    16  financiële ondersteuning
#    16  akoestisch onderzoek
#    16  andere omstandigheden
#    16  specifieke eisen
#    16  aanzuigende werking
#    16  beschikbare capaciteit
#    16  militair ambtenarenreglement
#    16  Algemeen militair ambtenarenreglement
#    16  openbare weg
#    16  liquide middelen
#    16  minderjarige kinderen
#    16  benodigde informatie
#    16  eigen rechtspersoonlijkheid
#    16  insulaire karakter
#    16  andere gemeenten
#    16  toenmalige Minister
#    16  strafrechtelijke veroordeling
#    16  andere wetgeving
#    16  eerste toelating
#    16  administratieve lastenverlichting
#    16  zieke werknemer
#    16  bestuurlijke inrichting
#    16  territoriale onderdelen
#    16  tijdelijke karakter
#    16  onvoldoende reden
#    16  openbare scholen
#    16  monetaire unie
#    16  actief kiesrecht
#    16  buitenlandse betrekkingen
#    16  uiterste geval
#    16  andere middelen
#    16  duaal stelsel
#    16  dubbele heffing
#    16  AOW-gerechtigde leeftijd
#    16  totale hoeveelheid
#    16  andere instellingen
#    16  hoger beroepsonderwijs
#    16  regionale beleidsplan
#    16  duurzame inzetbaarheid
#    16  bestuursrechtelijke regiem
#    16  nieuwe raad
#    16  tijdelijke onderwijsvoorziening
#    16  milieugevaarlijke stoffen
#    16  sectorale toezichtswetten
#    16  generieke strafbaarstelling
#    16  seksuele misdrijven
#    16  seksuele integriteit
#    16  medische kinderdagverblijven
#    15  wettelijke controle
#    15  technische specificaties
#    15  strengere voorschriften
#    15  technische eisen
#    15  totaal aantal
#    15  extra banen
#    15  generieke maatregelen
#    15  huidige tijd
#    15  verschillende momenten
#    15  andere situaties
#    15  andere situatie
#    15  formele wetgever
#    15  strikte voorwaarden
#    15  algemene uitgangspunten
#    15  dergelijke situaties
#    15  openbare school
#    15  hogere kosten
#    15  eerste redactionele kanttekening
#    15  blanco adviezen
#    15  derde dinsdag
#    15  nieuwe aanvraag
#    15  individuele omstandigheden
#    15  overeenkomstig artikel
#    15  tweede opmerking
#    15  bovengenoemde punten
#    15  financiële verantwoording
#    15  Nederlandse situatie
#    15  dergelijke voorziening
#    15  Unierechtelijke aspecten
#    15  wettelijk niveau
#    15  financiële producten
#    15  ander deel
#    15  kleine groep
#    15  direct verband
#    15  flexibel hoger onderwijs
#    15  noodzakelijke voorwaarde
#    15  afzonderlijk artikel
#    15  verschillende instrumenten
#    15  internationale regelgeving
#    15  elektronisch communicatienetwerk
#    15  extra aandacht
#    15  verschillende bestuursorganen
#    15  dergelijk verzoek
#    15  Staatkundige hervorming
#    15  verdere stappen
#    15  eerdere advies
#    15  andere doelstellingen
#    15  doeltreffende wijze
#    15  specifieke taken
#    15  industriële emissies
#    15  diverse punten
#    15  belangrijk verschil
#    15  financiële verantwoordelijkheid
#    15  huidige artikelen
#    15  effectieve aanpak
#    15  positieve effecten
#    15  voorwaardelijke beëindiging
#    15  desbetreffende artikelen
#    15  Nationale Schuld
#    15  algemene verplichting
#    15  voldoende ernstige bedreiging
#    15  sociaal minimum
#    15  huidige Besluit
#    15  financiële verslaggeving
#    15  Nederlandse regelgeving
#    15  huidige regime
#    15  individuele geval
#    15  specifieke categorieën
#    15  vijfde tekstblok
#    15  gemeentelijke verantwoordelijkheid
#    15  nieuwe tweede lid
#    15  blauwe kaart
#    15  financiële verhouding
#    15  internationale organisaties
#    15  noodzakelijke zorg
#    15  bovenvermelde voorstel
#    15  feitelijk arbeidsverleden
#    15  technische aanpassing
#    15  zwaardere eisen
#    15  belastbaar loon
#    15  vaste dienst
#    15  structureel €
#    15  schadelijke gevolgen
#    15  speciaal basisonderwijs
#    15  zelfstandige leesbaarheid
#    15  goede orde
#    15  algemene termen
#    15  nieuwe opleidingen
#    15  duurzame energie
#    15  vrije ruimte
#    15  inkomensafhankelijke bijdrage
#    15  fiscale neutraliteit
#    15  desbetreffende artikel
#    15  radioactieve stoffen
#    15  elektronisch bestuurlijk verkeer
#    15  dertiende lid
#    15  verdere verwerking
#    15  oud artikel
#    15  minnelijke overleg
#    15  medisch onderzoek
#    15  fiscale recht
#    15  tijdelijke verlaging
#    15  ernstige criminaliteit
#    14  ondergeschikte punten
#    14  huidige formulering
#    14  grotere rol
#    14  verschillende typen
#    14  andere aard
#    14  tweede categorie
#    14  juridische grondslag
#    14  belangrijke reden
#    14  discretionaire ruimte
#    14  lokaal bestuur
#    14  nieuwe bevoegdheid
#    14  universele postdienst
#    14  andere werkzaamheden
#    14  regionale politiekorpsen
#    14  nauwere samenwerking
#    14  strafrechtelijke procedure
#    14  huidige Mediawet
#    14  landelijke publieke omroep
#    14  nieuwe structuur
#    14  eerste onderdeel
#    14  naburige rechten
#    14  elektronische dienstverlening
#    14  derde vraag
#    14  noodzakelijke wijzigingen
#    14  verschillende groepen
#    14  oudere belastingplichtigen
#    14  organisatorische eenheid
#    14  vertegenwoordigende organen
#    14  principiële bezwaren
#    14  integraal onderdeel
#    14  mogelijk stadium
#    14  financiële verhoudingen
#    14  universele dienstverlening
#    14  grote verscheidenheid
#    14  gemeentelijke verordeningen
#    14  langer sprake
#    14  duidelijk onderscheid
#    14  economisch beleid
#    14  andere aspecten
#    14  nieuw wetsvoorstel
#    14  cultureel erfgoed
#    14  negatief effect
#    14  generieke toezicht
#    14  Europeesrechtelijke verplichtingen
#    14  rechtstreeks beroep
#    14  periodieke evaluatie
#    14  overige leden
#    14  tweede geval
#    14  betere afstemming
#    14  recente ontwikkelingen
#    14  vreemde staat
#    14  duurzame energieproductie
#    14  wederzijdse administratieve bijstand
#    14  directe belastingen
#    14  persoonlijke omstandigheden
#    14  desbetreffende persoon
#    14  voorwaardelijke straf
#    14  Overige aanpassingen
#    14  vorig jaar
#    14  buitenlandse belastingplichtigen
#    14  gerechtvaardigde belangen
#    14  elektronische voorzieningen
#    14  concrete omstandigheden
#    14  andere rechtsgebieden
#    14  werkzame personen
#    14  Europese blauwe kaart
#    14  dergelijke procedure
#    14  vertrouwelijke communicatie
#    14  nieuwe bevoegdheden
#    14  bevoegde rechter
#    14  onderlinge waarborgmaatschappij
#    14  financiële steun
#    14  vaste contracten
#    14  burgerlijke zaken
#    14  financiële bijdrage
#    14  Nederlandse openbare orde
#    14  wettelijke bevoegdheid
#    14  particuliere beveiligers
#    14  wettelijk recht
#    14  Nederlands belang
#    14  eerdere veroordeling
#    14  volledige rechtsbevoegdheid
#    14  bijzondere wet
#    14  bijzondere gedelegeerden
#    14  democratisch deficit
#    14  relevante informatie
#    14  nieuwe taak
#    14  vorige voorlichting
#    14  horizontale verantwoording
#    14  bouwtechnische voorschriften
#    14  vorige kabinet
#    14  nieuwe Wet
#    14  zwakke scholen
#    14  gerechtelijk vooronderzoek
#    14  landelijke politiediensten
#    14  ernstige tekortkomingen
#    14  academisch ziekenhuis
#    14  ruimtelijke belangen
#    14  lokale binding
#    14  temporele voorwaarde
#    14  niet-essentiële detailhandel
#    14  nationale politie
#    14  zakelijk samenwerkingsverband
#    14  Technische Herzieningsrichtlijn
#    14  nationale procedure
#    14  hoge boetes
#    14  buitengerechtelijke afdoening
#    13  algemene grondslag
#    13  sociale veiligheid
#    13  huidige voorstel
#    13  metrologische controle
#    13  essentieel onderdeel
#    13  verschillende beleidsterreinen
#    13  goede afstemming
#    13  algemene noodtoestand
#    13  separate toepassing
#    13  andere ministers
#    13  specifieke geval
#    13  vitale infrastructuur
#    13  verschillende rollen
#    13  duidelijke keuze
#    13  acute zorg
#    13  dwingende reden
#    13  eerste opmerking
#    13  verdere versterking
#    13  nadere analyse
#    13  evenwichtige verdeling
#    13  zorgvuldige besluitvorming
#    13  relevante aspecten
#    13  voorlopige toepassing
#    13  Sociale verzekeringsbank
#    13  nieuwe vierde lid
#    13  grove schuld
#    13  daadwerkelijk sprake
#    13  kleine wijzigingen
#    13  publieke media-instellingen
#    13  ruimere mogelijkheden
#    13  andere regeling
#    13  tijdelijk verbod
#    13  ruime mate
#    13  parlementaire stelsel
#    13  ernstige overtredingen
#    13  laatste categorie
#    13  flexibele premieregeling
#    13  flexibele premieovereenkomst
#    13  andere maatregel
#    13  specifieke kenmerken
#    13  nadere bepalingen
#    13  belangrijkste reden
#    13  verschillende partijen
#    13  nieuwe norm
#    13  redelijke vergoeding
#    13  onderhavig besluit
#    13  huidige bepalingen
#    13  concrete aanwijzingen
#    13  rechterlijke instantie
#    13  eerste ronde
#    13  nieuw derde lid
#    13  zware ongevallen
#    13  onevenredige gevolgen
#    13  huidige niveau
#    13  grotere mate
#    13  nieuwe nummering
#    13  ander karakter
#    13  vroeg mogelijk stadium
#    13  wettelijke strafmaxima
#    13  diverse bepalingen
#    13  overige werkzaamheden
#    13  andere weg
#    13  nauwe band
#    13  klein deel
#    13  wettelijke stelsel
#    13  rechterlijke uitspraken
#    13  nieuwe bepaling
#    13  eigen land
#    13  ambtelijke organisatie
#    13  diverse maatregelen
#    13  hoger inkomen
#    13  juridische basis
#    13  relevante onderdelen
#    13  toekomstige ontwikkelingen
#    13  essentiële onderdelen
#    13  nationale programma
#    13  nationale belangen
#    13  sectorale wetten
#    13  dagelijkse praktijk
#    13  dergelijke regels
#    13  andere gronden
#    13  lokale autonomie
#    13  landelijke voorziening
#    13  zorgvuldige voorbereiding
#    13  administratieve verplichtingen
#    13  eerste geval
#    13  dergelijke wijziging
#    13  eventuele wijziging
#    13  goede samenwerking
#    13  individuele belangenafweging
#    13  nuttige toepassing
#    13  structurele maatregelen
#    13  zesde alinea
#    13  humanitaire aard
#    13  flexibel werken
#    13  substantieel deel
#    13  groter deel
#    13  algemeen gedeelte
#    13  politieke verantwoordelijkheid
#    13  Nederlandse banken
#    13  staatkundige positie
#    13  derde partij
#    13  buitengewoon opsporingsambtenaar
#    13  bredere aanpak
#    13  nadere afspraken
#    13  kleine gemeenten
#    13  nieuwe eisen
#    13  extra waarborg
#    13  onderhavige wet
#    13  burgerlijk recht
#    13  lokale veiligheidsbeleid
#    13  bestuurlijk toezicht
#    13  kritische kanttekeningen
#    13  penitentiaire inrichting
#    13  gelijke behandelingstoets
#    13  Europese aanbestedingsrichtlijnen
#    13  substantieel belang
#    13  klein aantal
#    13  lage premiepercentage
#    13  dringende reden
#    13  andere rechtspersonen
#    13  reguliere onderwijs
#    13  administratieve rechter
#    13  maatschappelijk verkeer
#    13  verschillende taken
#    13  Nederlandse Grondwet
#    13  nieuwe vorm
#    13  eigen onderzoek
#    13  centraal loket
#    13  economische eigendom
#    13  individuele producenten
#    13  fiscale loon
#    13  neerwaartse wijziging
#    13  absolute zin
#    13  overige opmerkingen
#    13  gewone wet
#    13  private middelen
#    13  verschillende overheden
#    13  behoorlijke rechtspraak
#    13  collectieve belegging
#    13  air marshals
#    13  relevante invloed
#    13  maatschappelijke vraagstukken
#    13  niet-bekostigde instellingen
#    13  publiekrechtelijke rechtspersoon
#    13  toeristische verhuur
#    13  landelijk register
#    13  onteigenen percelen
#    13  algemene berekeningswijze
#    13  tijdelijke onderwijsvoorzieningen
#    13  individuele projecten
#    13  bedrijfseconomische redenen
#    13  beroepsethische normen
#    13  Noorse systeem
#    13  tweezijdige arbeidsovereenkomst
#    12  Vergelijk aanwijzing
#    12  aftrekbare kosten
#    12  andere afweging
#    12  technische ontwikkelingen
#    12  nationale beleid
#    12  praktische bezwaren
#    12  kleine werkgevers
#    12  economisch verkeer
#    12  bijzondere wetgeving
#    12  nieuwe fase
#    12  lange periode
#    12  sectorspecifieke wetgeving
#    12  organieke wetgeving
#    12  strafrechtelijke aanpak
#    12  zwaarwegend algemeen belang
#    12  hoge kwaliteit
#    12  Centrale organisatie
#    12  hoogste €
#    12  bestuursrechtelijke sancties
#    12  bijzondere aard
#    12  apart wetsvoorstel
#    12  andere diensten
#    12  objectieve gegevens
#    12  desbetreffende land
#    12  concrete situaties
#    12  evenwichtige wijze
#    12  indirecte discriminatie
#    12  verschillende mogelijkheden
#    12  dergelijke maatregel
#    12  expliciet aandacht
#    12  wettelijke waarborgen
#    12  grote problemen
#    12  benodigde gegevens
#    12  fysieke vrijheid
#    12  internationale rechtsorde
#    12  gelijke voet
#    12  fiscale winst
#    12  desbetreffende passage
#    12  nieuwe bepalingen
#    12  gelijktijdige inwerkingtreding
#    12  bestaand gebruik
#    12  seksuele uitbuiting
#    12  ernstige overlast
#    12  huidige wetsvoorstel
#    12  fiscale structuur
#    12  verschillende regelingen
#    12  overeenkomstige bepaling
#    12  budgettaire ruimte
#    12  verschillende elementen
#    12  maatschappelijke behoefte
#    12  minnelijke overeenstemming
#    12  hoger niveau
#    12  nieuwe taken
#    12  incidentele gevallen
#    12  wettelijke termijn
#    12  sociale markteconomie
#    12  daadwerkelijk gebruik
#    12  andere actoren
#    12  natuurlijke kenmerken
#    12  materiële integratie
#    12  specifieke voorschriften
#    12  dynamische verwijzing
#    12  materiële zin
#    12  fictieve beschikking
#    12  positieve fictieve beschikking
#    12  noodzakelijke voorzieningen
#    12  nationale bepalingen
#    12  grote druk
#    12  eerste deel
#    12  wettelijke mogelijkheden
#    12  vergaande maatregelen
#    12  legaal verblijf
#    12  verschillende terreinen
#    12  andere leden
#    12  psychiatrische ziekenhuizen
#    12  laatstgenoemde wet
#    12  dringende redenen
#    12  bijzondere situaties
#    12  onderhavige richtlijn
#    12  beoogde datum
#    12  Huidig artikel
#    12  grote hoeveelheid
#    12  derde elektriciteitsrichtlijn
#    12  langdurig toezicht
#    12  andere wetsvoorstellen
#    12  Tijdelijke referendumwet
#    12  specifieke situaties
#    12  financiële instelling
#    12  voldoende aanleiding
#    12  mogelijke effecten
#    12  burgerlijk procesrecht
#    12  flexibele arbeid
#    12  elektronische verzending
#    12  wetenschappelijk onderwijs
#    12  direct betrekking
#    12  nieuw beleid
#    12  maritieme beveiligers
#    12  ambtelijk apparaat
#    12  eigen gemeente
#    12  sociale verzekeringspremies
#    12  oneerlijke concurrentie
#    12  tweede nota
#    12  Europese banken
#    12  economische structuur
#    12  sociale huursector
#    12  externe accountant
#    12  grote projecten
#    12  binnenlands product
#    12  monetaire beleid
#    12  grote werkgevers
#    12  onafhankelijke oordeelsvorming
#    12  geneeskundige behandeling
#    12  goede staat
# ...
#     1  koninklijke waardigheid
#     1  eetbare voedsel
#     1  onverantwoorde verspilling
#     1  bijzonder supermarkten
#     1  totale voedselverspilling
#     1  Wettelijke verplichting
#     1  aanzienlijk financieel belang
#     1  overige bedrijfsvoering
#     1  bewust voedselverspilling
#     1  financieel-bedrijfsmatige prikkels
#     1  efficiënte bedrijfsvoering
#     1  grotere inspanning
#     1  substantieel grotere inspanning
#     1  Kleine ondernemingen
#     1  grote supermarktketens
#     1  Relevante categorie
#     1  verse eet-
#     1  hoofdzakelijk verse eet-
#     1  zelfstandig gegevens
#     1  Nederlandse Voedsel
#     1  werkbaar meetsysteem
#     1  extra investering
#     1  kleine extra investering
#     1  Maandelijkse informatie
#     1  maandelijkse hoeveelheid
#     1  verspilde voedingswaren
#     1  toenmalige Ministeries
#     1  bijzondere richtlijn
#     1  veertiende bijzondere richtlijn
#     1  verschillende gevaarlijke stoffen
#     1  algemene verklaring
#     1  geachte implementatie
#     1  noodzakelijk geachte implementatie
#     1  departementale voorbereiding
#     1  materiële richtlijnbepalingen
#     1  professioneel vuurwerk
#     1  mutagene stoffen
#     1  onverzegelde producten
#     1  aanwezige producten
#     1  niet-verkochte producten
#     1  lagere hoeveelheid
#     1  relatief kleine hoeveelheden
#     1  zodanig sprake
#     1  bijzondere preferentie
#     1  preferente vorderingen
#     1  andere preferente vorderingen
#     1  hypothecaire vorderingen
#     1  algemene zekerheidsrecht
#     1  dringend probleem
#     1  andere scheepscrediteur
#     1  draagkrachtiger motivering
#     1  teboekstaand schip
#     1  zodanige vordering
#     1  zodanige voorrang
#     1  hoge rangorde
#     1  Nederlandse havenbedrijven
#     1  vorige reis
#     1  buitenlandse havengelden
#     1  hoog voorrecht
#     1  Nieuw Burgerlijk Wetboek
#     1  onderzochte havens
#     1  grootste haven
#     1  Exacte gegevens
#     1  onverhaalbare havengelden
#     1  verder Verdrag
#     1  nationale handelsvloten
#     1  juridische infrastructuur
#     1  maritieme staten
#     1  internationale rechtsuniformiteit
#     1  kleinere maritieme natie
#     1  Gemeentelijk Havenbedrijf
#     1  WODC- onderzoek
#     1  Oekraïense staten
#     1  nieuwe reis
#     1  vorige reizen
#     1  Garantiefonds zeevarenden
#     1  soortgelijke instellingen
#     1  overige overgangsbepalingen
#     1  overige inhoud
#     1  vertrouwelijke veiligheidsbijlage
#     1  nieuwe Protocol
#     1  vertrouwelijke karakter
#     1  laatste waarborg
#     1  eerste verdrag
#     1  dwingende argumenten
#     1  langer dwingende argumenten
#     1  geheime bijlagen
#     1  vertrouwelijke status
#     1  vertrouwelijke Veiligheidsbijlage
#     1  respectievelijk geheim
#     1  vertrouwelijk respectievelijk geheim
#     1  separate ratificatie
#     1  Nederlandse verdragenrecht
#     1  nieuwe bestemming
#     1  overbodige exercitie
#     1  bestuursrechtelijke fase
#     1  civielrechtelijke fase
#     1  eventuele beroepsprocedure
#     1  Onduidelijke voorwaarde
#     1  juridisch-technische verbeteringen
#     1  Goede Aarde
#     1  juiste versie
#     1  terminologisch juiste versie
#     1  potentiële gezondheidsrisico
#     1  grote potentiële gezondheidsrisico
#     1  algemene artikel
#     1  vergiftige stoffen
#     1  achttiende aanpassing
#     1  andere officiële talen
#     1  Voornoemde richtlijn
#     1  bekend referentiekader
#     1  algemeen bekend referentiekader
#     1  ongewilde gebeurtenissen
#     1  zevende wijziging
#     1  deskundige bijstand
#     1  verdere begrenzing
#     1  beoogde pilots
#     1  Wetenschappelijk comité
#     1  onafhankelijk wetenschappelijk comité
#     1  vaste kamercommissie
#     1  preventief gezondheidsbeleid
#     1  gehele samenstelling
#     1  ongewenste nadelen
#     1  aanzienlijke ongewenste nadelen
#     1  overeenkomstige diensten
#     1  radicale oplossing
#     1  volledige afsplitsing
#     1  onafhankelijke onderneming
#     1  duidelijker scheidslijn
#     1  commerciële werkzaamheden
#     1  overige commerciële werkzaamheden
#     1  verliesgevende kernactiviteiten
#     1  mogelijk verliesgevende kernactiviteiten
#     1  commerciële winst
#     1  fiscaalrechtelijk oogpunt
#     1  duidelijke scheiding
#     1  onbelaste kernactiviteiten
#     1  andere crediteuren
#     1  verschillende fondsen
#     1  juiste uitwerking
#     1  Verplichte verhuiskostenvergoeding
#     1  apart artikellid
#     1  noodzakelijke voorstellen
#     1  overige schade
#     1  eventuele overige schade
#     1  andere bijdrage
#     1  diverse andere wijzigingen
#     1  directe reactie
#     1  centrale inning
#     1  verschillende transactievoorwaarden
#     1  heel algemene zin
#     1  verdere inhoud
#     1  afzonderlijk belang
#     1  duidelijker aanpak
#     1  gezamenlijk aanspreekpunt
#     1  afzonderlijke arbeidsmarktregio
#     1  eigen aansturingsstructuur
#     1  flexibele opstelling
#     1  afzonderlijke regio
#     1  andere zijde
#     1  verschillende opdrachten
#     1  personele regelmogelijkheden
#     1  wezenlijk aandachtspunt
#     1  verschillende bestuurlijke kaders
#     1  strakkere regie
#     1  budgettaire vlak
#     1  Goede werkgeversdienstverlening
#     1  werkzoekenden dienstverlening
#     1  eigen aansturing
#     1  lokale aansturing
#     1  eigen uitvoeringsvormen
#     1  gedecentraliseerde beleid
#     1  brede contacten
#     1  online begeleiding
#     1  gezamenlijk werkgevers
#     1  goede match
#     1  goede werkgeversdienstverlening
#     1  hoogwaardige dienstverlening
#     1  gezamenlijke organisatie
#     1  onderlinge betrokkenheid
#     1  verantwoordelijke besturen
#     1  regionale initiatieven
#     1  personele regelruimte
#     1  regionale aanwezigheid
#     1  regionale arbeidsdeskundigen
#     1  regionale beleidsadviseurs
#     1  voldoende keuzeruimte
#     1  derde aspect
#     1  landelijke beschikbare instrumenten
#     1  eenduidige inzet
#     1  persoonlijke ondersteuning
#     1  verder inzicht
#     1  gezamenlijk uitvoeringsplan
#     1  Bestuurlijke reactie
#     1  derde meting
#     1  dergelijke afwijkingsbevoegdheid
#     1  beknopte weergave
#     1  extra beveiligingsmaatregelen
#     1  internationale teksten
#     1  ander spanningsveld
#     1  eenvoudig mogelijke wijze
#     1  zodanige lichamelijke beperking
#     1  andere balans
#     1  eerste test
#     1  specifieke oogmerk
#     1  eventuele herinvoering
#     1  vermeende onbetrouwbaarheid
#     1  verschillende verhalen
#     1  openbare norm
#     1  operationele eisen
#     1  niet-geteste apparaten
#     1  onjuiste software
#     1  diverse plekken
#     1  andere software
#     1  politieke voorkeuren
#     1  rood potlood
#     1  Verbeterde stemcomputers
#     1  zogenoemde paper
#     1  schriftelijke bewijs
#     1  verschillende taalgroepen
#     1  desbetreffende taken
#     1  desbetreffende hoofdstukken
#     1  geheime stemming
#     1  ruime afwijkingsbevoegdheid
#     1  directe juridische betekenis
#     1  verantwoordelijke organen
#     1  Eventuele afwijking
#     1  lage opkomst
#     1  bureaucratische procedure
#     1  ingewikkelde bureaucratische procedure
#     1  ruime regeling
#     1  zodanige afstand
#     1  potentiële kiezers
#     1  expliciete regeling
#     1  geregistreerde partner
#     1  geheime karakter
#     1  huidige papieren
#     1  significante groep
#     1  alternatieve bedieningswijzen
#     1  zogenaamde sip
#     1  elektronische hulpmiddelen
#     1  periodieke herijking
#     1  diverse staten
#     1  extra regime
#     1  huidige suatie
#     1  verschillende wetgevingsprocedures
#     1  zogenoemde Memoranda
#     1  Caribische Codes
#     1  kennelijk medegelding
#     1  Caribische codes
#     1  Dergelijke gelding
#     1  mogelijke taakverzwaring
#     1  desbetreffende vlaggenstaat
#     1  zogenoemde controles
#     1  themagerichte controleacties
#     1  afzonderlijke aspecten
#     1  lichtere regime
#     1  ‘lichtere regime
#     1  mogelijke overeenkomstige wijze
#     1  internationale scheepvaartverdragen
#     1  Praktische problemen
#     1  equivalente regeling
#     1  commerciële schepen
#     1  kleine commerciële schepen
#     1  derde Aanpassingswet
#     1  wettelijke planprocedures
#     1  nieuwe onderwijsvoorzieningen
#     1  pedagogisch-didactisch concept
#     1  betrouwbare prognose
#     1  verschillende beleidsnotities
#     1  extra belang
#     1  andere signatuur
#     1  terminologische kanttekening
#     1  expliciet blijk
#     1  ongeconditioneerde aanspraken
#     1  gelijke bekostiging
#     1  pedagogisch-didactische ontwikkelingen
#     1  Onderwijskundige differentiaties
#     1  eerste school
#     1  lagere stichtingseisen
#     1  inhoudelijke bemoeienis
#     1  specifieke richtingsscholen
#     1  culturele context
#     1  algemenere formule
#     1  specifieke bijzondere scholen
#     1  nieuwe specifieke bijzondere scholen
#     1  gebruikelijke openheid
#     1  algemene onderwijsbeleid
#     1  verschillende oogmerken
#     1  brede identiteit
#     1  anderszins brede identiteit
#     1  specifieke richtingen
#     1  huidige planning
#     1  specifieke richting
#     1  nieuwe planningssystematiek
#     1  open begrip
#     1  relatief hogere mate
#     1  specifieke (
#     1  pedagogisch-didactische vernieuwingsconcepten
#     1  eigen instandhoudingsnorm
#     1  mogelijke bemoeienis
#     1  gering mogelijke bemoeienis
#     1  denominatieve aanbod
#     1  ernstig bezwaar
#     1  gelijkmatige spreiding
#     1  vrije mogelijkheid
#     1  nieuwe richtingen
#     1  precieze oorzaak
#     1  kleine groeperingen
#     1  denominatieve richting
#     1  grotere steden
#     1  incidenteel problemen
#     1  nieuwe bijzondere scholen
#     1  onbetaalbare wijze
#     1  complexere tweede voornemen
#     1  ideëel draagvlak
#     1  statistische gegevens
#     1  vruchtbare leeftijd
#     1  voorspellende waarde
#     1  richtingvrije planningssystematiek
#     1  dezelfde richting
#     1  traditionele scholenplanning
#     1  gelijksoortig probleem
#     1  andere verklaring
#     1  adequate controle
#     1  hogere stichtingsnormen
#     1  aanzienlijk hogere stichtingsnormen
#     1  gemeentelijke belangstellingspercentages
#     1  geringere mate
#     1  betrouwbaar instrument
#     1  tijdelijke stopzetting
#     1  categoriale scholen
#     1  buitenlandse steun
#     1  financiële waarborg
#     1  extra drempel
#     1  subsidiaire stelsel
#     1  oude subsidiaire stelsel
#     1  mogelijke verstarring
#     1  veiligste manier
#     1  reguliere belangstellingspercentages
#     1  vergelijkbare gemeente
#     1  directe meting
#     1  huidige prognosesystematiek
#     1  sterk verschillen
#     1  doelmatige planning
#     1  betere weergave
#     1  unieke richting
#     1  forse uitvoeringslasten
#     1  oneigenlijke wijze
#     1  eigen ambities
#     1  onderwijskundige visie
#     1  meervoudige publieke verantwoording
#     1  onderzochte gemeenten
#     1  Vergelijk B.P.
#     1  strafrechtelijke systeem
#     1  Nederlandse strafrechtelijke systeem
#     1  specifieke strafmaxima
#     1  algemene minimumstraffen
#     1  huidige straftoemeting
#     1  andere zijden
#     1  nadere uniformering
#     1  verdere uniformering
#     1  zogenaamde Mulder-zaken
#     1  automatische strafpuntentoekenning
#     1  strakke grenzen
#     1  grote ruimte
#     1  onredelijke hardheid
#     1  administratiefrechtelijke invorderingsprocedure
#     1  dergelijk rechtsgevolg
#     1  vorengenoemde redenen
#     1  Extra beslag
#     1  wezenlijke versterking
#     1  eventuele extra beslag
#     1  zogenaamde OM-afdoening
#     1  onvoorwaardelijke opleggingen
#     1  onbeperkte straftoemetingsvrijheid
#     1  relatief onbeperkte straftoemetingsvrijheid
#     1  rechtsgeleerde literatuur
#     1  verschillende bandbreedtes
#     1  ruimere bandbreedte
#     1  nadere versterking
#     1  zekere democratische legitimering
#     1  lichte verkeersfeiten
#     1  juridisch-technische zin
#     1  feitelijke bestuurder
#     1  streng puntenstelsel
#     1  aantrekkelijk alternatief
#     1  geringere kosten
#     1  relatief geringere kosten
#     1  fijnmazige systemen
#     1  administratieve afwikkeling
#     1  eenvoudig stelsel
#     1  strakke grens
#     1  denkbare wettelijke voorziening
#     1  andere bestraffende sanctie
#     1  wettelijke maximumduur
#     1  eerdere strafrechtelijke afdoening
#     1  ongeclauseerde delegatie
#     1  Parlementaire invloed
#     1  rechtsgeleerde schrijvers
#     1  bestuursrechtelijke vorderingsprocedure
#     1  sterk patroon
#     1  tweede hoofdelement
#     1  zodanige rijontzegging
#     1  zodanige duur
#     1  groot risico
#     1  bekende omstandigheden
#     1  extra gratieverzoeken
#     1  onvoorwaardelijke rijontzeggingen
#     1  duur vergunning
#     1  agrarische grond
#     1  soortgelijk bezwaar
#     1  normale dwarsprofiel
#     1  gebruikelijke normale dwarsprofiel
#     1  alternatieve aanleg
#     1  maatschappelijke instemming
#     1  brede maatschappelijke instemming
#     1  Omvang goedkeuringsrecht
#     1  wezenlijk andere vennootschap
#     1  verklaarbare leemte
#     1  duurzame samenwerking
#     1  ’n vennootschap
#     1  wenst volmacht
#     1  bijzondere voordrachtsrecht
#     1  duidelijke vennootschappelijke verhoudingen
#     1  114a lid
#     1  zestigste dag
#     1  zwaarwichtig belang
#     1  laatstgenoemde term
#     1  twaalfde alinea
#     1  wezenlijk betrekking
#     1  typisch bestuursbesluit
#     1  andere rechtshandelingen
#     1  benodigde andere rechtshandelingen
#     1  Privatieve werking
#     1  onnodig vergaande ingreep
#     1  ongerijmde resultaten
#     1  Nederlandse vennootschapsrecht
#     1  Terzelfder tijd
#     1  gehele raad
#     1  maatschappelijke ervaring
#     1  zorgvuldige overweging
#     1  mogelijk objectieve criteria
#     1  specifieke capaciteiten
#     1  sociale verhoudingen
#     1  individuele profiel
#     1  eventuele consolidatie
#     1  Wettelijke procedure
#     1  besmettelijke personen
#     1  sterkere roep
#     1  sociaal-maatschappelijke gevolgen
#     1  aanmerkelijke versoepelingen
#     1  maatschappelijke achtergrond
#     1  mogelijk beleid
#     1  coherent mogelijk beleid
#     1  eerste piek
#     1  eerste versoepeling
#     1  dagelijkse ziekenhuisopnames
#     1  Grote Steden
#     1  zogenoemde biometrische gegevens
#     1  persoonlijke kenmerken
#     1  Dezelfde (
#     1  voorziene algemene maatregelen
#     1  ’n definitie
#     1  essentieel nieuw onderdeel
#     1  technische vraag
#     1  nieuwe negende lid
#     1  spoorse doorsnijdingen
#     1  belangrijke eigen verantwoordelijkheid
#     1  jaarlijkse subsidie
#     1  meerjarige exploitatie-overeenkomsten
#     1  behoorlijke taakuitoefening
#     1  functionerende subsidieverhouding
#     1  goed functionerende subsidieverhouding
#     1  4)Vergelijk aanwijzingen
#     1  5)Vergelijk aanwijzing
#     1  belangrijkste rechtsgrond
#     1  strafrechtelijke regeling
#     1  achtereenvolgende wetswijzigingen
#     1  oorspronkelijke gronden
#     1  ruimere verjaringstermijnen
#     1  vatbare straffen
#     1  afzonderlijke invoeringsregeling
#     1  dergelijke invoeringsregeling
#     1  Inhoudelijke beoordeling
#     1  onherroepelijke sancties
#     1  onherroepelijke straf
#     1  pedagogisch doel
#     1  belangrijk pedagogisch doel
#     1  pedagogisch oogpunt
#     1  snelle strafrechtelijke reactie
#     1  definitief vonnis
#     1  actieve inspanning
#     1  actieve opsporingshandelingen
#     1  Gratiewet gratie
#     1  wettelijke verjaringsregeling
#     1  huidige wettelijke verjaringsregeling
#     1  technische invoeringswet
#     1  kritische reacties
#     1  ’ verjaringstermijnen
#     1  gewone’ verjaringstermijnen
#     1  ‘Wet
#     1  Nederlandse Jeugdrechtadvocaten
#     1  gelijktijdig zicht
#     1  gelijktijdige toevoegingen
#     1  derde kandidaat-gerechtsdeurwaarder
#     1  extra aanwijzing
#     1  voldoende gegevens
#     1  ongewenste ontwikkelingen
#     1  genoegzame spreiding
#     1  kortere perioden
#     1  nieuwe tuchtrecht
#     1  late verlengingen
#     1  nieuwe gerechtsdeurwaarders
#     1  volledig uniforme regeling
#     1  separate vermelding
#     1  medische geschiktheid
#     1  vage toepassingscriteria
#     1  desbetreffende data
#     1  schriftelijk bewijs
#     1  verschillende benaming
#     1  maritieme wetgeving
#     1  Nederlandse maritieme wetgeving
#     1  huidige zeevaartbemanningswetgeving
#     1  geneeskundige medisch specialist
#     1  geneeskundige verklaring
#     1  redactionele misstelling
#     1  nadrukkelijke overweging
#     1  Koninklijke Marine

# %% [markdown]
# # Slightly less basic

# %% [markdown]
# ## Extracting patterns with rule-based matching
