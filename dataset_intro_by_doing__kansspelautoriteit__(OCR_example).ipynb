# %% [markdown]
# <a href="https://colab.research.google.com/github/knobs-dials/wetsuite-dev/blob/main/notebooks/intro/using_dataset_kansspelautoriteit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (only) in colab, run this first to install wetsuite from (the most recent) source.   For your own setup, see wetsuite's install guidelines.
# !pip3 install -U --no-cache-dir --quiet https://github.com/knobs-dials/wetsuite-dev/archive/refs/heads/main.zip

# %% [markdown]
# # Purpose of this notebook

# %% [markdown]
# To show you around the dataset from the [kansspelautoriteit](https://kansspelautoriteit.nl/)'s [sanctiebesluiten](https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/)

# %%
import pprint

import wetsuite.datasets
ks = wetsuite.datasets.load('kansspelautoriteit-sancties-struc')

# %%
# how does that dataset describe itself?
print( ks.description )
# Out:
# This is a plaintext form of the set of documents you can find under https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/ as PDFs.
#
#             Since almost half of those PDFs do not have a text stream, this data is entirely OCR'd,
#             so expect some typical OCR errors.  The OCR quality seems fairly decent, and some effort was made to remove headers and footers,
#             yet there are some leftovers  like _ instead of . and = instead of :
#
#
#             The data is a fairly nested structure of python objects (or JSON, before it's parsed).
#             - .data is a list of cases.
#
#             - each case is a dict, with a
#                 - 'name',
#                 - 'docs' (a list)
#                 - and some extracted information like mentioned money amounts, the apparent date span of the case
#
#             - each document in that mentioned list is is a dict, with keys like
#               - 'url' - to the PDF it came from
#               - 'status' - from the detail page (if we could find it - not 100%)
#               - extracted informations like 'header_dates' (comes from PDF contents)
#               - 'pages' (a list)
#
#             - each page in that list is a dict, which has keys:
#               - 'body_text' - a list, which containts text fragments that are _almost_ like paragraphs
#                   except that text may continue between pages anyway - currently still up to you to detect -
#                   plus the post-OCR processing isn't perfect.
#               - 'foot_text' - generally just [ "Pagina 1 van 27" ]
#               - 'head_text' - fragments like []"Kansspelautoriteit", "OPENBAAR"] but also the date and kenmerk lines
#
#
#             (TODO: update this example)
#             For example (body text edited for brevity), one case's dict, with one document:
#                 { # dict for a case
#                     'name': 'Toto Online B.V.',  # case's name
#                     'docs': [                    # list of PDF documents in this case
#                         { # dict detailing first document in case
#                             'url': 'https://kansspelautoriteit.nl/publish/library/32/01_278_071_15091_sanctiebesluit_toto_ov.pdf',
#                             'pages': [
#                                 {  # first page's dict   (currently contains only body's text fragments; idea was to split off header contents)
#                                     'body_text':[  # first page's text fragments
#                                         'Besluit van de raad van [more sentence]',
#                                         'Zaak: 15091 Kenmerk: 15091 [more kenmerk]',
#                                         'Besluit',
#                                         'Inleiding',
#                                         'De raad van bestuur van de Kansspelautoriteit [more paragraph]'
#                                     ]
#                                 },
#                                 { # second page's dict
#                                     'body_text': [   # second page text fragment
#                                     'heeft heeft ontvangen sinds hij daar [more paragraph]',
#                                     'De toezichthouders zijn naar aanleiding [more paragraph]'
#                                     ]
#                                 }
#                                 # ...more pages
#                             ],
#                         }, # end of document dict
#                         # ...more documents
#                     ]
#                 }

# %% [markdown]
# ## What does the document data look like?
#
# Text in fragments, grouped into pages.
#
# Yes, these fragments are somewhat clunky to work with.
#
# This is sort of a fact of life if the document doesn't provide text and we have to apply OCR.
#
# We could flatten that to text, but that requires baking even more interpretation than we already do
# ('more': we already estimate how to remove headers, join and split paragraphs, and section names).
#
# So instead, we show this (creative) work here.
# We currently do not figure out whether paragraphs continue from the previous page.
# As the next section illustrates, something like "first letter on a page is lowercase" doesn't always work,
# which argues either for better polishing of this data - or perhaps to give it in even clunkier OCR form where the positions on the page are still there.

# %%
cases = ks.data   # Call it what it is.   Type-wise this is a list of case dicts

for case_details in cases:                                # show case's
    print('\n\n === CASE: %s === '%case_details['name'])  # name
    for ck, cv in case_details.items():                   # and metadata
        if ck not in ('name', 'docs'):                    #   (skip some fields)
            print('   %20s %s'%(ck, cv) )

    # List the documents that are part of the case
    print('              DOCUMENTS    (%d of them)'%(len(case_details['docs']),) )
    for doc_dict in case_details['docs']:
        print()
        for dk, dv in doc_dict.items():
            if dk in ('pages',):
                print('   %30s %s'%('#pages', len(dv)) )
            else:
                print('   %30s %s'%(dk, dv) )
# Out:
#  === CASE: Probe Investments Limited ===
#              date_range ['2022-12-20', '2022-12-20']
#                   money ['1128000', '900000', '600000', '800000', '800000', '1600000', '800000', '600000', '17363089', '17363089', '1128000', '1128000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/probe-investments-limited/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/15269_01-281-231_sanctiebesluit_probe_investments_limited_ov.pdf
#                            #pages 27
#                      header_dates ['2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/15269_01-281-234_besluit_openbaarmaking_probe_investments_limited_ov.pdf
#                            #pages 5
#                      header_dates ['2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#
#  === CASE: Betpoint Group Limited ===
#              date_range ['2022-12-20', '2022-12-20']
#                   money ['1787000', '900000', '600000', '800000', '800000', '800000', '600000', '27507348', '1787000', '1787000', '1787000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/betpoint-group-limited/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/ov_15164_01-281-226_sanctiebesluit_betpoint.pdf
#                            #pages 31
#                      header_dates ['2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/ov_15164_01-281-229_betpoint_openbaarmaking.pdf
#                            #pages 6
#                      header_dates ['2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#
#  === CASE: N1 Interactive Limited ===
#              date_range ['2022-12-20', '2022-12-20']
#                   money ['12640000', '10000', '40000', '900000', '10000', '40000', '126407930', '126407930', '12640000', '12640000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/n1-interactive-limited/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01-281-253_sanctiebesluit_15244_ov.pdf
#                            #pages 28
#                      header_dates ['2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01-281-256_openbaarmakingbesluit_15244_ov.pdf
#                            #pages 4
#                      header_dates []
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#
#  === CASE: Videoslots Limited ===
#              date_range ['2022-12-20', '2022-12-20']
#                   money ['9874000', '900000', '600000', '800000', '800000', '1600000', '600000', '141069427', '282138854', '9874000', '9874000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/videoslots-limited/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/15167_01-281-259_sanctiebesluit_videoslots_ov.pdf
#                            #pages 30
#                      header_dates ['2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01-281-262_openbaarmakingsbesluit_videoslots_ov.pdf
#                            #pages 5
#                      header_dates ['2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#
#  === CASE: Fairload Limited ===
#              date_range ['2022-12-20', '2022-12-20']
#                   money ['900000', '900000', '600000', '800000', '800000', '1600000', '800000', '600000', '75000', '6526152', '13052305', '600000', '150000', '75000', '75000', '75000', '75000', '75000', '525000', '1125000', '900000', '900000', '900000', '900000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/fairload-limited/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/15151_ov_fairload_sanctiebesluit_def.pdf
#                            #pages 28
#                      header_dates ['2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/15151_01-281-217_ov_fairload_openbaarmaking.pdf
#                            #pages 6
#                      header_dates ['2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#
#  === CASE: Equinox Dynamic N.V. & Domiseda and Partners s.r.o. ===
#              date_range ['2022-12-20', '2023-01-26']
#                   money ['900000', '900000', '600000', '800000', '800000', '1600000', '800000', '600000', '75000', '8380160', '16760320', '8380160', '600000', '600000', '75000', '75000', '75000', '75000', '75000', '450000', '900000', '900000', '1050000', '900000', '900000', '900000', '900000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/equinox-dynamic-domiseda-and-partners/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01-281-220_sanctiebesluit_2022_openbaar.pdf
#                            #pages 16
#                      header_dates ['2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20']
#                            status Tegen dit besluit kan bezwaar gemaakt worden.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_equinox_dynamic_domiseda.pdf
#                            #pages 5
#                      header_dates ['2023-01-26', '2023-01-26', '2023-01-26', '2023-01-26']
#                            status Tegen dit besluit kan bezwaar gemaakt worden.
#
#
#  === CASE: Bingoal Nederland B.V. ===
#              date_range ['2022-11-08', '2022-11-08']
#                   money ['350000', '350000', '350000', '350000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/bingoal-nederland/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_bingoal_8_febrauri_2023.pdf
#                            #pages 18
#                      header_dates ['2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08', '2022-11-08']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_bingoal_8_februari_2023.pdf
#                            #pages 4
#                      header_dates ['2022-11-08', '2022-11-08', '2022-11-08']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#
#  === CASE: JOI Gaming Ltd ===
#              date_range ['2023-01-10', '2023-01-11']
#                   money ['400000', '350000', '50000', '400000', '400000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/joi-gaming-ltd/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_joi_gaming_ltd_10_januari_2023_.pdf
#                            #pages 14
#                      header_dates ['2023-01-10', '2023-01-10', '2023-01-10', '2023-01-10', '2023-01-10', '2023-01-10', '2023-01-10', '2023-01-10', '2023-01-10', '2023-01-10', '2023-01-10', '2023-01-10', '2023-01-10']
#                            status Tegen dit besluit kan bezwaar gemaakt worden.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_joi_gaming_ltd.pdf
#                            #pages 4
#                      header_dates ['2023-01-11', '2023-01-11', '2023-01-11']
#                            status Tegen dit besluit kan bezwaar gemaakt worden.
#
#
#  === CASE: Shark77.Ltd ===
#              date_range ['2022-12-20', '2022-12-22']
#                   money ['900000', '900000', '600000', '800000', '800000', '1600000', '800000', '600000', '600000', '150000', '75000', '75000', '75000', '75000', '75000', '1125000', '900000', '900000', '900000', '900000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/shark77-ltd/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_shark77.pdf
#                            #pages 22
#                      header_dates ['2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20', '2022-12-20']
#                            status Tegen dit besluit kan bezwaar gemaakt worden.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_shark77.pdf
#                            #pages 5
#                      header_dates ['2022-12-22', '2022-12-22', '2022-12-22', '2022-12-22']
#                            status Tegen dit besluit kan bezwaar gemaakt worden.
#
#
#  === CASE: Holland Casino N.V. ===
#              date_range ['2021-12-03', '2022-04-19']
#                   money ['25000', '25000', '25000', '25000', '25000', '25000', '25000', '25000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/holland-casino-0/
#               DOCUMENTS    (6 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01_252_792_lod_hc.pdf
#                            #pages 9
#                      header_dates ['2021-12-03']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01_252_795_openbaarmakingsbesluit.pdf
#                            #pages 4
#                      header_dates []
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01_263_938_bob_lod_hc.pdf
#                            #pages 13
#                      header_dates ['2022-04-19', '2022-04-19', '2022-04-19', '2022-04-19', '2022-04-19', '2022-04-19', '2022-04-19', '2022-04-19', '2022-04-19', '2022-04-19', '2022-04-19', '2022-04-19']
#                            status Tegen deze beslissing op bezwaar is inmiddels beroep ingesteld bij de rechtbank.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01_263_939_besluit_openbaarmaking_beslissing_op_bezwaar_holland_casino_n_v.pdf
#                            #pages 3
#                      header_dates ['2022-04-19', '2022-04-19']
#                            status Tegen dit besluit is inmiddels beroep ingesteld bij de rechtbank.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01_264_668_invorderingsbeschikking_lod_hc.pdf
#                            #pages 8
#                      header_dates []
#                            status Tegen dit besluit is inmiddels beroep ingesteld bij de rechtbank.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01_268_588_besluit_tot_openbaarmaking_holland_casino_n_v.pdf
#                            #pages 5
#                      header_dates []
#                            status Tegen dit besluit is inmiddels beroep ingesteld bij de rechtbank.
#
#
#  === CASE: Toto Online B.V. ===
#              date_range []
#                   money []
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/toto-online/
#               DOCUMENTS    (0 of them)
#
#
#  === CASE: Nationale Postcode Loterij N.V. ===
#              date_range ['2022-07-28', '2022-10-19']
#                   money []
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/nationale-postcode-loterij/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_npl.pdf
#                            #pages 13
#                      header_dates ['2022-07-28', '2022-07-28', '2022-07-28', '2022-07-28', '2022-07-28', '2022-07-28', '2022-07-28', '2022-07-28', '2022-07-28', '2022-07-28', '2022-07-28', '2022-07-28']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_npl.pdf
#                            #pages 7
#                      header_dates ['2022-10-19', '2022-10-19', '2022-10-19', '2022-10-19', '2022-10-19', '2022-10-19']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: M.K.C Limited ===
#              date_range []
#                   money ['28000', '84000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/mkc-limited/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/20220823_01_265_505_-_besluit_last_onder_dwangsom_ov.pdf
#                            #pages 11
#                      header_dates []
#                            status Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen zijn gestaakt. Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/20220823_01_265_507_-_besluit_openbaarmaking_ov.pdf
#                            #pages 5
#                      header_dates []
#                            status Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen zijn gestaakt. Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: L.C.S Limited ===
#              date_range []
#                   money ['55000', '165000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/limited/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/20220817_01_265_500_-_besluit_lod_sons-of-slots_ov.pdf
#                            #pages 11
#                      header_dates []
#                            status Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen zijn gestaakt. Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/20220817_01_265_499_-_besluit_openbaarmaking_ov.pdf
#                            #pages 5
#                      header_dates []
#                            status Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen zijn gestaakt. Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: Gammix Limited ===
#              date_range []
#                   money ['20000', '1470000', '4412000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/gammix-limited/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/20220707_01_270_078_-_lod_gammix_ov.pdf
#                            #pages 14
#                      header_dates []
#                            status Tegen dit besluit kan bezwaar worden gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/20220707_01_270_081_-_besluit_openbaarmaking_gammix_ov.pdf
#                            #pages 5
#                      header_dates []
#                            status Tegen dit besluit kan bezwaar worden gemaakt.
#
#
#  === CASE: Red Ridge Marketing ===
#              date_range []
#                   money ['25000', '25000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/red-ridge-marketing/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/20220412_01_263_969_besluit_lod_ov_1.pdf
#                            #pages 11
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/20220412_01_263_968_besluit_openbaarmaking_wob_ov_1.pdf
#                            #pages 5
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: Performing Media Limited ===
#              date_range []
#                   money ['12500', '12500']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/performing-media-limited/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/last_onder_dwangsom_performing_media_limited.pdf
#                            #pages 12
#                      header_dates []
#                            status Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen zijn gestaakt. De last onder dwangsom is ingetrokken.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_tot_openbaarmaking_performing_media_limited.pdf
#                            #pages 5
#                      header_dates []
#                            status Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen zijn gestaakt. De last onder dwangsom is ingetrokken.
#
#
#  === CASE: Linkerik B.V. ===
#              date_range []
#                   money ['25000', '25000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/linkerik/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_last_onder_dwangsom_14508.pdf
#                            #pages 11
#                      header_dates []
#                            status Tegen dit besluit kan bezwaar worden gemaakt. Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen zijn gestaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_14508.pdf
#                            #pages 4
#                      header_dates []
#                            status Tegen dit besluit kan bezwaar worden gemaakt. Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen zijn gestaakt.
#
#
#  === CASE: Onlinecasinobonus.nl ===
#              date_range []
#                   money ['12500', '12500']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/onlinecasinobonus-nl/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/last_onder_dwangsom_onlinecasinobonus_nl.pdf
#                            #pages 13
#                      header_dates []
#                            status Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen zijn gestaakt. De last onder dwangsom is ingetrokken.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_onlinecasinobonus_nl.pdf
#                            #pages 5
#                      header_dates []
#                            status Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen zijn gestaakt. De last onder dwangsom is ingetrokken.
#
#
#  === CASE: LCB CORP ===
#              date_range []
#                   money ['6250', '31250', '6250', '6250', '31250']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/lcb-corp/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/lcb_corp_lod_20211213_01_252_632_lod_nl_lcb_org_ov.pdf
#                            #pages 10
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/lcb_corp_besluit_openbaarmaking_20211213_01_252_633.pdf
#                            #pages 5
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: Casinoscout.nl ===
#              date_range []
#                   money ['25000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/casinoscout-nl/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/casinoscout_nl_besluit_openbaarmaking_ov.pdf
#                            #pages 4
#                      header_dates []
#                            status Tegen dit besluit kan bezwaar worden gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/casinoscout_nl_lod.pdf
#                            #pages 9
#                      header_dates []
#                            status Tegen dit besluit kan bezwaar worden gemaakt.
#
#
#  === CASE: Online Casino Ground ltd ===
#              date_range []
#                   money ['16000', '80000', '16000', '16000', '80000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/online-casino-ground-ltd/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/last_onder_dwangsom_online_casino_ground_ltd.pdf
#                            #pages 9
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_online_casino_ground_ltd.pdf
#                            #pages 4
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: Slots Dev ===
#              date_range []
#                   money ['25000', '25000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/slots-dev/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/last_onder_dwangsom_slots_dev.pdf
#                            #pages 9
#                      header_dates []
#                            status Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen zijn gestaakt. De last onder dwangsom is ingetrokken.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_slots_dev.pdf
#                            #pages 4
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: Tipico Co. Ltd ===
#              date_range []
#                   money ['21000', '21000', '870000', '870000', '100000', '200000', '75000', '75000', '75000', '425000', '106250', '531250', '531250']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/tipico-co-ltd/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_tipico_openbaar.pdf
#                            #pages 21
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_tipico_openbaar.pdf
#                            #pages 4
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: BSB Shop ===
#              date_range ['2021-08-20', '2021-08-20']
#                   money ['7000', '35000', '7000', '35000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/bsb-shop/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_last_onder_dwangsom_bsb_shop.pdf
#                            #pages 8
#                      header_dates ['2021-08-20', '2021-08-20', '2021-08-20', '2021-08-20', '2021-08-20', '2021-08-20', '2021-08-20']
#                            status Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen zijn gestaakt. De last onder dwangsom is ingetrokken.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_bsb_shop.pdf
#                            #pages 4
#                      header_dates []
#                            status Tegen dit besluit kan bezwaar worden gemaakt.
#
#
#  === CASE: Luxury Bingo ===
#              date_range []
#                   money ['30000', '30000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/luxury-bingo/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_lxury_bingo.pdf
#                            #pages 8
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_luxery_bingo.pdf
#                            #pages 5
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: N1 Interactive Limited ===
#              date_range ['2021-03-30', '2021-10-05']
#                   money ['500000', '500000', '500000', '100000', '870000', '100000', '100000', '500000', '500000', '870000', '10000', '10000', '40000', '40000', '1500000', '176737', '870000', '870000', '100007', '40000000', '200000', '75000', '75000', '125000', '75000', '50000', '400000', '500000', '500000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/n1-interactive/
#               DOCUMENTS    (5 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/beslissing_op_bezwaar_n1_interactive_ltd.pdf
#                            #pages 3
#                      header_dates ['2021-10-05', '2021-10-05']
#                            status Tegen deze beslissing op bezwaar is inmiddels beroep ingesteld bij de rechtbank.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_n1_interactive_ltd.pdf
#                            #pages 3
#                      header_dates ['2021-10-05', '2021-10-05']
#                            status Tegen deze beslissing op bezwaar is inmiddels beroep ingesteld bij de rechtbank.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/bac_advies_n1_interactive_ltd.pdf
#                            #pages 14
#                      header_dates []
#                            status None
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_n1_interactive_limited_ov.pdf
#                            #pages 27
#                      header_dates ['2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_interactive_limited.pdf
#                            #pages 4
#                      header_dates ['2021-03-30', '2021-03-30', '2021-03-30']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#
#  === CASE: Staatsloterij B.V. ===
#              date_range ['2021-06-03', '2021-06-03']
#                   money ['100000', '3500000', '100000', '3500000', '100000', '3500000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/staatsloterij-0/
#               DOCUMENTS    (4 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/20220118_-_01_256_290_intrekkingsbesluit.pdf
#                            #pages 5
#                      header_dates []
#                            status None
#
#                               url https://kansspelautoriteit.nl/publish/library/32/20220224_-_01_258_184_openbaarmakingsbesluit_intrekkingsbesluit.pdf
#                            #pages 5
#                      header_dates []
#                            status None
#
#                               url https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_staatsloterij.pdf
#                            #pages 18
#                      header_dates ['2021-06-03']
#                            status Tegen dit besluit is bezwaar gemaakt
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_tot_openbaarmaking_staatsloterij.pdf
#                            #pages 5
#                      header_dates []
#                            status Tegen dit besluit is bezwaar gemaakt
#
#
#  === CASE: Raging Rhino N.V. ===
#              date_range ['2021-03-30', '2021-03-30']
#                   money ['440000', '440000', '870000', '10000', '10000', '18085', '870000', '870000', '10000', '200000', '75000', '75000', '75000', '50000', '25000', '350000', '90000', '440000', '440000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/raging-rhino/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_raging_rhino_n_v.pdf
#                            #pages 19
#                      header_dates ['2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30', '2021-03-30']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_tot_openbaarmaking_raging_rhino_n_v.pdf
#                            #pages 4
#                      header_dates ['2021-03-30', '2021-03-30', '2021-03-30']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: Lovelto Mar LTD ===
#              date_range []
#                   money ['6000', '30000', '6000', '6000', '24000', '6000', '30000', '30000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/lovelto-mar-ltd/
#               DOCUMENTS    (4 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01_237_092_-_invorderingsbeschikking_ov.pdf
#                            #pages 5
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01_237_093_-_besluit_openb_invorderingsbeschikking_ov.pdf
#                            #pages 4
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/lod_ov.pdf
#                            #pages 11
#                      header_dates []
#                            status Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen niet zijn gestaakt. Er zijn dwangsommen verbeurd. Nadien zijn de overtredingen gestaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01_077_647_-_besluit_openbaarmaking_-_ov_1.pdf
#                            #pages 5
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk. De Kansspelautoriteit legde Lovelto Mar LTD eind vorig jaar een last onder dwangsom op wegens het reclame maken voor illegale aanbieders.
#
#
#  === CASE: 1X Corp N.V._Exinvest Limited ===
#              date_range ['2019-01-04', '2019-04-26']
#                   money ['400000', '400000', '830000', '50000', '200000', '400000', '600000', '5000000', '830000', '830000', '820000', '830000', '50000', '600000', '100000', '150000', '400000', '400000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/1x-corp-exinvest/
#               DOCUMENTS    (4 of them)
#
#                               url https://kansspelautoriteit.nl/publish/pages/5945/12924_advies_bac_ov.pdf
#                            #pages 20
#                      header_dates ['2019-04-26']
#                            status Het beroep tegen deze beslissing is ingetrokken. De beslissing is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5945/12924_besluit_openbaarmaking_bob_ov.pdf
#                            #pages 3
#                      header_dates []
#                            status De beslissing is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5945/12924_-_01_047_552_sanctiebesluit_-_openbare_versie_met_logo_1.pdf
#                            #pages 28
#                      header_dates ['2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04', '2019-01-04']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5945/12924_-_01_047_553_openbaarmakingsbesluit_-_openbare_versie_met_logo_1.pdf
#                            #pages 5
#                      header_dates []
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#
#  === CASE: WL Deal ===
#              date_range []
#                   money ['20000', '20000', '20000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/wl-deal/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01_079_482_besluit_lod_wl_deal_openbaar.pdf
#                            #pages 9
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk
#
#                               url https://kansspelautoriteit.nl/publish/library/32/01_079_484_besluit_openbaarmaking_lod_wl_deal_openbaar.pdf
#                            #pages 4
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk
#
#
#  === CASE: Virtual Coin Gaming N.V. ===
#              date_range ['2020-12-15', '2021-07-13']
#                   money ['500000', '100000', '150000', '25000', '25000', '50000', '50000', '50000', '500000', '100000', '830000', '150000', '50000', '200000', '50000', '500000', '500000', '100000', '500000', '100000', '500000', '100000', '830000', '150000', '200000', '100000', '50000', '50000', '50000', '50000', '100000', '500000', '100000', '500000', '100000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/virtual-coin-gaming/
#               DOCUMENTS    (6 of them)
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_op_bezwaar_virtual_coin_gaming.pdf
#                            #pages 8
#                      header_dates ['2021-07-13', '2021-07-13', '2021-07-13', '2021-07-13', '2021-07-13', '2021-07-13', '2021-07-13']
#                            status None
#
#                               url https://kansspelautoriteit.nl/publish/library/32/advies_van_de_adviescommissie_bezwaarschriften.pdf
#                            #pages 18
#                      header_dates []
#                            status Tegen de uitspraak van de rechtbank is geen hoger beroep ingesteld. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_virtual_coin_gaming.pdf
#                            #pages 3
#                      header_dates ['2021-07-13', '2021-07-13']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_betalingsweigering_virtual_coin_gaming_n_v.pdf
#                            #pages 3
#                      header_dates ['2021-06-01', '2021-06-01']
#                            status Virtual Coin Gaming N.V. heeft de boete niet betaald. De Ksa merkt dit aan als een betalingsweigering en is overgegaan tot een dwanginvordering.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/sanctiebesluit_futgalaxy_openbaar.pdf
#                            #pages 33
#                      header_dates ['2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/library/32/besluit_openbaarmaking_futgalaxy_openbaar.pdf
#                            #pages 5
#                      header_dates ['2020-12-15', '2020-12-15', '2020-12-15', '2020-12-15']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#
#  === CASE: Clipboard Publications B.V. ===
#              date_range []
#                   money ['50000', '50000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/clipboard/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/pages/7716/20200806_01_073_790_lod_bevorderen_ov.pdf
#                            #pages 10
#                      header_dates []
#                            status None
#
#                               url https://kansspelautoriteit.nl/publish/pages/7716/20200806_01_073_815_besluit_openbaarmaking_ov_1.pdf
#                            #pages 4
#                      header_dates []
#                            status Naar aanleiding van het besluit is gecontroleerd , hierbij is geconstateerd dat de overtreding is gestaakt. Bij brief van 28 juli 2020 is Clipboard Publications B.V. medegedeeld dat de last onder dwangsom is ingetrokken.
#
#
#  === CASE: Kelner Automaten Service ===
#              date_range []
#                   money []
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/kelner-automaten-service/
#               DOCUMENTS    (0 of them)
#
#
#  === CASE: Schinveld BV ===
#              date_range ['2020-01-30', '2020-01-30']
#                   money ['8652845', '8652845', '8652845', '86528', '74250', '9144', '86528', '93278', '86528']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/schinveld-bv/
#               DOCUMENTS    (5 of them)
#
#                               url https://kansspelautoriteit.nl/publish/pages/7397/beslissing_op_bezwaar.pdf
#                            #pages 3
#                      header_dates []
#                            status None
#
#                               url https://kansspelautoriteit.nl/publish/pages/7397/advies_bac.pdf
#                            #pages 11
#                      header_dates []
#                            status Tegen deze beslissing op bezwaar is inmiddels beroep ingesteld bij de rechtbank.
#
#                               url https://kansspelautoriteit.nl/publish/pages/7397/besluit_openbaarmaking_schinveld_bv.pdf
#                            #pages 4
#                      header_dates []
#                            status Het bezwaar tegen dit besluit is ingetrokken. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/7397/sanctiebesluit_schinveld_bv.pdf
#                            #pages 19
#                      header_dates ['2020-01-30', '2020-01-30', '2020-01-30', '2020-01-30', '2020-01-30', '2020-01-30', '2020-01-30', '2020-01-30', '2020-01-30', '2020-01-30', '2020-01-30', '2020-01-30', '2020-01-30', '2020-01-30', '2020-01-30', '2020-01-30']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/pages/7397/openbaarmakingsbesluit_schinveld_bv.pdf
#                            #pages 4
#                      header_dates ['2020-01-30', '2020-01-30', '2020-01-30']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#
#  === CASE: Voormalig exploitant Dordrecht ===
#              date_range []
#                   money []
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/voormalig-exploitant-1/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/pages/7169/01_066_052_besluit_lob_openbaar.pdf
#                            #pages 6
#                      header_dates []
#                            status Naar aanleiding van het besluit is gecontroleerd , hierbij is geconstateerd dat de overtreding is gestaakt. Bij brief van 27 november 2020 is medegedeeld dat de last onder bestuursdwang is ingetrokken.
#
#                               url https://kansspelautoriteit.nl/publish/pages/7169/01_066_053_besluit_openbaarmaking_lob_openbaar.pdf
#                            #pages 4
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: Voormalig exploitant Amersfoort ===
#              date_range []
#                   money []
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/voormalig-exploitant-0/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/pages/7119/01_062_613_besluit_lob_openbaar.pdf
#                            #pages 6
#                      header_dates []
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk. Naar aanleiding van het besluit is gecontroleerd, hierbij is geconstateerd dat de overtredingen zijn gestaakt. De last onder bestuursdwang is ingetrokken.
#
#                               url https://kansspelautoriteit.nl/publish/pages/7119/01_062_614_besluit_openbaarmaking_lob_openbaar.pdf
# ...
#
#                               url https://kansspelautoriteit.nl/publish/pages/5469/besluit_tot_openbaarmaking_koffiehuis_vadi_-_openbaar.pdf
#                            #pages 4
#                      header_dates ['2014-05-08', '2014-05-08', '2014-05-08']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: Gooische Bingo Show ===
#              date_range ['2014-03-11', '2014-03-11']
#                   money ['50000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/gooische-bingo-show/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/pages/5468/8090_-_00_023_231_sanctiebesluit_gooische_bingo_show.pdf
#                            #pages 21
#                      header_dates ['2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11', '2014-03-11']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5468/8090_-_00_023_232_openbaarmakingsbesluit_gooische_bingo_show.pdf
#                            #pages 4
#                      header_dates ['2014-03-11', '2014-03-11', '2014-03-11']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: Globalstars ===
#              date_range ['2013-12-05', '2013-12-05']
#                   money ['100000', '100000', '100000', '100000', '100000', '780000', '780000', '25000', '25000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/globalstars/
#               DOCUMENTS    (4 of them)
#
#                               url https://kansspelautoriteit.nl/publish/pages/5467/7822_sanctiebesluit_globalstars.pdf
#                            #pages 31
#                      header_dates []
#                            status Tegen deze beslissing is geen beroep ingesteld. De beslissing is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5467/7822_besluit_openbaarmaking_globalstars.pdf
#                            #pages 4
#                      header_dates []
#                            status Tegen deze beslissing is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5467/7822_-_00_019_152_besluit_op_bezwaar_inclusief_advies_bac_-_openbare_versie.pdf
#                            #pages 18
#                      header_dates ['2013-12-05', '2013-12-05']
#                            status None
#
#                               url https://kansspelautoriteit.nl/publish/pages/5467/7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf
#                            #pages 3
#                      header_dates ['2013-12-05', '2013-12-05']
#                            status None
#
#
#  === CASE: Grand Café Randenbroek ===
#              date_range ['2013-10-24', '2014-04-03']
#                   money ['780000', '20000', '7500', '21000', '40000', '21000', '40000', '40000', '780000', '810000', '40000', '25980', '21025', '25980', '21025', '7925', '6000', '780000', '40000', '40000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/grand-cafe/
#               DOCUMENTS    (4 of them)
#
#                               url https://kansspelautoriteit.nl/publish/pages/5466/besluit_op_bezwaar_openbaar_cafe_randenbroek.pdf
#                            #pages 12
#                      header_dates ['2014-04-03', '2014-04-03', '2014-04-03']
#                            status Tegen deze beslissing is geen beroep ingesteld. De beslissing is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5466/besluit_openbaarmaking_bob_openbaar_cafe_randenbroek.pdf
#                            #pages 3
#                      header_dates ['2014-04-03', '2014-04-03']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5466/7861_sanctiebesluit_grand_cafe_randenbroek.pdf
#                            #pages 19
#                      header_dates ['2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24', '2013-10-24']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5466/7861_besluit_openbaarmaking_grand_cafe_randenbroek.pdf
#                            #pages 4
#                      header_dates ['2013-10-24', '2013-10-24', '2013-10-24']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: Onisac Limited en Mansion Online Casino Limited ===
#              date_range ['2014-02-25', '2019-04-30']
#                   money ['450000', '450000', '450000', '830000', '830000', '21186', '21186', '150000', '150000', '200000', '200000', '50000', '450000', '450000', '150000', '780000', '150000', '150000', '150000', '150000', '780000', '780000', '100000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/onisac-limited/
#               DOCUMENTS    (9 of them)
#
#                               url https://kansspelautoriteit.nl/publish/pages/5465/190625_besluit_openbaarmaking_bob_onisac_openbaar_003.pdf
#                            #pages 3
#                      header_dates ['2019-04-30', '2019-04-30']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5465/190704_bob_en_bac.pdf
#                            #pages 12
#                      header_dates ['2019-04-30', '2019-04-30']
#                            status Het beroep tegen deze beslissing is ingetrokken. De beslissing is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5465/sanctiebesluit_onisac.pdf
#                            #pages 15
#                      header_dates ['2019-01-24', '2019-01-24', '2019-01-24', '2019-01-24', '2019-01-24', '2019-01-24', '2019-01-24', '2019-01-24', '2019-01-24', '2019-01-24', '2019-01-24', '2019-01-24', '2019-01-24', '2019-01-24']
#                            status Tegen dit sanctiebesluit is bezwaar ingediend
#
#                               url https://kansspelautoriteit.nl/publish/pages/5465/openbaarmakingsbesluit_sanctiebesluit_onisac.pdf
#                            #pages 4
#                      header_dates ['2019-01-24', '2019-01-24', '2019-01-24']
#                            status Tegen dit besluit is bezwaar ingediend
#
#                               url https://kansspelautoriteit.nl/publish/pages/5465/7845_00_021_663_-_sanctiebesluit_openbaar.pdf
#                            #pages 30
#                      header_dates []
#                            status In deze zaak is hoger beroep ingesteld en de Raad van State heeft www.raadvanstate.nl/uitspraken/zoeken-in-uitspraken/tekst-uitspraak.html?id=96664&summary_only=&q= gedaan op 26 september 2018.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5465/7845_00_021_664-_openbaarmaking_openbaar.pdf
#                            #pages 5
#                      header_dates []
#                            status In deze zaak is hoger beroep ingesteld en de Raad van State heeft www.raadvanstate.nl/uitspraken/zoeken-in-uitspraken/tekst-uitspraak.html?id=96664&summary_only=&q= gedaan op 26 september 2018.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5465/7845_-_advies_bac_ov_pdf.pdf
#                            #pages 17
#                      header_dates []
#                            status None
#
#                               url https://kansspelautoriteit.nl/publish/pages/5465/7845_-_beslissing_op_bezwaar_ov_pdf.pdf
#                            #pages 3
#                      header_dates ['2014-02-25', '2014-02-25']
#                            status Tegen deze beslissing op bezwaar is inmiddels beroep ingesteld bij de rechtbank.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5465/8051_-_besluit_openbaarmaking_bob_ov_pdf.pdf
#                            #pages 3
#                      header_dates ['2014-02-25', '2014-02-25']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: Café Lucky ===
#              date_range ['2013-11-14', '2014-03-28']
#                   money ['20000', '780000', '20000', '7500', '12000', '20000', '12000', '20000', '20000', '780000', '84558', '26222', '20000', '84558', '26222', '780000', '20000', '20000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/cafe-lucky/
#               DOCUMENTS    (4 of them)
#
#                               url https://kansspelautoriteit.nl/publish/pages/5464/besluit_op_bezwaar_openbaar_cafe_lucky.pdf
#                            #pages 13
#                      header_dates ['2014-03-28', '2014-03-28', '2014-03-28']
#                            status Tegen de beslissing van de rechtbank is geen hoger beroep ingesteld. De uitspraak van de rechtbank is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5464/besluit_openbaarmaking_bob_openbaar_cafe_lucky.pdf
#                            #pages 3
#                      header_dates ['2014-03-28']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5464/7938_-_00_018_637_sanctiebesluit_openbare_versie.pdf
#                            #pages 16
#                      header_dates ['2013-11-14', '2013-11-14', '2013-11-14', '2013-11-14', '2013-11-14', '2013-11-14', '2013-11-14', '2013-11-14', '2013-11-14', '2013-11-14', '2013-11-14', '2013-11-14', '2013-11-14', '2013-11-14', '2013-11-14']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5464/7938_besluit_openbaarmaking_cafe_lucky.pdf
#                            #pages 4
#                      header_dates ['2013-11-14', '2013-11-14']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#
#  === CASE: Star SAT Electronica ===
#              date_range ['2013-11-21', '2013-11-21']
#                   money ['20000', '10511', '7705', '780000', '20000', '20000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/star-sat-electronica/
#               DOCUMENTS    (2 of them)
#
#                               url https://kansspelautoriteit.nl/publish/pages/5463/7971_-_00_019_052_sanctiebesluit_openbare_versie.pdf
#                            #pages 14
#                      header_dates ['2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5463/7971_besluit_openbaarmaking_star_sat_electronica.pdf
#                            #pages 3
#                      header_dates ['2013-11-21', '2013-11-21']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: Call Internet City ===
#              date_range ['2013-11-21', '2014-04-10']
#                   money ['780000', '7500', '6000', '20000', '6000', '20000', '20000', '70000', '20000', '780000', '810000', '780000', '20000', '20000', '61329', '16196', '780000', '20000', '20000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/call-internet-city/
#               DOCUMENTS    (4 of them)
#
#                               url https://kansspelautoriteit.nl/publish/pages/5462/besluit_op_bezwaar_openbaar_call_internet_city.pdf
#                            #pages 9
#                      header_dates ['2014-04-10', '2014-04-10', '2014-04-10']
#                            status Tegen deze beslissing is geen beroep ingesteld. De beslissing is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5462/7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf
#                            #pages 3
#                      header_dates ['2013-12-05', '2013-12-05']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5462/7970_sanctiebesluit_call_internet_city.pdf
#                            #pages 13
#                      header_dates ['2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21', '2013-11-21']
#                            status Tegen dit besluit is bezwaar gemaakt.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5462/7970_besluit_openbaarmaking_call_internet_city.pdf
#                            #pages 3
#                      header_dates ['2013-11-21', '2013-11-21']
#                            status Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.
#
#
#  === CASE: Huizenloterij ===
#              date_range ['2014-04-30', '2014-04-30']
#                   money ['20000', '30000', '780000']
#                    ecli []
#         case_detail_url https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/huizenloterij/
#               DOCUMENTS    (4 of them)
#
#                               url https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_020_754_kennisgeving_als_bedoeld_in_art_5_50_lid_2_sub_a_awb_openbaar.pdf
#                            #pages 26
#                      header_dates []
#                            status None
#
#                               url https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_020_755_besluit_tot_openbaarmaking_openbaar.pdf
#                            #pages 4
#                      header_dates []
#                            status None
#
#                               url https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_026_508_en_8140_-_00_026_510_besluit_op_bezwaar_openbaar1.pdf
#                            #pages 15
#                      header_dates ['2014-04-30', '2014-04-30', '2014-04-30']
#                            status In deze zaak is beroep ingesteld en de rechtbank heeft uitspraak gedaan op 17 februari 2015. Het beroep is ongegrond verklaard.
#
#                               url https://kansspelautoriteit.nl/publish/pages/5461/7982_-_00_025_509_en_8140_-_00_026_511_besluit_openbaarmaking_bob_openbaar1.pdf
#                            #pages 3
#                      header_dates ['2014-04-30', '2014-04-30']
#                            status Het hoger beroep tegen de uitspraak van de rechtbank is ingetrokken. De uitspraak van de rechtbank is thans definitief.

# %%
# For example, the first page  in the first document  of the first case
pprint.pprint( cases[0]['docs'][0]['pages'][0] )
# Out:
# {'date_range': ['2022-12-20', '2022-12-20'],
#  'docs': [{'header_dates': ['2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20',
#                             '2022-12-20'],
#            'pages': [{'body_text': ['Besluit van de raad van bestuur van de '
#                                     'Kansspelautoriteit als bedoeld in artikel '
#                                     '35a van de Wet op de kansspelen tot '
#                                     'oplegging van een boete aan Probe '
#                                     'Investments Limited .',
#                                     'Zaak: 15269 Kenmerk: 15269 01.281.230 '
#                                     'Openbaarmaking onder kenmerk: 15269 '
#                                     '01.281.231',
#                                     'Besluit',
#                                     'Inleiding',
#                                     'De raad van bestuur van de '
#                                     'Kansspelautoriteit (hierna: de '
#                                     'Kansspelautoriteit) is belast met het '
#                                     'toezicht op de naleving van de Wet op de '
#                                     'kansspelen (hierna: Wok) . De Wok bevat '
#                                     'een verbod op het gelegenheid geven tot '
#                                     'deelname aan kansspelen zonder '
#                                     'vergunning. Het handhaven van dit verbod '
#                                     'is één van de prioriteiten van de '
#                                     'Kansspelautoriteit. In dit besluit stelt '
#                                     'de Kansspelautoriteit vast dat Probe '
#                                     'Investments Limited (hierna: PIL) dit '
#                                     'verbod heeft overtreden. Daarom wordt '
#                                     'haar een boete van € 1.128.000,- '
#                                     'opgelegd. De Kansspelautoriteit zet dat '
#                                     'hieronder nader uiteen',
#                                     'Onderzoek naar website en betrokkene',
#                                     'De website',
#                                     'De Kansspelautoriteit heeft op 22 '
#                                     'december 2021 de website WWW '
#                                     'energycasino.com (hierna: de website) '
#                                     'onderzocht. 1 Daarbij is onder meer het '
#                                     'volgende gebleken. Gelegenheid tot '
#                                     'deelneming aan kansspelen',
#                                     'De website was bereikbaar vanaf een '
#                                     'Nederlands IP-adres en het was voor de '
#                                     'toezichthouder van de Kansspelautoriteit '
#                                     '(hierna: toezichthouder) mogelijk om met '
#                                     'Nederlandse (adres)gegevens een account '
#                                     'aan te maken, daarop in te',
#                                     'Rapport 14712/01.254.946, 31 augustus '
#                                     '2022.'],
#                       'foot_text': ['Pagina 1 van 27'],
#                       'head_text': ['Kansspelautoriteit', 'OPENBAAR']},
#                      {'body_text': ['loggen  een storting te doen en deel te '
#                                     'nemen aan kansspelen. 2 Er waren '
#                                     'technische maatregelen genomen om '
#                                     'deelnemers vanuit Nederland de toegang '
#                                     'tot de kansspelen te beletten.',
#                                     'Op de website werden casinospelen '
#                                     'aangeboden. 3 Deze spellen zijn aan te '
#                                     'merken als kansspelen.',
#                                     'Met deelname aan de kansspelen kan worden '
#                                     'meegedongen naar prijzen of premies. Dat '
#                                     'is onder andere gebleken uit deelname van '
#                                     'de toezichthouder aan de kansspelen en '
#                                     'promotionele teksten op de website '
#                                     'waaruit blijkt dat er geldprijzen te '
#                                     'winnen zijn.',
#                                     'Op de website stond vermeld dat PIL is '
#                                     'gevestigd in Malta en een vergunning '
#                                     'heeft in Groot-Brittannië en in Malta '
#                                     'voor het aanbieden van kansspelen. 4',
#                                     'Bij het inschrijvingsproces werd de '
#                                     'leeftijd niet zichtbaar geverifieerd '
#                                     'voordat het inschrijvingsproces was '
#                                     'voltooid. 2.1.2 Gerichtheid op de '
#                                     'Nederlandse markt Zoals benoemd onder '
#                                     'randnummer 3 was de website bereikbaar '
#                                     'vanaf een Nederlands IP-adres en kon '
#                                     'vanuit Nederland een account worden '
#                                     'aangemaakt en deelgenomen aan kansspelen.',
#                                     'Uit de data van Similarweb blijkt dat de '
#                                     'website veelvuldig vanuit Nederland is '
#                                     'bezocht.',
#                                     'Bij het inschrijvingsproces werd de optie '
#                                     "'Netherlands' aangeboden in een aantal "
#                                     "keuzemenu's en was deze reeds ingevuld. 8",
#                                     'Bij het inschrijvingsproces werd bij het '
#                                     'telefoonnummer de landcode van Nederland '
#                                     '(+31) automatisch ingevuld.',
#                                     'Bij het inschrijvingsproces was een '
#                                     'Nederlandse vlag zichtbaar. 10',
#                                     'Bijlage 14712/01.254.945/02. Bijlage '
#                                     '14712/01.254.945/03. Bijlage '
#                                     '14712/01.254.945/04. Bijlage '
#                                     '14712/01.254.945/01. Bijlage '
#                                     '14712/01.254.945/01 . Bijlage '
#                                     '14712/01.270.022. Bijlage '
#                                     '14712/01.254.945/01. Bijlage '
#                                     '14712/01.254.945/01. Bijlage '
#                                     '14712/01.254.945/01.'],
#                       'foot_text': ['Pagina', '2 van 27'],
#                       'head_text': ['OPENBAAR',
#                                     'Kansspelautoriteit',
#                                     'Kansspelautoriteit',
#                                     'Datum',
#                                     '20 december 2022',
#                                     'Ons kenmerk',
#                                     '15269/01.2581.230']},
#                      {'body_text': ['Nederland was niet aangemerkt als '
#                                     'uitgesloten land in het overzicht van '
#                                     'Excluded Countries" in de Terms & '
#                                     'Conditions (hierna: T&Cs).11',
#                                     'Er is door de toezichthouder vanuit een '
#                                     'Nederlandse bank en betaalrekening een '
#                                     'storting van € 10,- op de spelersrekening '
#                                     'verricht. De instructies over de betaling '
#                                     'waren gedeeltelijk in de Nederlandse '
#                                     'taal. De betaling was gericht aan PIL. 12',
#                                     'Daarnaast was de website internationaal '
#                                     'georiënteerd, waaruit medegerichtheid op '
#                                     'Nederland bleek. Spelers konden geld '
#                                     'storten in diverse munteenheden, '
#                                     'waaronder de euro. Zowel de website, als '
#                                     'de klantenservice, was beschikbaar in de '
#                                     'Engelse taal. Er was sprake van een '
#                                     'internationale topleveldomeinnaam, '
#                                     'namelijk een com-extensie. Ook had PIL '
#                                     'voor spelers op de website een '
#                                     'internationaal telefoonnummer opengesteld '
#                                     'en werd een internationale clientèle '
#                                     'genoemd.',
#                                     '2.1.3 Last onder dwangsom 16. Op 7 april '
#                                     '2022 heeft de Kansspelautoriteit een '
#                                     'voorgenomen last onder dwangsom aan PIL '
#                                     'verstuurd. 13',
#                                     'Naar aanleiding hiervan is de website op '
#                                     '25 april 2022 nogmaals onderzocht. De '
#                                     'Kansspelautoriteit heeft onderzocht of er '
#                                     'gelegenheid werd gegeven om vanuit '
#                                     'Nederland deel te nemen aan kansspelen. '
#                                     'Daaruit bleek dat het niet meer mogelijk '
#                                     'was om vanuit Nederland deel te nemen aan '
#                                     'kansspelen.',
#                                     'Op 4 mei 2022 heeft de Kansspelautoriteit '
#                                     'aan PIL een brief gestuurd waarin is '
#                                     'aangegeven dat de Kansspelautoriteit '
#                                     'afziet van het opleggen van een last '
#                                     'onder dwangsom. In deze brief is '
#                                     'aangegeven dat indien wederom wordt '
#                                     'geconstateerd dat PIL gelegenheid geeft '
#                                     'aan consumenten om vanuit Nederland deel '
#                                     'te nemen aan kansspelen, de '
#                                     'Kansspelautoriteit alsnog zal overgaan '
#                                     'tot het opleggen van een last onder '
#                                     'dwangsom. Vervolgens is PIL gewezen dat '
#                                     'de Kansspelautoriteit tevens kan '
#                                     'besluiten een boete op te leggen conform '
#                                     'de Boetebeleidsregels voor het aanbieden '
#                                     'van kansspelen op afstand zonder 14 '
#                                     'vergunning .',
#                                     'Bijlage 14712/01.254.945/05. Bijlage '
#                                     '14712/01.254.945/02. 13 Kenmerk: '
#                                     '14712/01.254.945. Boetebeleidsregels voor '
#                                     'het aanbieden van kansspelen op afstand '
#                                     'zonder vergunning, Stcrt. 2021, 41413.'],
#                       'foot_text': ['Pagina 3 van 27'],
#                       'head_text': ['OPENBAAR',
#                                     'Kansspelautoriteit',
#                                     'Kansspelautoriteit',
#                                     'Datum',
#                                     '20 december 2022',
#                                     'Ons kenmerk',
#                                     '15269/01.2581.230']},
#                      {'body_text': ['De betrokkene',
#                                     'Naast de website is ook de betrokkene '
#                                     'onderzocht. Blijkens het onderzoek biedt '
#                                     'PIL gelegenheid tot deelname aan de '
#                                     'kansspelen op de website. Dat blijkt '
#                                     'onder meer uit het volgende. Op de '
#                                     'website staan de contactgegevens en '
#                                     'vergunningen van PIL vermeld. 15 De '
#                                     'website waarop kansspelen worden '
#                                     'aangeboden, staat geregistreerd op naam '
#                                     'van PIL. 16 Volgens de informatie op de '
#                                     'websitel7 exploiteert PIL de website '
#                                     'Onderaan de homepagina staat PIL als '
#                                     'eigenaar van de website genoemd. 18 '
#                                     'Daarbij is tevens vermeld dat PIL over '
#                                     'kansspelvergunningen beschikt van de UK '
#                                     'Gambling Commission en de Malta Gaming '
#                                     'Authority (MGA). Bovendien is PIL '
#                                     'blijkens de T8Cs de wederpartij met wie '
#                                     'de speler een overeenkomst sluit.',
#                                     'Rapport',
#                                     'De Kansspelautoriteit heeft op grond van '
#                                     'de hierboven genoemde onderzoeken op 31 '
#                                     'augustus 2022 een rapport (hierna: het '
#                                     'rapport) opgesteld. In het rapport is '
#                                     'geconstateerd dat PIL door middel van de '
#                                     'website gelegenheid heeft gegeven om mede '
#                                     'te dingen naar prijzen of premies, '
#                                     'waarbij de aanwijzing van de winnaars '
#                                     'geschiedt door enige kansbepaling waarop '
#                                     'de deelnemers in het algemeen overwegende '
#                                     'invloed kunnen uitoefenen, terwijl '
#                                     'daarvoor geen vergunning is verleend. Dat '
#                                     'is een overtreding van artikel 1, eerste '
#                                     'lid, aanhef en onder a, van de Wok.',
#                                     'Zienswijze',
#                                     'Procedureel',
#                                     'Bij brief van 21 oktober 2022 heeft '
#                                     '[advocaat 1] namens PIL een schriftelijke '
#                                     'zienswijze gegeven op het rapport.',
#                                     'Op 1 november 2022 hebben [advocaat 1], '
#                                     '[advocaat 2] en [advocaat 3] namens PIL '
#                                     'de schriftelijke zienswijze mondeling '
#                                     'toegelicht. Op 7 november 2022 is het '
#                                     'verslag van de hoorzitting per e-mail '
#                                     'naar PIL verzonden. Op 14 november 2022 '
#                                     'heeft PIL gereageerd op het verslag.',
#                                     'Bijlage 14712/01.254.945/04. Bijlage '
#                                     '14712/01.254.945/04 . Bijlage '
#                                     '14712/01.254.945/04. Bijlage '
#                                     '14712/01.254.945/04.'],
#                       'foot_text': ['Pagina', '4 van 27'],
#                       'head_text': ['OPENBAAR',
#                                     'Kansspelautoriteit',
#                                     'Kansspelautoriteit',
#                                     'Datum',
#                                     '20 december 2022',
#                                     'Ons kenmerk',
#                                     '15269/01.2581.230']},
#                      {'body_text': ['Inhoudelijk',
#                                     'Namens PIL is aangevoerd dat het rapport '
#                                     'niet als basis kan dienen voor het '
#                                     'opleggen van een sanctie. Het rapport kan '
#                                     'niet in stand blijven en dient te worden '
#                                     'ingetrokken of te worden herroepen. '
#                                     'Samengevat voert PIL aan dat: a er geen '
#                                     'grond bestaat om het rapport op te '
#                                     'stellen, nu PIL reeds in april 2022 een '
#                                     'voornemen tot het opleggen van een last '
#                                     'onder dwangsom van de Kansspelautoriteit '
#                                     'heeft ontvangen  waarna PIL vrijwillig en '
#                                     'onmiddellijk aan de voorgenomen last '
#                                     'heeft voldaan; b. de Kansspelautoriteit '
#                                     'niet tot de conclusie had kunnen komen '
#                                     'dat er sprake is van strijd met artikel '
#                                     '1, eerste lid, aanhef en onder a, van de '
#                                     'Wok, omdat PIL gelegenheid om vanuit '
#                                     'Nederland deel te nemen aan haar online '
#                                     'kansspelen en de website niet gericht was '
#                                     'op Nederland; c het rapport onzorgvuldig '
#                                     'tot stand is gekomen, niet objectief is '
#                                     'en meer in algemene zin onduidelijk is en '
#                                     'dat van een werkelijke toetsing van de '
#                                     'feitelijke constateringen aan het '
#                                     'wettelijk (en beleidsmatig) kader geen '
#                                     'sprake is; en d. de Kansspelautoriteit op '
#                                     'onwettige en onzorgvuldige wijze de '
#                                     'relevante omzet van PIL heeft bepaald, '
#                                     'waarmee sprake is van strijd met het '
#                                     'rechtszekerheidsvereiste en het '
#                                     'evenredigheidsvereiste.',
#                                     'De Kansspelautoriteit zal hieronder '
#                                     'ingaan op deze punten.',
#                                     'Juridische beoordeling',
#                                     'De wettelijke bepalingen',
#                                     'Artikel 1, eerste lid, aanhef en onder a, '
#                                     'van de Wok bepaalt dat het verboden is om '
#                                     'gelegenheid te geven om mede te dingen '
#                                     'naar prijzen of premies, indien de '
#                                     'aanwijzing der winnaars geschiedt door '
#                                     'enige kansbepaling waarop de deelnemers '
#                                     'geen overwegende invloed kunnen '
#                                     'uitoefenen  tenzij daarvoor ingevolge '
#                                     'deze wet vergunning is verleend .',
#                                     'Artikel 35a, eerste lid, van de Wok '
#                                     'bepaalt dat de Kansspelautoriteit een '
#                                     'bestuurlijke boete kan opleggen wegens '
#                                     'overtreding van onder andere de '
#                                     'voorschriften vastgesteld bij of '
#                                     'krachtens artikel 1, eerste lid, onder a.',
#                                     'Artikel 35a, tweede lid, van de Wok '
#                                     'bepaalt dat de bestuurlijke boete die '
#                                     'voor een overtreding als bedoeld in het '
#                                     'eerste lid kan worden opgelegd ten '
#                                     'hoogste het bedrag van de zesde '
#                                     'categorie  bedoeld in artikel 23, vierde '
#                                     'lid, van het Wetboek'],
#                       'foot_text': ['Pagina', '5 van 27'],
#                       'head_text': ['OPENBAAR',
#                                     'Kansspelautoriteit',
#                                     'Kansspelautoriteit',
#                                     'Datum',
#                                     '20 december 2022',
#                                     'Ons kenmerk',
#                                     '15269/01.2581.230']},
#                      {'body_text': ['van Strafrecht bedraagt of, indien dat '
#                                     'meer is, tien procent van de omzet in het '
#                                     'boekjaar voorafgaande aan de beschikking.',
#                                     'Artikel 23, vierde lid, van het Wetboek '
#                                     'van Strafrecht bepaalt dat het hiervoor '
#                                     'bedoelde bedrag van de zesde categorie € '
#                                     '900.000, - is.',
#                                     'Aanleiding voor het bestuurlijk rapport',
#                                     '29 . PIL voert aan dat er geen grond was '
#                                     'om een sanctieonderzoek te starten, '
#                                     'althans dat dit onevenredig en '
#                                     'onzorgvuldig is. Na ontvangst van het '
#                                     'voornemen last onder dwangsom in april '
#                                     '2022 heeft PIL zich coöperatief '
#                                     'opgesteld. In dat licht acht PIL het '
#                                     'alsnog opmaken van een rapport op grond '
#                                     'van artikel 5.48 van de Algemene wet '
#                                     'bestuursrecht (kennelijk met het doel om '
#                                     'alsnog een boete op te leggen) '
#                                     'onevenredig .',
#                                     'Bovendien vindt PIL het opmerkelijk dat '
#                                     'het rapport pas nu is opgesteld en niet '
#                                     'in het kader van de voorgenomen last '
#                                     'onder dwangsom.',
#                                     'Volgens vaste jurisprudentie kunnen een '
#                                     'toezichthoudend bestuursorgaan en de bij '
#                                     'haar werkzame toezichthouders om adequaat '
#                                     'toezicht te kunnen uitoefenen op de '
#                                     'naleving van de bij en krachtens de wet '
#                                     'gestelde regels, beschikken over '
#                                     'verschillende bevoegdheden die zij steeds '
#                                     'en spontaan kunnen uitoefenen. 19 Het '
#                                     'aanbieden van online kansspelen die zijn '
#                                     'gericht op de Nederlandse markt zonder de '
#                                     'daarvoor benodigde vergunning was zonder '
#                                     'uitzondering verboden en tegen illegale '
#                                     'aanbieders kan, ook spontaan, door de '
#                                     'Kansspelautoriteit handhavend worden '
#                                     'opgetreden. 20 Het argument kan daarom '
#                                     'geen doel treffen.',
#                                     'Ten aanzien van het voornemen tot het '
#                                     'opleggen van een last onder dwangsom '
#                                     'overweegt de Kansspelautoriteit als '
#                                     'volgt. Niet in geschil is dat PIL na het '
#                                     'voornemen last onder dwangsom de '
#                                     'overtreding beëindigd heeft. De website '
#                                     'was immers niet meer bereikbaar vanuit '
#                                     'Nederland. Dit maakt echter nog niet dat '
#                                     'het onevenredig is dat nu een boete wordt '
#                                     'opgelegd.',
#                                     'Een (voornemen) last onder dwangsom is '
#                                     'een herstelsanctie. Het doel hiervan is '
#                                     'om de overtreding te doen beëindigen. De '
#                                     'boete is een punitieve sanctie. Daarbij '
#                                     'is het doel om (ook) leed toe te voegen, '
#                                     'als straf voor de overtreding (speciale '
#                                     'preventie) . Daarnaast heeft een '
#                                     'punitieve sanctie een afschrikkende '
#                                     'werking',
#                                     'College van Beroep voor het bedrijfsleven '
#                                     '15 oktober 2019, ECLI:NL:CBB:2019.496, '
#                                     'r.o 4.5. Afdeling 29 juni 2022, '
#                                     'ECLI:NL:RVS:2022:1833 (Corona Limited) , '
#                                     'r.o 10.2.'],
#                       'foot_text': ['Pagina', '6 van 27'],
#                       'head_text': ['OPENBAAR',
#                                     'Kansspelautoriteit',
#                                     'Kansspelautoriteit',
#                                     'Datum',
#                                     '20 december 2022',
#                                     'Ons kenmerk',
#                                     '15269/01.2581.230']},
#                      {'body_text': ['(generale preventie). Het enkel opleggen '
#                                     'van een (voornemen) last onder dwangsom '
#                                     'zou tot gevolg hebben dat een illegale '
#                                     'aanbieder ongestraft kan aanbieden totdat '
#                                     'er een herstelsanctie wordt opgelegd. Een '
#                                     'last onder dwangsom heeft immers geen, of '
#                                     'in veel mindere mate, een '
#                                     'afschrikwekkende werking. Kortom, het '
#                                     'voornemen last onder dwangsom en het '
#                                     'opstarten van deze sanctieprocedure, met '
#                                     'dit boetebesluit tot gevolg, dienen twee '
#                                     'verschillende doelen. Dat alsnog een '
#                                     'rapport is opgemaakt na het voornemen '
#                                     'last onder dwangsom maakt dan ook niet '
#                                     'dat dit onevenredig of onzorgvuldig is. '
#                                     'De Kansspelautoriteit volgt het standpunt '
#                                     'van PIL dan ook niet.',
#                                     'Vertrouwensbeginsel',
#                                     '34 . PIL heeft aangevoerd dat '
#                                     'gerechtvaardigd vertrouwen was gewekt dat '
#                                     'er geen sanctie opgelegd zou worden. Na '
#                                     'het voornemen last onder dwangsom heeft '
#                                     'zij namelijk een brief ontvangen waarin '
#                                     'stond dat er geen last onder dwangsom zou '
#                                     "worden opgelegd, maar dat als er weer' "
#                                     'een overtreding zou plaatsvinden er '
#                                     'alsnog een last onder dwangsom kon worden '
#                                     'opgelegd en dat de Kansspelautoriteit '
#                                     '"tevens kan besluiten" een bestuurlijke '
#                                     'boete op te leggen. Uit deze brief van 4 '
#                                     'mei 2022 stelt PIL gerechtvaardigd '
#                                     'vertrouwen te kunnen ontlenen dat het '
#                                     'dossier met deze brief was gesloten. Door '
#                                     'alsnog een rapport op te maken, wordt in '
#                                     'strijd met het vertrouwensbeginsel '
#                                     'gehandeld, aldus PIL',
#                                     'Wie zich beroept op het '
#                                     'vertrouwensbeginsel moet aannemelijk '
#                                     'maken dat van de kant van de overheid '
#                                     'toezeggingen of andere uitlatingen zijn '
#                                     'gedaan of gedragingen zijn verricht '
#                                     'waaruit zij in de gegeven omstandigheden '
#                                     'redelijkerwijs kon en mocht afleiden of '
#                                     'het bestuursorgaan een bepaalde '
#                                     'bevoegdheid zou uitoefenen en zo ja hoe. '
#                                     'In deze zaak moet dus worden beoordeeld '
#                                     'of met de aan PIL toegezonden brief van 4 '
#                                     'mei 2022 een toezegging of uitlating is '
#                                     'gedaan, waaruit PIL redelijkerwijs kon en '
#                                     'mocht afleiden dat de Kansspelautoriteit '
#                                     'niet handhavend zou optreden tegen haar.',
#                                     'In de brief van 4 mei 2022 heeft de '
#                                     'Kansspelautoriteit aan PIL laten weten '
#                                     'dat er geen last onder dwangsom zal '
#                                     'worden opgelegd. Verder staat in de '
#                                     'brief: Indien wederom wordt geconstateerd '
#                                     'dat u gelegenheid geeft aan consumenten '
#                                     'om vanuit Nederland deel te nemen aan '
#                                     'kansspelen  waaronder, maar niet '
#                                     'uitsluitend, via de onderzochte website '
#                                     'of een andere website of kansspelapp  zal '
#                                     'de Kansspelautoriteit alsnog overgaan tot '
#                                     'het opleggen van een last onder dwangsom. '
#                                     'De Kansspelautoriteit er evenwel vanuit '
#                                     'dat in de toekomst van een overtreding '
#                                     'van de Wok geen sprake meer zal zijn en '
#                                     'een last onder dwangsom niet nodig is. '
#                                     'gaat'],
#                       'foot_text': ['Pagina', '7 van 27'],
#                       'head_text': ['OPENBAAR',
#                                     'Kansspelautoriteit',
#                                     'Kansspelautoriteit',
#                                     'Datum',
#                                     '20 december 2022',
#                                     'Ons kenmerk',
#                                     '15269/01.2581.230']},
#                      {'body_text': ['Tot slot wijzen wij u erop dat de '
#                                     'Kansspelautoriteit tevens kan besluiten u '
#                                     'een boete op te leggen conform de '
#                                     'Boetebeleidsregels voor het aanbieden van '
#                                     'kansspelen op afstand zonder vergunning.',
#                                     'De Kansspelautoriteit volgt PIL niet in '
#                                     'haar standpunt dat zij aan deze brief '
#                                     'gerechtvaardigd vertrouwen heeft kunnen '
#                                     'ontlenen. In de brief van 4 mei 2022 is '
#                                     'enkel en ondubbelzinnig gezegd dat er op '
#                                     'dat moment geen last onder dwangsom zal '
#                                     'worden opgelegd, maar dat dit bij een '
#                                     'nieuwe overtreding alsnog gedaan kan '
#                                     'worden. Daarnaast is juist expliciet '
#                                     'benoemd dat er een boete opgelegd kan '
#                                     'worden. Dit staat bovendien in een aparte '
#                                     'alinea. Met de term "tevens" is hier '
#                                     'evident bedoeld "aanvullend op\' Nergens '
#                                     'in de brief van 4 mei 2022 staat dat er '
#                                     'niet een boete opgelegd kan worden voor '
#                                     'de overtreding waarop het voornemen ziet '
#                                     'of dat het eventueel opleggen van een '
#                                     'boete pas zou spelen bij een nieuwe, '
#                                     'toekomstige overtreding . Dat PIL uit '
#                                     'deze brief heeft opgemaakt dat er geen '
#                                     'vervolgstappen meer zouden zijn omdat dat '
#                                     'dossier was gesloten; is haar eigen '
#                                     'interpretatie en dus onvoldoende om te '
#                                     'kunnen spreken van gerechtvaardigd '
#                                     'vertrouwen.',
#                                     'Gerichtheid op de Nederlandse markt en '
#                                     'prioriteringscriteria',
#                                     '5.4.1 Gerichtheid op Nederland',
#                                     'Volgens PIL kunnen de door de Ksa '
#                                     'vastgestelde feiten en omstandigheden de '
#                                     '(juridische) conclusie niet dragen dat '
#                                     'PIL deelname vanuit Nederland mogelijk '
#                                     'maakt.',
#                                     '39 . Ter verdere onderbouwing verwijst '
#                                     'PIL naar het relevante EU recht, het '
#                                     'Ladbrokes-arrest en de '
#                                     'prioriteringscriteria21 van de '
#                                     'Kansspelautoriteit.',
#                                     'PIL stelt dat er geen sprake is van '
#                                     'gerichtheid op Nederland en dat zij ook '
#                                     'geen deelname vanuit Nederland mogelijk '
#                                     'maakt. Daarbij verwijst PIL naar artikel '
#                                     '6, eerste lid, onder b, van Rome I22 en '
#                                     'overweging 3.5.1 van het Ladbrokesarrest. '
#                                     '23',
#                                     'PIL stelt dat sprake moet zijn van een '
#                                     'mede op Nederland gerichte website, '
#                                     'waarbij toegang tot kansspelen wordt '
#                                     'geboden aan potentiële deelnemers in '
#                                     'Nederland én potentiële deelnemers in '
#                                     'Nederland via hun computer rechtstreeks',
#                                     'https: / '
#                                     '/kansspelautoriteit.nl/over-ons/publicaties/regels-leidraden/aanbieders-online '
#                                     '. kansspelen '
#                                     '/handhavingsbeleid-prioritering/ '
#                                     'Verordening (EG) nr. 593/2008 van het '
#                                     'Europees Parlement en de Raad van 17 juni '
#                                     '2008 inzake het recht dat van toepassing '
#                                     'is op verbintenissen uit overeenkomst . '
#                                     '23 HR 18 februari 2005, '
#                                     'ECLI:NL:HR:2005:AR4841.'],
#                       'foot_text': ['Pagina 8 van 27'],
#                       'head_text': ['OPENBAAR',
#                                     'Kansspelautoriteit',
#                                     'Kansspelautoriteit',
#                                     'Datum',
#                                     '20 december 2022',
#                                     'Ons kenmerk',
#                                     '15269/01.2581.230']},
#                      {'body_text': ['aan het spel kunnen deelnemen. Volgens '
#                                     'haar is aan geen van beide cumulatieve '
#                                     'criteria voldaan en is geen sprake van '
#                                     'gerichtheid op Nederland.',
#                                     'PIL voert verder aan dat het '
#                                     'bezoekersaantal vanuit Nederland '
#                                     'simpelweg wordt genoemd zonder enige '
#                                     'uitwerking hoe en of dit deelname aan '
#                                     'kansspelen vanuit Nederland mogelijk '
#                                     'maakt. Het bezoeken van een website is '
#                                     'volgens haar iets anders dan het '
#                                     'deelnemen aan kansspelen op die website.',
#                                     'Volgens de Kansspelautoriteit kan het '
#                                     'betoog van PIL niet slagen. De website '
#                                     'was mede op Nederland gericht. overweegt '
#                                     'daarbij het volgende.',
#                                     '44 . Volgens vaste jurisprudentie moet '
#                                     'bij de vraag of het via internet '
#                                     'aanbieden van kansspelen kan worden '
#                                     'beschouwd als het hier te lande door '
#                                     'artikel 1, aanhef en onder a, Wok '
#                                     'verboden "gelegenheid geven\' '
#                                     'vooropgesteld worden dat doel en '
#                                     'strekking van die bepaling tot een ruime '
#                                     'uitleg van dat begrip nopen. 24',
#                                     'Er is sprake van een overtreding van '
#                                     'artikel 1, aanhef en onder a, van de Wok '
#                                     'indien het voor een consument uit '
#                                     'Nederland mogelijk is om door middel van '
#                                     'een mede op Nederland gerichte website '
#                                     'deel te nemen aan een onlinekansspel. 25 '
#                                     'Het erom of aanbieders van kansspelen via '
#                                     'internet door de inrichting van hun '
#                                     'website de mogelijkheid bieden dat '
#                                     'Nederlandse ingezetenen via hun computer '
#                                     'rechtstreeks aan de kansspelen kunnen '
#                                     'deelnemen. In deze laatste situatie is '
#                                     'een maatregel die ertoe strekt dat een '
#                                     'aanbieder met de aan haar ter beschikking '
#                                     'staande software deelneming aan de '
#                                     'kansspelen via internet onmogelijk maakt, '
#                                     'niet disproportioneel te noemen. 26 De '
#                                     'voorzieningenrechter van de Rechtbank Den '
#                                     'Haag oordeelde: `Nu [A] niet stelt dat '
#                                     'zij deelname vanuit Nederland ten tijde '
#                                     'hier van belang onmogelijk heeft gemaakt; '
#                                     'kan het hier besproken argument van [A] '
#                                     'niet leiden tot twijfel aan de '
#                                     'rechtmatigheid van het sanctiebesluit. '
#                                     "'27",
#                                     'Volgens vaste jurisprudentie is het '
#                                     'daarbij niet relevant of kansspelaanbod '
#                                     'primair op Nederland is gericht: Voor de '
#                                     'vraag of artikel 1, aanhef en onder a, '
#                                     'van de Wok is overtreden, is namelijk, '
#                                     'anders dan [appellante] hebben aangevoerd '
#                                     ', niet relevant of het aanbod primair is '
#                                     "gericht op Nederland. '28",
#                                     '24 HR 18 februari 2005, '
#                                     'ECLI:NL:HR:2005:AR4841, r.o 3.3.2 '
#                                     '(Ladbrokes) . Afdeling 22 februari 2017, '
#                                     'ECLI:NL:RVS:2017:484 (Bluemay), r.0. 5 26 '
#                                     'HR 18 februari 2005, '
#                                     'ECLI:NL:HR:2005:AR4841, r.o. 3.6.9-3.6.10 '
#                                     '(Ladbrokes) ; vgI. Afdeling 30 juni 2021, '
#                                     'ECLI:NL:RVS:2021:1421, r.o. 11-11.1; '
#                                     'ECLI:NL:RVS:2021:1421, r.o. 7-7.1 '
#                                     '(dokteronline.com) 27 11 september 2018, '
#                                     'ECLI:NL:RBDHA:2018:16636 (Mr. Green) r.o. '
#                                     '7 Afdeling 22 februari 2017, '
#                                     'ECLI:NL:RVS:2017:484 (Bluemay) r.o. 5.'],
#                       'foot_text': ['Pagina 9 van 27'],
#                       'head_text': ['OPENBAAR',
#                                     'Kansspelautoriteit',
#                                     'Kansspelautoriteit',
#                                     'Datum',
#                                     '20 december 2022',
#                                     'Ons kenmerk',
#                                     '15269/01.2581.230']},
#                      {'body_text': ['47 . Verder wijst de Kansspelautoriteit '
#                                     'erop dat daadwerkelijke deelname door '
#                                     'spelers geen bestanddeel is van de '
#                                     'verbodsbepaling. Volgens vaste '
#                                     'jurisprudentie is dan ook niet vereist '
#                                     'dat de kansspelen in kwestie '
#                                     'daadwerkelijk (vanuit Nederland) zijn '
#                                     'gespeeld. 29',
#                                     'De Kansspelautoriteit heeft vastgesteld '
#                                     'dat PIL haar website zo had ingericht dat '
#                                     'toegang tot kansspelen werd geboden aan '
#                                     'potentiële deelnemers in Nederland en dat '
#                                     'potentiële deelnemers in Nederland via '
#                                     'hun computer rechtstreeks aan het spel '
#                                     'konden deelnemen. Daarbij wijst zij op '
#                                     'het volgende.',
#                                     'Net als daadwerkelijke deelname; is '
#                                     'daadwerkelijk websitebezoek geen '
#                                     'bestanddeel van artikel 1, eerste lid, '
#                                     'aanhef en onder a, van de Wok. Voor de '
#                                     'overtreding daarvan is niet vereist dat '
#                                     'een website daadwerkelijk (vanuit '
#                                     'Nederland) is bezocht. Dat neemt niet weg '
#                                     'dat rechtstreekse toegang vanuit '
#                                     'Nederland, daadwerkelijke websitebezoeken '
#                                     'vanuit Nederland, de mogelijkheid tot '
#                                     'registratie van spelers vanuit Nederland '
#                                     'en de mogelijkheid tot deelname vanuit '
#                                     'Nederland, kenmerken zijn van '
#                                     'medegerichtheid op Nederland. PIL heeft '
#                                     'de website zo ingericht dat spelers '
#                                     'vanuit Nederland rechtstreeks toegang '
#                                     'konden krijgen tot haar website3o , zich '
#                                     'daarop vanuit Nederland rechtstreeks '
#                                     'konden registreren en vanuit Nederland '
#                                     'rechtstreeks konden deelnemen aan haar '
#                                     'kansspelen.',
#                                     'De website had een internationale '
#                                     'topleveldomeinnaam  namelijk een com '
#                                     'extensie. Ook had het bedrijf voor '
#                                     'spelers op de website een internationaal '
#                                     'telefoonnummer opengesteld. Verder werd '
#                                     'een internationale clientèle genoemd. 31 '
#                                     'Spelers konden geld storten in diverse '
#                                     'munteenheden, waaronder de euro. PIL had '
#                                     'op haar website kansspelen en te winnen '
#                                     'prijzen geëtaleerd. Een dergelijke '
#                                     'internationale oriëntatie door PIL van '
#                                     'haar commerciële activiteiten is mede '
#                                     'gericht op Nederland.',
#                                     'Daar komt bij dat tijdens de registratie '
#                                     'Nederland al als land was ingevuld bij '
# ...
#                                     'ook in dit concrete geval in het belang '
#                                     'van',
#                                     'consumenten die aldus kennis kunnen nemen '
#                                     'van het feit dat ten aanzien van PIL is '
#                                     'vastgesteld dat zij in strijd heeft '
#                                     'gehandeld met artikel 1, eerste lid, '
#                                     'onder a, van de Wok en dat de '
#                                     'Kansspelautoriteit hiertegen heeft '
#                                     'opgetreden.',
#                                     'De Kansspelautoriteit neemt hierbij het '
#                                     'volgende in aanmerking .',
#                                     'De Afdeling bestuursrechtspraak van de '
#                                     'Raad van State (hierna: de Afdeling) '
#                                     'heeft bij uitspraak van 10 november 2010, '
#                                     'ECLI:NL:RVS:2010.B03468, bepaald: Het '
#                                     'boetebesluit is een bevoegd genomen '
#                                     'besluit in het kader van een aan het '
#                                     'college door de wetgever toegekende taak '
#                                     'om toezicht te houden op de naleving van '
#                                     'regelgeving en de daarmee samenhangende '
#                                     'bevoegdheid om handhavend op te treden '
#                                     'tegen overtreding van die regelgeving. In '
#                                     'het kader van deze toezichthoudende taak '
#                                     'dat boetebesluiten worden gepubliceerd, '
#                                     'zodat bekendheid wordt gegeven aan de '
#                                     'wijze van uitvoering van deze taak" '
#                                     '(overweging 2.5).',
#                                     'Ten aanzien van de vereiste '
#                                     'belangenafweging bepaalde de Afdeling in '
#                                     'voornoemde uitspraak: "Van een '
#                                     'onevenredige benadeling zal in gevallen '
#                                     'als de onderhavige naar het oordeel van '
#                                     'de Afdeling sprake kunnen zijn als het '
#                                     'boetebesluit uiteindelijk in rechte geen '
#                                     'stand houdt en de betrokken rechtspersoon '
#                                     'ten onrechte als overtreder kenbaar is '
#                                     'gemaakt. Of sprake is van onevenredige '
#                                     'benadeling hangt dan af van een oordeel '
#                                     'over de rechtmatigheid van het '
#                                     'boetebesluit.',
#                                     'Zienswijze en beoordeling',
#                                     '10. PIL stelt dat openbaarmaking van het '
#                                     'sanctiebesluit in strijd is met artikel '
#                                     '3.3 tweede lid, sub k (onder 4) van de '
#                                     'Wet open overheid (hierna: de Woo), '
#                                     'waarin een uitzondering is opgenomen voor '
#                                     'het openbaar maken van bestuurlijke '
#                                     'strafsancties. Hoewel dit artikel nog '
#                                     'niet in werking is getreden druist de '
#                                     'openbaarmaking van sanctiebesluiten in '
#                                     'tegen de bedoeling van dit artikel en is '
#                                     'daarmee naar zijn aard onevenredig, aldus '
#                                     'PIL'],
#                       'foot_text': [],
#                       'head_text': ['OPENBAAR',
#                                     'Kansspelautoriteit',
#                                     'Kansspelautoriteit',
#                                     'Datum',
#                                     '20 december 2022',
#                                     'Ons kenmerk',
#                                     '15269/01.281.234']},
#                      {'body_text': ['De Woo wil een transparante en actief '
#                                     'openbaar makende overheid. Artikel 3.1, '
#                                     'eerste lid, van de Woo bepaalt dat '
#                                     'bestuursorganen zoveel mogelijk '
#                                     'informatie uit eigen beweging openbaar '
#                                     'moeten maken (inspanningsverplichting) . '
#                                     'Deze brede verplichting krijgt invulling '
#                                     'doordat artikel 3.3 van de Woo bepaalt '
#                                     'welke soorten informatie in ieder geval '
#                                     'openbaar moeten worden gemaakt.',
#                                     'De Kansspelautoriteit volgt PIL niet in '
#                                     'het standpunt dat uit artikel 3.3 van de '
#                                     'Woo volgt dat sanctiebesluiten niet '
#                                     'openbaar mogen worden gemaakt. Nog '
#                                     'daargelaten dat de Kansspelautoriteit '
#                                     'niet gebonden is aan wetgeving die niet '
#                                     'in werking is getreden, zou dit immers '
#                                     'geen recht doen aan het doel van de '
#                                     'wetgever  namelijk een transparante '
#                                     'overheid . Op grond van artikel 3.1, '
#                                     'eerste lid van de Woo kan de '
#                                     'Kansspelautoriteit ook sanctiebesluiten '
#                                     'openbaar maken, behoudens voor zover de '
#                                     'artikelen 5.1, eerste, tweede en vijfde '
#                                     'lid, en 5.2 van de Woo aan openbaarmaking '
#                                     'in de weg staan of met de openbaarmaking '
#                                     'geen redelijk belang wordt gediend.',
#                                     '13. Deze afweging is in lijn met de '
#                                     'belangenafweging die plaatsvond bij '
#                                     'actieve openbaarmaking op grond van '
#                                     'artikel 8 van de Wet openbaarheid van '
#                                     'bestuur (voorloper van artikel 3.3, '
#                                     'eerste lid van de Woo) . Die afweging '
#                                     'houdt in dat het algemene belang dat met '
#                                     'openbaarmaking wordt gediend, moet worden '
#                                     'afgewogen tegen het belang van een '
#                                     'betrokkene om geen onevenredig nadeel te '
#                                     'lijden als gevolg van de publicatie. '
#                                     'Daarbij wordt aan het algemeen belang een '
#                                     'groot gewicht toegekend.',
#                                     'De Kansspelautoriteit wijst er verder op '
#                                     'dat de namen van natuurlijke personen en '
#                                     'de namen van rechtspersonen die in het '
#                                     'onderzoek zijn genoemd, maar van wie geen '
#                                     'overtreding is vastgesteld, nimmer '
#                                     'openbaar worden gemaakt. Verwijzingen '
#                                     'naar namen die genoemd worden in '
#                                     'jurisprudentie en reeds openbaar gemaakte '
#                                     'besluiten van de Kansspelautoriteit '
#                                     'vallen hier niet onder.',
#                                     'De Kansspelautoriteit merkt voorts op dat '
#                                     'er een groot belang is bij openbaarmaking '
#                                     'uit het oogpunt van '
#                                     'consumentenbescherming. De website '
#                                     'energycasino.com is mede gericht op de '
#                                     'Nederlandse markt. Het spelen van '
#                                     'kansspelen bij een aanbieder zonder '
#                                     'vergunning is een overtreding van artikel '
#                                     '1, eerste lid, aanhef en onder c, van de '
#                                     'Wok, als een speler ook bekend is met het '
#                                     'feit dat geen vergunning is verleend. '
#                                     'Deze strafbaarstelling richt zich '
#                                     'nadrukkelijk tot spelers.'],
#                       'foot_text': [],
#                       'head_text': ['OPENBAAR',
#                                     'Kansspelautoriteit',
#                                     'Kansspelautoriteit',
#                                     'Datum',
#                                     '20 december 2022',
#                                     'Ons kenmerk',
#                                     '15269/01.281.234']},
#                      {'body_text': ['16. Openbaarmaking geschiedt met het oog '
#                                     'op de hiervoor weergegeven belangen: het '
#                                     'informeren van consumenten  generale en '
#                                     'speciale preventie en transparantie van '
#                                     'het werk van de Kansspelautoriteit. '
#                                     'Openbaarmaking is derhalve zeer relevant. '
#                                     'Openbaarmaking is eens te meer van belang '
#                                     'omdat consumenten zo kunnen worden behoed '
#                                     'voor het plegen van een overtreding .',
#                                     'De Kansspelautoriteit is tevens van '
#                                     'oordeel dat er geen aanleiding is te '
#                                     'veronderstellen dat het sanctiebesluit in '
#                                     'rechte geen stand zal houden. Naar het '
#                                     'oordeel van de Kansspelautoriteit is '
#                                     'afdoende aangetoond dat er sprake is van '
#                                     'een overtreding van artikel 1. eerste '
#                                     'lid, aanhef en onder a, van de Wok.',
#                                     'Van andere belangen of omstandigheden; op '
#                                     'grond waarvan zou moeten worden afgezien '
#                                     'van openbaarmaking, is de '
#                                     'Kansspelautoriteit niet gebleken.',
#                                     'Besluit',
#                                     '19. Op grond van het voorgaande zal de '
#                                     'Kansspelautoriteit overgaan tot '
#                                     'openbaarmaking van het besluit van 20 '
#                                     'december 2022, kenmerk 15269/01.281.230. '
#                                     'Tevens zal dit besluit tot openbaarmaking '
#                                     'openbaar worden gemaakt.',
#                                     '20 . In de openbaar te maken besluiten '
#                                     'blijft vermelding van de namen van alle '
#                                     'in de zaak betrokken natuurlijke personen '
#                                     'achterwege. Daarnaast blijven '
#                                     'bedrijfsvertrouwelijke gegevens buiten de '
#                                     'openbaarmaking. Tot slot blijft '
#                                     'openbaarmaking van de namen van '
#                                     'rechtspersonen ten aanzien van wie geen '
#                                     'overtreding wordt vastgesteld en geen '
#                                     'sanctie wordt opgelegd achterwege.',
#                                     '21. Openbaarmaking geschiedt door middel '
#                                     'van publicatie op de website WWW '
#                                     'kansspelautoriteit nl op de datum en tijd '
#                                     'zoals genoemd in de aanbiedingsbrief bij '
#                                     'dit besluit.',
#                                     'Den Haag, 20 december 2022',
#                                     'Hoogachtend ,',
#                                     'De raad van bestuur van de '
#                                     'Kansspelautoriteit, namens deze,'],
#                       'foot_text': [],
#                       'head_text': ['OPENBAAR',
#                                     'Kansspelautoriteit',
#                                     'Kansspelautoriteit',
#                                     'Datum',
#                                     '20 december 2022',
#                                     'Ons kenmerk',
#                                     '15269/01.281.234']},
#                      {'body_text': ['W.g.',
#                                     'mr. Laurence M.A. Gimbrere Hoofd afdeling '
#                                     'Juridische Zaken en Vergunningen',
#                                     'VERZONDEN OP [datum].',
#                                     'Tegen dit besluit kan degene wiens belang '
#                                     'rechtstreeks bij dit besluit is '
#                                     'betrokken; binnen zes weken na de dag van '
#                                     'bekendmaking van dit besluit een '
#                                     'gemotiveerd bezwaarschrift indienen bij '
#                                     'de Kansspelautoriteit, afdeling '
#                                     'Juridische Zaken en Vergunningen, Postbus '
#                                     '298, 2501 CG Den Haag. Let wel: het '
#                                     'instellen van bezwaar/beroep schort de '
#                                     'werking van dit besluit niet op. Kunt u '
#                                     'de beslissing op uw '
#                                     'bezwaarschrift/beroepschrift niet '
#                                     'afwachten vanwege een spoedeisend belang? '
#                                     'Dan kunt u bij de sector bestuursrecht '
#                                     'van de rechtbank in uw arrondissement een '
#                                     'verzoek om voorlopige voorziening '
#                                     'indienen'],
#                       'foot_text': [],
#                       'head_text': ['OPENBAAR',
#                                     'Kansspelautoriteit',
#                                     'Kansspelautoriteit',
#                                     'Datum',
#                                     '20 december 2022',
#                                     'Ons kenmerk',
#                                     '15269/01.281.234']}],
#            'status': 'Tegen dit besluit is bezwaar gemaakt.',
#            'url': 'https://kansspelautoriteit.nl/publish/library/32/15269_01-281-234_besluit_openbaarmaking_probe_investments_limited_ov.pdf'}],
#  'money': ['1128000',
#            '900000',
#            '600000',
#            '800000',
#            '800000',
#            '1600000',
#            '800000',
#            '600000',
#            '17363089',
#            '17363089',
#            '1128000',
#            '1128000'],
#  'name': 'Probe Investments Limited'}

# %% [markdown]
# ## Flattening to text

# %%
# Example: flatten documents into plain text files.
import re

files = [] # Our goal: a list of  (filename, singlestring)  tuples

for case_i, case in enumerate( cases ):   # enumerate helps numbering, e.g. enumerate(['q','r'])  yields  (0, 'q'),  (1, 'r')
    for doc_i, doc in enumerate( case['docs'] ):

        # figure out a descriptive filename
        case_safename = re.sub( '[^A-Za-z0-9\s]','', case['name'] )    # remove anything other than basic alphanumeric, so that it's safe to put in a file name
        doc_name      = wetsuite.helpers.format.url_basename(doc['url']).rsplit('.')[0] # the split takes off the .pdf
        filename      = "case%04d_doc%02d__%s__%s.txt"%(case_i, doc_i, case_safename, doc_name) # the numbering also makes filenames unique

        doc_text = [] # we collect document content here

        for page in doc['pages']:
            for par_i, par in enumerate( page['body_text'] ):
                # par is text, so we mostly just care to do that final 'doc_text.append( par )'

                # ...but here we try to estimates whether we should put in an empty line or not - whether the first text on a page continues a paragraph from the previous page
                if par_i == 0: # first text fragment on a page
                    first_character = par.strip()[0] # currently not very cleverly:
                    if first_character in '0123456789' or first_character != first_character.lower(): # assume a numbered thing is to be separated,   and not-lowercase the same (not always true) 
                        doc_text.append( '\n\n' ) # add empty line
                    else:
                        doc_text.append( '\n' ) # same paragraph, but let's put it on a new line  (you may care to change this, depending on how you consume that text)
                else: # all but the first paragraph: alway add an empty line
                    doc_text.append( '\n\n' ) # new paragraph

                doc_text.append( par )

        files.append( (filename, ''.join(doc_text)) )

# %%
# if doing this locally, you could write a few hundred .txt files        
for filename, content_string in files:
    print("WRITING %r"%filename)
    with open(filename, mode='w', encoding='utf8') as txtfile:
        txtfile.write( content_string )

# %%
# If doing this in google colab, you may want to fetch those files as a single archive
import zipfile
import google.colab.files

with zipfile.ZipFile('kansspel_txt.zip', 'w') as zip:
    for filename, content_string in files:
        zip.writestr( filename , content_string.encode('utf8'), compress_type=zipfile.ZIP_DEFLATED, compresslevel=5 )

google.colab.files.download('kansspel_txt.zip')

# %% [markdown]
# ## Something a little more interesting
#
# For a short example, let's make a word cloud for each case, for some idea about the focus of each case.
#
# We use spacy to extract only the nouns, and maybe verbs, to make that word cloud less messy.

# %%
# spacy itself was installed as a dependency of wetsuite,  but we do not necessarily have a language model to apply to the text:
# !python3 -m spacy download nl_core_news_md

# %%
import spacy
dutch = spacy.load('nl_core_news_md')

# %%
import textwrap, random, re
import wetsuite.helpers.format
import wetsuite.extras.word_cloud

stop_mixed = []
stop_mixed.extend( wetsuite.extras.word_cloud.stopwords_nl ) # shouldn't be as necessary when you use the 'only nouns' code, but in case you don't
stop_mixed.extend( 'Kansspelautoriteit kansspelen artikel lid Wet raad bestuur besluit'.split() ) # extra stopwords - nouns that we decide are common to all cases and less interesting to see

def show_wordcloud(words):
    counts = wetsuite.extras.word_cloud.count_normalized( words, stopwords=stop_mixed )
    im = wetsuite.extras.word_cloud.wordcloud_from_freqs( counts, 1100, 120 )
    display( im )   # note: display() exists in the context of IPython notebooks.  Outside of notebooks you would probably im.save() instead.


# only show wordcloud image for first few cases, to keep this demo notebook size down  (the rest are still parsed, but only for the final word count)
num_wordcloud_cases = 10

num_cases, num_docs, num_pages, num_pars, num_words = 0, 0, 0, 0, 0

for case_i, case in enumerate( cases ) :
    num_cases += 1
    print( 'CASE: %s'%case['name'] )
    words = [] # collects interesting words for a case
    for doc in case['docs']:
        num_docs += 1
        print( '  %s'%wetsuite.helpers.format.url_basename(doc['url']) )
        for page in doc['pages']:
            num_pages += 1
            for par in page['body_text']:
                num_pars += 1
                #for line in textwrap.wrap( par ):
                #    print(line)
                #print()
                parsed = dutch( par )
                for token in parsed:
                    num_words += 1
                    if token.pos_ in ('NOUN','PROPN', 'VERB'):
                        words.append( token.text )

    print( '  %d words'%(len(words))  )
    if case_i < num_wordcloud_cases: 
        show_wordcloud( words )
    print()
    print('-'*80)


print( '\n\nTotal number of   cases:%d  documents:%d   pages:%d   text fragments:%d   words:%d'%( num_cases, num_docs, num_pages, num_pars, num_words) )
# Out:
# CASE: Toto Online B.V.
#   01_278_071_15091_sanctiebesluit_toto_ov.pdf
#   01_278_082_ov_openbaarmakingsbesluit_woo_15091.pdf
#   2204 words
# <PIL.Image.Image image mode=RGB size=1100x120 at 0x7F5B1DF39B80>
# --------------------------------------------------------------------------------
# CASE: Nationale Posctode Loterij N.V.
#   sanctiebesluit_npl.pdf
#   openbaarmakingsbesluit_npl.pdf
#   2344 words
# <PIL.Image.Image image mode=RGB size=1100x120 at 0x7F5B1DF8C310>
# --------------------------------------------------------------------------------
# CASE: M.K.C Limited
#   20220823_01_265_505_-_besluit_last_onder_dwangsom_ov.pdf
#   20220823_01_265_507_-_besluit_openbaarmaking_ov.pdf
#   1589 words
# <PIL.Image.Image image mode=RGB size=1100x120 at 0x7F5B1DF39F40>
# --------------------------------------------------------------------------------
# CASE: L.C.S Limited
#   20220817_01_265_500_-_besluit_lod_sons-of-slots_ov.pdf
#   20220817_01_265_499_-_besluit_openbaarmaking_ov.pdf
#   1590 words
# <PIL.Image.Image image mode=RGB size=1100x120 at 0x7F5B1E3ABC40>
# --------------------------------------------------------------------------------
# CASE: Gammix Limited
#   20220707_01_270_078_-_lod_gammix_ov.pdf
#   20220707_01_270_081_-_besluit_openbaarmaking_gammix_ov.pdf
#   2029 words
# <PIL.Image.Image image mode=RGB size=1100x120 at 0x7F5B1DFE6490>
# --------------------------------------------------------------------------------
# CASE: Red Ridge Marketing
#   20220412_01_263_969_besluit_lod_ov_1.pdf
#   20220412_01_263_968_besluit_openbaarmaking_wob_ov_1.pdf
#   1664 words
# <PIL.Image.Image image mode=RGB size=1100x120 at 0x7F5B1DF39A90>
# --------------------------------------------------------------------------------
# CASE: Performing Media Limited
#   last_onder_dwangsom_performing_media_limited.pdf
#   besluit_tot_openbaarmaking_performing_media_limited.pdf
#   1787 words
# <PIL.Image.Image image mode=RGB size=1100x120 at 0x7F5B1E36C820>
# --------------------------------------------------------------------------------
# CASE: Linkerik B.V.
#   besluit_last_onder_dwangsom_14508.pdf
#   besluit_openbaarmaking_14508.pdf
#   1559 words
# <PIL.Image.Image image mode=RGB size=1100x120 at 0x7F5B1DF395E0>
# --------------------------------------------------------------------------------
# CASE: Onlinecasinobonus.nl
#   last_onder_dwangsom_onlinecasinobonus_nl.pdf
#   besluit_openbaarmaking_onlinecasinobonus_nl.pdf
#   2048 words
# <PIL.Image.Image image mode=RGB size=1100x120 at 0x7F5B1DF8C490>
# --------------------------------------------------------------------------------
# CASE: LCB CORP
#   lcb_corp_lod_20211213_01_252_632_lod_nl_lcb_org_ov.pdf
#   lcb_corp_besluit_openbaarmaking_20211213_01_252_633.pdf
#   1562 words
# <PIL.Image.Image image mode=RGB size=1100x120 at 0x7F5C088B43A0>
# --------------------------------------------------------------------------------
# CASE: Casinoscout.nl
#   casinoscout_nl_besluit_openbaarmaking_ov.pdf
#   casinoscout_nl_lod.pdf
#   1318 words
#
# --------------------------------------------------------------------------------
# CASE: Online Casino Ground ltd
#   last_onder_dwangsom_online_casino_ground_ltd.pdf
#   besluit_openbaarmaking_online_casino_ground_ltd.pdf
#   1352 words
#
# --------------------------------------------------------------------------------
# CASE: Slots Dev
#   last_onder_dwangsom_slots_dev.pdf
#   besluit_openbaarmaking_slots_dev.pdf
#   1337 words
#
# --------------------------------------------------------------------------------
# CASE: Tipico Co. Ltd
#   besluit_tipico_openbaar.pdf
#   openbaarmakingsbesluit_tipico_openbaar.pdf
#   2867 words
#
# --------------------------------------------------------------------------------
# CASE: BSB Shop
#   besluit_last_onder_dwangsom_bsb_shop.pdf
#   besluit_openbaarmaking_bsb_shop.pdf
#   1238 words
#
# --------------------------------------------------------------------------------
# CASE: Luxury Bingo
#   besluit_lxury_bingo.pdf
#   besluit_openbaarmaking_luxery_bingo.pdf
#   1354 words
#
# --------------------------------------------------------------------------------
# CASE: N1 Interactive Limited
#   beslissing_op_bezwaar_n1_interactive_ltd.pdf
#   besluit_openbaarmaking_n1_interactive_ltd.pdf
#   bac_advies_n1_interactive_ltd.pdf
#   besluit_n1_interactive_limited_ov.pdf
#   openbaarmakingsbesluit_interactive_limited.pdf
#   6186 words
#
# --------------------------------------------------------------------------------
# CASE: Staatsloterij B.V.
#   20220118_-_01_256_290_intrekkingsbesluit.pdf
#   20220224_-_01_258_184_openbaarmakingsbesluit_intrekkingsbesluit.pdf
#   sanctiebesluit_staatsloterij.pdf
#   besluit_tot_openbaarmaking_staatsloterij.pdf
#   3310 words
#
# --------------------------------------------------------------------------------
# CASE: Raging Rhino N.V.
#   sanctiebesluit_raging_rhino_n_v.pdf
#   besluit_tot_openbaarmaking_raging_rhino_n_v.pdf
#   2567 words
#
# --------------------------------------------------------------------------------
# CASE: Lovelto Mar LTD
#   01_237_092_-_invorderingsbeschikking_ov.pdf
#   01_237_093_-_besluit_openb_invorderingsbeschikking_ov.pdf
#   lod_ov.pdf
#   01_077_647_-_besluit_openbaarmaking_-_ov_1.pdf
#   2472 words
#
# --------------------------------------------------------------------------------
# CASE: 1X Corp N.V._Exinvest Limited
#   12924_beslissing_op_bezwaar_ov.pdf
#   12924_beslissing_op_bezwaar_ov.pdf
#   12924_advies_bac_ov.pdf
#   12924_advies_bac_ov.pdf
#   12924_besluit_openbaarmaking_bob_ov.pdf
#   12924_-_01_047_552_sanctiebesluit_-_openbare_versie_met_logo_1.pdf
#   12924_-_01_047_553_openbaarmakingsbesluit_-_openbare_versie_met_logo_1.pdf
#   11972 words
#
# --------------------------------------------------------------------------------
# CASE: WL Deal
#   01_079_482_besluit_lod_wl_deal_openbaar.pdf
#   01_079_484_besluit_openbaarmaking_lod_wl_deal_openbaar.pdf
#   1445 words
#
# --------------------------------------------------------------------------------
# CASE: Virtual Coin Gaming N.V.
#   besluit_op_bezwaar_virtual_coin_gaming.pdf
#   advies_van_de_adviescommissie_bezwaarschriften.pdf
#   besluit_openbaarmaking_virtual_coin_gaming.pdf
#   besluit_openbaarmaking_betalingsweigering_virtual_coin_gaming_n_v.pdf
#   sanctiebesluit_futgalaxy_openbaar.pdf
#   besluit_openbaarmaking_futgalaxy_openbaar.pdf
#   10062 words
#
# --------------------------------------------------------------------------------
# CASE: Clipboard Publications B.V.
#   20200806_01_073_790_lod_bevorderen_ov.pdf
#   20200806_01_073_815_besluit_openbaarmaking_ov_1.pdf
#   1459 words
#
# --------------------------------------------------------------------------------
# CASE: Kelner Automaten Service
#   beslissing_op_bezwaar.pdf
#   advies_bac.pdf
#   besluit_openbaarmaking.pdf
#   sanctiebesluit_betrokkene_handelend_onder_de_naam_kelner_automaten_service.pdf
#   openbaarmakingsbesluit_betrokkene_handelend_onder_de_naam_kelner_automaten_service.pdf
#   4132 words
#
# --------------------------------------------------------------------------------
# CASE: Schinveld BV
#   beslissing_op_bezwaar.pdf
#   advies_bac.pdf
#   besluit_openbaarmaking_schinveld_bv.pdf
#   sanctiebesluit_schinveld_bv.pdf
#   openbaarmakingsbesluit_schinveld_bv.pdf
#   4792 words
#
# --------------------------------------------------------------------------------
# CASE: Voormalig exploitant Dordrecht
#   01_066_052_besluit_lob_openbaar.pdf
#   01_066_052_besluit_lob_openbaar.pdf
#   01_066_053_besluit_openbaarmaking_lob_openbaar.pdf
#   1681 words
#
# --------------------------------------------------------------------------------
# CASE: Voormalig exploitant Amersfoort
#   01_062_613_besluit_lob_openbaar.pdf
#   01_062_614_besluit_openbaarmaking_lob_openbaar.pdf
#   1048 words
#
# --------------------------------------------------------------------------------
# CASE: Royal Panda Limited
#   13384_002_beslissing_op_bezwaar_ov.pdf
#   13384_002_bac_advies_ov.pdf
#   13384_002_besluit_openbaarmaking_ov.pdf
#   sanctiebesluit_rp_openbaar_1.pdf
#   openbaarmakingsbesluit_rp.pdf
#   5916 words
#
# --------------------------------------------------------------------------------
# CASE: LeoVegas Gaming
#   13385_002_beslissing_op_bezwaar_ov_002.pdf
#   13385_002_bac_advies_ov_002_2.pdf
#   13385_002_beslissing_op_bezwaar_besluit_openbaarmaking_ov_002.pdf
#   sanctiebesluit_lv_openbaar_002.pdf
#   sanctiebesluit_lv_openbaar_002.pdf
#   openbaarmaking_lv_openbaar.pdf
#   8309 words
#
# --------------------------------------------------------------------------------
# CASE: Pokerstars
#   13366_-_bob_-_pokerstars_ov.pdf
#   13366_bac-advies_pokerstars_ov.pdf
#   13366_-_besluit_openbaarmaking_bob_-_pokerstars_ov.pdf
#   besluit_pokerstars.pdf
#   openbaarmakingsbesluit_pokerstars.pdf
#   7196 words
#
# --------------------------------------------------------------------------------
# CASE: Chance Publications Malta Ltd
#   invorderingsbeschikking.pdf
#   besluit_openbaarmaking_invorderingsbeschikking.pdf
#   01_061_945_last_onder_dwangsom_openbare_versie.pdf
#   01_061_945_last_onder_dwangsom_openbare_versie.pdf
#   01_061_946_besluit_openbaarmaking_lod_openbare_versie.pdf
#   3657 words
#
# --------------------------------------------------------------------------------
# CASE: Unibet
#   13365_sanctie_besluit_ov.pdf
#   13365_openbaarmakingsbesluit_ov.pdf
#   6035 words
#
# --------------------------------------------------------------------------------
# CASE: Bwin
#   13367_001_01_067_148_openbare_versie_beslissing_op_bezwaar.pdf
#   13367_001_01_064_921_bac-advies-_openbaar.pdf
#   13367_002_01_067_145_besluit_openbaarmaking_bob-_openbaar.pdf
#   13367_-_sanctiebesluit_bwin_openbare_versie.pdf
#   13367_-_besluit_openbaarmaking_bwin_openbare_versie.pdf
#   5497 words
#
# --------------------------------------------------------------------------------
# CASE: Simbat Entertainment Systems en Spinity
#   besluit_openbaarmaking_betalingsweigering_simbat_openbaar.pdf
#   besluit_openbaarmaking_betalingsweigering_spinity.pdf
#   03_10474_besluit_op_bezwaar_openbare_versie_1.pdf
#   07_10474_openbaarmaking_bob_openbare_versie.pdf
#   04_10474_advies_commissie_openbare_versie.pdf
#   05_10474_bijlage_1_bij_het_advies_openbare_versie.pdf
#   06_10474_bijlage_2_bij_het_advies_openbare_versie.pdf
#   01_10474_sanctiebesluit_openbare_versie_1.pdf
#   01_10474_sanctiebesluit_openbare_versie_1.pdf
#   02_10474_-_openbaarmakingsbesluit_openbare_versie.pdf
#   46396 words
#
# --------------------------------------------------------------------------------
# CASE: Com Coin Operated Machines
#   besluit_last_onder_dwangsom.pdf
#   besluit_openbaarmaking_lod.pdf
#   1608 words
#
# --------------------------------------------------------------------------------
# CASE: Casumo
#   13078_besluit_op_bezwaar_ov.pdf
#   13078_-_advies_bac_casumo_ov.pdf
#   13078_bombob_ov.pdf
#   13878_-_sanctiebesluit.pdf
#   13078_-_openbaarmakingsbesluit.pdf
#   7617 words
#
# --------------------------------------------------------------------------------
# CASE: Innovation Labs en Gaming Innovation Group
#   openbaar_-_last_onder_dwangsom_ill.pdf
#   openbaar_-_last_onder_dwangsom_gig.pdf
#   openbaar_-_besluit_openbaarmaking_last_onder_dwangsom_ill.pdf
#   openbaar_-_besluit_openbaarmaking_last_onder_dwangsom_gig.pdf
#   openbaar_-_beslissing_op_bezwaar_ill_en_gig.pdf
#   openbaar_-_besluit_tot_openbaarmaking_van_de_beslissing_op_bezwaar_ill_en_gig.pdf
#   6220 words
#
# --------------------------------------------------------------------------------
# CASE: Content Publishing Limited
#   uitspraak_rechtbank_den_haag_van_10_januari_2019.pdf
#   primair_besluit_tot_oplegging_last_onder_dwangsom_1.pdf
#   openbaarmakingsbesluit_van_het_primaire_besluit.pdf
#   besluit_op_het_bezwaar_tegen_de_last_onder_dwangsom.pdf
#   openbaarmakingsbesluit_van_de_beslissing_op_bezwaar.pdf
#   4469 words
#
# --------------------------------------------------------------------------------
# CASE: Exploiteren zonder vergunning in café
#   besluit_01_047_464.pdf
#   besluit_tot_openbaarmaking_13052.pdf
#   01_037_509_besluit_last_onder_bestuursdwang.pdf
#   01_037_510_besluit_openbaarmaking.pdf
#   2550 words
#
# --------------------------------------------------------------------------------
# CASE: WHG (International) Limited
#   12920_besluit_openbaarmaking_openbaar.pdf
#   12920_bac_advies_whg_openbaar.pdf
#   12920_bac_advies_whg_openbaar.pdf
#   sanctiebesluit_whg.pdf
#   openbaarmakingsbesluit_whg.pdf
#   9176 words
#
# --------------------------------------------------------------------------------
# CASE: Voormalig exploitant Abcoude
#   01_044_953_besluit_last_onder_bestuursdwang_openbaar.pdf
#   01_044_954_besluit_openbaarmaking_lob_openbaar.pdf
#   2004 words
#
# --------------------------------------------------------------------------------
# CASE: CyberRock Entertainment N.V. en Honeydew Trading Limited.
#   besluit_openbaarmaking_betalingsweigering_cyberrock_honeydew_ov.pdf
#   12863_beslissing_op_bezwaar_cyberrock.pdf
#   12863_advies_van_de_commissie.pdf
#   13324_besluit_tot_openbaarmaking_bob_cyber_rock.pdf
#   12863_-_sanctiebesluit_docx.pdf
#   12863_besluit_tot_openbaarmaking.pdf
#   8846 words
#
# --------------------------------------------------------------------------------
# CASE: Mr Green Limited
#   beslissing_op_bezwaar_mr_green_1.pdf
#   besluit_openbaarmaking_beslissing_op_bezwaar.pdf
#   sanctiebesluit_mr_green.pdf
#   besluit_tot_openbaarmaking_mr_green.pdf
#   9097 words
#
# --------------------------------------------------------------------------------
# CASE: ITC Lounge Plaza
#   sanctiebesluit_itc_lounge_plaza.pdf
#   sanctiebesluit_itc_lounge_plaza.pdf
#   besluit_tot_openbaarmaking_itc_lounge_plaza.pdf
#   3131 words
#
# --------------------------------------------------------------------------------
# CASE: Corona Limited
#   beslissing_op_bezwaar_corona.pdf
#   besluit_openbaarmaking_bob_corona.pdf
#   12517_-_sanctiebesluit_ov_def_def.pdf
#   12517_-_openbaarmakingsbesluit_ov.pdf
#   13225 words
#
# --------------------------------------------------------------------------------
# CASE: Café restaurant De Kruik
#   last_onder_dwangsom_cafe_restaurant_de_kruik.pdf
#   besluit_openbaarmaking_cafe_restaurant_de_kruik.pdf
#   1274 words
#
# --------------------------------------------------------------------------------
# CASE: Bet-at-home
#   20190103-01_048_080_besluit_op_bezwaar.pdf
#   20190103-01_048_077_besluit_tot_openbaarmaking.pdf
#   sanctiebesluit_bet-at-home.pdf
#   besluit_tot_openbaarmaking_bet-at-home.pdf
#   7002 words
#
# --------------------------------------------------------------------------------
# CASE: Visionairy iGaming
#   openbaarmakingsbesluit_v_i_g_openbaar.pdf
#   openbaarmakingsbesluit_bestuurder_openbaar.pdf
#   sanctiebesluit_visionairy_igaming.pdf
#   besluit_tot_openbaarmaking_visionairy_igaming.pdf
#   4479 words
#
# --------------------------------------------------------------------------------
# CASE: VriendenLoterij N.V.
#   besluit_intrekken_lod_2.pdf
#   besluit_openbaarmaking_intrekking_lod_2.pdf
#   besluit_op_bezwaar_last_onder_dwangsom_npl_bgl_en_vl.pdf
#   besluit_tot_openbaarmaking_bob_npl_bgl_en_vd.pdf
#   last_onder_dwangsom_vriendenloterij_n_v.pdf
#   openbaarmaking_last_onder_dwangsom_vriendenloterij_n_v.pdf
#   openbaarmaking_last_onder_dwangsom_vriendenloterij_n_v.pdf
#   besluit_last_onder_dwangsom_gdl.pdf
#   besluit_openbaarmaking_last_onder_dwangsom_gdl.pdf
#   7028 words
#
# --------------------------------------------------------------------------------
# CASE: BankGiro Loterij N.V.
#   besluit_intrekken_lod_1.pdf
#   besluit_openbaarmaking_intrekking_lod_1.pdf
#   besluit_op_bezwaar_last_onder_dwangsom_npl_bgl_en_vl.pdf
#   besluit_tot_openbaarmaking_bob_npl_bgl_en_vd.pdf
#   last_onder_dwangsom_bankgiro_loterij_n_v.pdf
#   openbaarmaking_last_onder_dwangsom_bankgiro_loterij_n_v.pdf
#   besluit_last_onder_dwangsom_gdl.pdf
#   besluit_openbaarmaking_last_onder_dwangsom_gdl.pdf
#   6570 words
#
# --------------------------------------------------------------------------------
# CASE: Nationale Postcode Loterij N.V.
#   besluit_intrekken_lod.pdf
#   besluit_openbaarmaking_intrekking_lod.pdf
#   190520-01_056_018-01_057_548_invorderingsbeschikking_-_npl_-_openbaar.pdf
#   190520-01_056_019-01_057_549_besluit_openbaarmaking_invorderingsbeschikking_-_npl_-_openbaar.pdf
#   besluit_op_bezwaar_last_onder_dwangsom_npl_bgl_en_vl.pdf
#   besluit_tot_openbaarmaking_bob_npl_bgl_en_vd.pdf
#   last_onder_dwangsom_nationale_postcode_loterij_n_v.pdf
#   openbaarmaking_last_onder_dwangsom_nationale_postcode_loterij_n_v.pdf
#   besluit_last_onder_dwangsom_gdl.pdf
#   besluit_openbaarmaking_last_onder_dwangsom_gdl.pdf
#   8167 words
#
# --------------------------------------------------------------------------------
# CASE: Lotto B.V.
#   20220901_-_01_272_228_openbare_versie_besluit_opheffen_last_lotto.pdf
#   20220901_-_01_273_365_besluit_tot_openbaarmaking_opheffing_lod_van_19-10-2017.pdf
#   20211025_-_01_249_821_openbare_versie_invorderingsbeschikking_toto_def_002.pdf
#   openbaarmakingsbesluit_lotto_11.pdf
#   invorderingsbeschikking_lotto.pdf
#   openbaarmakingsbesluit_lotto.pdf
#   01_047_588_-_01_046_119_invorderingsbeschikking_-_lotto_-_def_openbaar_002.pdf
#   01_047_589_besluit_openbaarmaking_invorderingsbeschikking_-_lotto_-_def_openbaar_002.pdf
#   besluit_op_bezwaar_last_onder_dwansom_staatsloterij_en_lotto.pdf
#   besluit_tot_openbaarmaking_bob_staatloterij_en_lotto.pdf
#   last_onder_dwangsom_lotto_b_v.pdf
#   openbaarmaking_last_onder_dwangsom_lotto_b_v.pdf
#   11362 words
#
# --------------------------------------------------------------------------------
# CASE: Staatsloterij B.V.
#   20220114_-_01_255_681_openbare_versie_besluit_opheffen_last_staatsloterij.pdf
#   20220114_-_01_255_680_openbaarmakingsbesluit_staatsloterij.pdf
#   01_047_590_-_01_046_120_invorderingsbeschikking_-_staatsloterij_-_def_openbaar.pdf
#   01_049_931_besluit_openbaarmaking_invorderingsbeschikking_-_staatsloterij_-_def_openbaar.pdf
#   besluit_op_bezwaar_last_onder_dwansom_staatsloterij_en_lotto.pdf
#   besluit_tot_openbaarmaking_bob_staatloterij_en_lotto.pdf
#   last_onder_dwangsom_staatsloterij_b_v.pdf
#   openbaarmaking_last_onder_dwangsom_staatsloterij_b_v.pdf
#   7895 words
#
# --------------------------------------------------------------------------------
# CASE: Holland Casino N.V.
#   20220114_-_01_255_682_openbare_versie_besluit_tot_opheffen_last_holland_casino.pdf
#   20220114_-_01_255_677_openbaarmakingsbesluit_hc.pdf
#   last_onder_dwangsom_holland_casino.pdf
#   openbaarmaking_last_onder_dwangsom_holland_casino.pdf
#   2698 words
#
# --------------------------------------------------------------------------------
# CASE: Catena Operations Limited
#   besluit_last_onder_dwangsom_catena_operations_limited.pdf
#   besluit_openbaarmaking_last_onder_dwangsom_catena_operations_limited.pdf
#   1676 words
#
# --------------------------------------------------------------------------------
# CASE: Weddenopvoetbal.org
#   10762_-_01_022_342_en_10868_-_01_022_343_besluit_op_bezwaar_openbaar.pdf
#   10762_-_01_022_344_en_10868_-_01_022_345_besluit_tot_openbaarmaking_openbaar.pdf
#   besluit_tot_openbaarmaking_besluit_op_bezwaar_weddenopvoetbal_org.pdf
#   besluit_last_onder_dwangsom_weddenopvoetbal_org.pdf
#   2823 words
#
# --------------------------------------------------------------------------------
# CASE: JvG speelautomaten
#   besluit_last_onder_dwangsom_jvg_amusement_vending_b_v.pdf
#   openbaarmakingsbesluit_jvg_amusement_bending_b_v.pdf
#   1109 words
#
# --------------------------------------------------------------------------------
# CASE: Trustfulgames.com Limited
#   besluit_openbaarmaking_betalingsweigering_trustfulgames.pdf
#   besluit_openbaarmaking_betalingsweigering_bestuurder_1.pdf
#   besluit_openbaarmaking_betalingsweigering_bestuurder_2.pdf
#   10507_-_sanctiebesluit_adviescommissie_003.pdf
#   10507_-_besluit_tot_openbaarmaking_003.pdf
#   sanctiebesluit_trustfulgames.pdf
#   besluit_tot_openbaarmaking_trustfulgames.pdf
#   7200 words
#
# --------------------------------------------------------------------------------
# CASE: L.S.A. B.V
#   besluit_op_bezwaar_l_s_a_b_v.pdf
#   ecli_nl_rvs_2019_11_uitspraak_inzake_lob_lsa_bv.pdf
#   besluit_tot_openbaarmaking.pdf
#   besluit_last_onder_bestuursdwang_02112016_geanonimiseerd.pdf
#   besluit_openbaarmaking_-_openbare_versie_op_briefpapier.pdf
#   2530 words
#
# --------------------------------------------------------------------------------
# CASE: M-automaten exploitatie
#   00_082_720_openbare_versie_last_onder_bestuursdwang.pdf
#   00_082_721_openbare_versie_besluit_tot_opehbaarmaking.pdf
#   902 words
#
# --------------------------------------------------------------------------------
# CASE: Wedwinkel Rotterdam
#   sanctiebesluit_wedwinkel.pdf
#   openbaarmakingsbesluit_wedwinkel.pdf
#   3167 words
#
# --------------------------------------------------------------------------------
# CASE: Friese ondernemer
#   besluit_last_onder_bestuursdwang.pdf
#   522 words
#
# --------------------------------------------------------------------------------
# CASE: Holland Gaming
#   besluit_op_bezwaar_holland_gaming.pdf
#   besluit_tot_openbaarmaking_holland_gaming.pdf
#   1176 words
#
# --------------------------------------------------------------------------------
# CASE: Olders Amusementsautomaten B.V.
#   besluit_last_bestuursdwang_-_olders_amusementsautomaten_bv_-_geanonimiseerde_versie_voor_publicatie.pdf
#   347 words
#
# --------------------------------------------------------------------------------
# CASE: Duitse loterijen
#   10072_-_00_071_137_en_10136_-_00_071_138_besluit_openbaar.pdf
#   10072_-_00_071_140_en_10136_-_00_071_141_besluit_openbaarmaking_openbaar.pdf
#   6237 words
#
# --------------------------------------------------------------------------------
# CASE: Dolle Pret in Almelo B.V.
#   last_onder_dwangsom_dolle_pret_in_almelo.pdf
#   besluit_tot_openbaarmaking_dolle_pret_in_almelo.pdf
#   2619 words
#
# --------------------------------------------------------------------------------
# CASE: Redslots
#   besluit_openbaarmaking_betalingsweigering_bluemay_enterprises_n_v_-_red.pdf
#   besluit_op_bezwaar_redslots.pdf
#   besluit_tot_openbaarmaking_bob_redslots.pdf
#   besluit_tot_openbaarmaking_bob_redslots.pdf
#   sanctiebesluit_redslots.pdf
#   besluit_tot_openbaarmaking_redslots.pdf
#   6741 words
#
# --------------------------------------------------------------------------------
# CASE: Café _ Bar Bağci
#   besluit_op_bezwaar_cafe_-_bar_bagci.pdf
#   besluit_tot_openbaarmaking_cafe_-_bar_bagci_2.pdf
#   sanctiebesluit_cafe_-_bar_bagci.pdf
#   besluit_tot_openbaarmaking_cafe_-_bar_bagci.pdf
#   3274 words
#
# --------------------------------------------------------------------------------
# CASE: Total E Soft Limited en XKL Limited
#   besluit_op_bezwaar_total_e_soft.pdf
#   besluit_tot_openbaarmaking_total_e_soft.pdf
#   sanctiebesluit_total_e_soft_limited_en_xkl_limited.pdf
#   besluit_tot_openbaarmaking_total_e_soft_limited_en_xkl_limited.pdf
#   4939 words
#
# --------------------------------------------------------------------------------
# CASE: Belhuis _ Internetcafé Ephesus
#   sanctiebesluit_belhuis_-_internetcafe_ephesus.pdf
#   sanctiebesluit_belhuis_-_internetcafe_ephesus.pdf
#   besluit_tot_openbaarmaking_belhuis_-_internetcafe_ephesus.pdf
#   3403 words
#
# --------------------------------------------------------------------------------
# CASE: V.O.F. AULON
#   besluit_v_o_f_aulon.pdf
#   besluit_tot_openbaarmaking_v_o_f_aulon.pdf
#   1394 words
#
# --------------------------------------------------------------------------------
# CASE: V.O.F. Bosma Amusement
#   besluit_v_o_f_bosma_amusement.pdf
#   besluit_tot_openbaarmaking_v_o_f_bosma_amusement.pdf
#   1450 words
#
# --------------------------------------------------------------------------------
# CASE: Stichting Sport Twente
#   sanctiebesluit_stichting_sport_twente.pdf
#   besluit_tot_openbaarmaking_stichting_sport_twente.pdf
#   besluit_op_bezwaar_stichting_sport_twente.pdf
#   besluit_tot_openbaarmaking_stichting_sport_twente_2.pdf
#   3574 words
#
# --------------------------------------------------------------------------------
# CASE: Thee- en koffiehuis Kayseri
#   besluit_op_bezwaar_kayseri.pdf
#   besluit_tot_openbaarmaking_kayseri.pdf
#   sanctiebesluit_thee-_en_koffiehuis_kayseri.pdf
#   besluit_tot_openbaarmaking_thee-_en_koffiehuis_kayseri.pdf
#   3455 words
#
# --------------------------------------------------------------------------------
# CASE: Eetcafé De Gouw
#   besluit_op_bezwaar_eetcafe_de_gouw.pdf
#   besluit_openbaarmaking_eetcafe_de_gouw.pdf
#   sanctiebesluit_eetcafe_de_gouw_1.pdf
#   besluit_tot_openbaarmaking_eetcafe_de_gouw_1.pdf
#   4289 words
#
# --------------------------------------------------------------------------------
# CASE: Co Gaming Limited (voorheen Come On Europe Limited)
#   besluit_op_bezwaar_co_gaming_limited.pdf
#   besluit_tot_openbaarmaking_co_gaming_limited.pdf
#   1_sanctiebesluit_come_on.pdf
#   besluit_tot_openbaarmaking_come_on.pdf
#   7769 words
#
# --------------------------------------------------------------------------------
# CASE: Stichting Trefcentrum Brinkstraat
#   besluit_op_bezwaar_stichting_trefcentrum_brinkstraat.pdf
#   besluit_openbaarmaking_stichting_trefcentrum_brinkstraat.pdf
#   sanctiebesluit_stichting_trefcentrum_brinkstraat.pdf
#   besluit_tot_openbaarmaking_stichting_trefcentrum_brinkstraat.pdf
#   4635 words
#
# --------------------------------------------------------------------------------
# CASE: Imperial E-club Limited
#   besluit_op_bezwaar_imperial_e-club_limited.pdf
#   besluit_tot_openbaarmaking_bob_imperial_e-club_limited.pdf
#   sanctiebesluit_imperial_e-club_limited.pdf
#   besluit_tot_openbaarmaking_imperial_e-club_limited.pdf
#   6454 words
#
# --------------------------------------------------------------------------------
# CASE: Stichting Bil Kazan
#   besluit_op_bezwaar_stichting_bil_kazan.pdf
#   7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf
#   sanctiebesluit_stichting_biil_kazan_1.pdf
#   besluit_tot_openbaarmaking_stichting_bil_kazan_1.pdf
#   5604 words
#
# --------------------------------------------------------------------------------
# CASE: 7Red.com
#   besluit_openbaarmaking_betalingsweigering_bluemay_enterprises_n_v_-_7re.pdf
#   besluit_op_bezwaar_7red_com.pdf
#   7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf
#   sanctiebesluit_7red_com.pdf
#   besluit_openbaarmaking_7red_com.pdf
#   13231 words
#
# --------------------------------------------------------------------------------
# CASE: Villa Mountain View
#   besluit_op_bezwaar_villa_mountain_view.pdf
#   besluit_tot_openbaarmaking_villa_mountain_view.pdf
#   sanctiebesluit_villa_mountain_view.pdf
#   besluit_openbaarmaking_villa_mountain_view.pdf
#   5372 words
#
# --------------------------------------------------------------------------------
# CASE: GT Beheersorganisatie
#   sanctiebesluit_gt_beheersorganisatie.pdf
#   besluit_tot_openbaarmaking_gt_beheersorganisatie.pdf
#   1505 words
#
# --------------------------------------------------------------------------------
# CASE: Koffiehuis Vadi
#   sanctiebesluit_koffiehuis_vadi_-_openbaar.pdf
#   besluit_tot_openbaarmaking_koffiehuis_vadi_-_openbaar.pdf
#   2100 words
#
# --------------------------------------------------------------------------------
# CASE: Gooische Bingo Show
#   8090_-_00_023_231_sanctiebesluit_gooische_bingo_show.pdf
#   8090_-_00_023_232_openbaarmakingsbesluit_gooische_bingo_show.pdf
#   2858 words
#
# --------------------------------------------------------------------------------
# CASE: Globalstars
#   7822_sanctiebesluit_globalstars.pdf
#   7822_besluit_openbaarmaking_globalstars.pdf
#   7822_-_00_019_152_besluit_op_bezwaar_inclusief_advies_bac_-_openbare_versie.pdf
#   7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf
#   6686 words
#
# --------------------------------------------------------------------------------
# CASE: Grand Café Randenbroek
#   besluit_op_bezwaar_openbaar_cafe_randenbroek.pdf
#   besluit_openbaarmaking_bob_openbaar_cafe_randenbroek.pdf
#   7861_sanctiebesluit_grand_cafe_randenbroek.pdf
#   7861_besluit_openbaarmaking_grand_cafe_randenbroek.pdf
#   4535 words
#
# --------------------------------------------------------------------------------
# CASE: Onisac Limited en Mansion Online Casino Limited
#   190625_besluit_openbaarmaking_bob_onisac_openbaar_003.pdf
#   190704_bob_en_bac.pdf
#   sanctiebesluit_onisac.pdf
#   openbaarmakingsbesluit_sanctiebesluit_onisac.pdf
#   7845_00_021_663_-_sanctiebesluit_openbaar.pdf
#   7845_00_021_664-_openbaarmaking_openbaar.pdf
#   7845_-_advies_bac_ov_pdf.pdf
#   7845_-_beslissing_op_bezwaar_ov_pdf.pdf
#   8051_-_besluit_openbaarmaking_bob_ov_pdf.pdf
#   11817 words
#
# --------------------------------------------------------------------------------
# CASE: Café Lucky
#   besluit_op_bezwaar_openbaar_cafe_lucky.pdf
#   besluit_openbaarmaking_bob_openbaar_cafe_lucky.pdf
#   7938_-_00_018_637_sanctiebesluit_openbare_versie.pdf
#   7938_besluit_openbaarmaking_cafe_lucky.pdf
#   4164 words
#
# --------------------------------------------------------------------------------
# CASE: Star SAT Electronica
#   7971_-_00_019_052_sanctiebesluit_openbare_versie.pdf
#   7971_besluit_openbaarmaking_star_sat_electronica.pdf
#   1868 words
#
# --------------------------------------------------------------------------------
# CASE: Call Internet City
#   besluit_op_bezwaar_openbaar_call_internet_city.pdf
#   7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf
#   7970_sanctiebesluit_call_internet_city.pdf
#   7970_besluit_openbaarmaking_call_internet_city.pdf
#   3144 words
#
# --------------------------------------------------------------------------------
# CASE: Huizenloterij
#   7982_-_00_020_754_kennisgeving_als_bedoeld_in_art_5_50_lid_2_sub_a_awb_openbaar.pdf
#   7982_-_00_020_755_besluit_tot_openbaarmaking_openbaar.pdf
#   7982_-_00_026_508_en_8140_-_00_026_510_besluit_op_bezwaar_openbaar1.pdf
#   7982_-_00_025_509_en_8140_-_00_026_511_besluit_openbaarmaking_bob_openbaar1.pdf
#   5595 words
#
# --------------------------------------------------------------------------------
#
#
# Total number of   cases:92  documents:351   pages:3573   text fragments:29199   words:1180435
